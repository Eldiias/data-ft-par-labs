# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import os

# %%
os.chdir(r'C:\Users\Quoc\Desktop\[ironhack]\[IronHack]\github\data-ft-par-labs\Labs\data')

# %%
data = pd.read_csv('.\liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
items = data.groupby('ItemType')[['RetailSales', 'RetailTransfers', 'WarehouseSales']].sum()

# %%
items.plot.bar()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
suppliers = data.groupby('Supplier')[['RetailSales', 'WarehouseSales']].sum().sort_values(by=['RetailSales', 'WarehouseSales'], ascending=False)[:10]
suppliers
# Out:
#                           RetailSales  WarehouseSales
# Supplier
# E & J GALLO WINERY           67455.63        75594.99
# DIAGEO NORTH AMERICA INC     57656.36        54252.88
# CONSTELLATION BRANDS         54472.51        44968.76
# ANHEUSER BUSCH INC           42559.14       493856.19
# JIM BEAM BRANDS CO           39156.79         2928.45
# MILLER BREWING COMPANY       35022.63       572623.41
# BACARDI USA INC              28034.63         4050.48
# CROWN IMPORTS                26707.83       579824.70
# SAZERAC CO                   25772.63         5304.18
# THE WINE GROUP               25758.15        26603.78

# %%
suppliers.plot.barh()

# %%
data['Supplier'].nunique()
# Out:
# 333

# %%
d=data[['Supplier','ItemType','RetailSales','RetailTransfers','WarehouseSales']].groupby(['Supplier','ItemType']).sum().sum(axis=1).sort_values(ascending=False)[:10]
d
# Out:
# Supplier                  ItemType
# MILLER BREWING COMPANY    BEER        638627.76
# CROWN IMPORTS             BEER        634868.20
# ANHEUSER BUSCH INC        BEER        606415.98
# HEINEKEN USA              BEER        360461.30
# E & J GALLO WINERY        WINE        194933.74
# CONSTELLATION BRANDS      WINE        143333.16
# DIAGEO NORTH AMERICA INC  LIQUOR      104393.72
# JIM BEAM BRANDS CO        LIQUOR       84499.06
# THE WINE GROUP            WINE         80823.98
# BOSTON BEER CORPORATION   BEER         73465.12
# dtype: float64

# %%
d.plot.barh()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
month = data.groupby('Month')[['RetailSales', 'RetailTransfers', 'WarehouseSales']].mean()
month
# Out:
#        RetailSales  RetailTransfers  WarehouseSales
# Month
# 1         5.679413         5.574833       19.072137
# 2         5.939247         6.050136       20.229658
# 4         0.000000        15.707503        0.000000
# 5         7.038838         7.421817       27.310548
# 6         7.143914         6.950396       27.839069
# 8         6.409991         6.584726       28.122641
# 9         6.757254         6.419721       22.817909
# 10        6.549021         6.827827       22.289367
# 11        6.765496         7.103699       23.348862
# 12        9.078241         8.353759       21.169463

# %%
fig = plt.figure(figsize=(15,6))
plt.plot(month['RetailSales'], label='RetailSales')
plt.plot(month['RetailTransfers'], label='RetailTransfers')
plt.plot(month['WarehouseSales'], label='WarehouseSales')
plt.legend()
plt.show()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
month.plot.bar()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data
# Out:
#         Year  Month                      Supplier ItemCode  \
# 0       2017      4               ROYAL WINE CORP   100200
# 1       2017      4      SANTA MARGHERITA USA INC   100749
# 2       2017      4            JIM BEAM BRANDS CO    10103
# 3       2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4       2017      4               ROYAL WINE CORP   101664
# ...      ...    ...                           ...      ...
# 128350  2018      2            ANHEUSER BUSCH INC     9997
# 128351  2018      2   COASTAL BREWING COMPANY LLC    99970
# 128352  2018      2       BOSTON BEER CORPORATION    99988
# 128353  2018      2                           NaN       BC
# 128354  2018      2                           NaN       WC
#
#                                     Description ItemType  RetailSales  \
# 0                             GAMLA CAB - 750ML     WINE         0.00
# 1          SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE         0.00
# ...

# %%
fig = plt.figure(figsize=(20,15))
d = da.pivot_table(index=['Year','Month'],columns='ItemType',values='RetailSales',aggfunc='mean')

d.plot()
plt.show()

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
d.plot.bar()

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
fig = plt.figure(figsize=(10,10))
sns.scatterplot(data = data, x=data['RetailSales'], y =data['RetailTransfers'], hue='ItemType')

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Supplier', 'ItemCode', 'Description', 'ItemType',
#        'RetailSales', 'RetailTransfers', 'WarehouseSales'],
#       dtype='object')

# %%
sns.pairplot(data[['Year', 'Month', 'Supplier', 'ItemCode', 'Description', 'ItemType',
       'RetailSales', 'RetailTransfers', 'WarehouseSales']], hue='ItemType')
