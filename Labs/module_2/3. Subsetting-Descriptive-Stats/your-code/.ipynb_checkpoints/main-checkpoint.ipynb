# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
df = pd.read_csv('.\Temp_states.csv')

# %% [markdown]
# #### Print `temp`.

# %%
df.head()
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
df.dtypes
# Out:
# Department    object
# Education     object
# Title         object
# Name          object
# Years          int64
# Salary         int64
# dtype: object

# %%
"""
city = object
State = object
Temperature = float
"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
df[df['State'] == 'New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
df[df['State'] == 'New York'].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
df[df['Temperature'] > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
pd.DataFrame(df.loc[(df['Temperature']>15), 'City'])
# Out:
#        City
# 0       NYC
# 3  Hartford
# 5    Treton
# 6    Newark

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
pd.DataFrame(df.loc[(df['Temperature']>15) & (df['Temperature']<20), 'City'])
# Out:
#        City
# 0       NYC
# 3  Hartford

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
df.groupby('State').Temperature.mean()
# Out:
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741
# Name: Temperature, dtype: float64

# %%
df.groupby('State').Temperature.std()
# Out:
# State
# Connecticut    1.964186
# New Jersey     1.571348
# New York       8.133404
# Name: Temperature, dtype: float64

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
df2 = pd.read_csv('.\employees.csv')

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Department  500 non-null    object
#  1   Education   500 non-null    object
#  2   Title       500 non-null    object
#  3   Name        500 non-null    object
#  4   Years       500 non-null    int64
#  5   Salary      500 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 15.7+ KB

# %%
"""
Department = object
Education = object
Title = object
Name = object
Years = int64 
Salary = int64 
"""

# %% [markdown]
# #### What's the average salary in this company?

# %%
df2
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 3        Admin    Master         VP  Manuella     15      33
# 4        Sales    Master    Analyst     Carla      6      38
# ..         ...       ...        ...       ...    ...     ...
# 495      Sales       PhD         VP    Calvin      2     119
# 496         HR    Master    Analyst    Dustin      6      67
# 497      Sales       PhD         VP   Winston     13      93
# 498         IT       PhD    Analyst      Earl     12     108
# 499      Sales    Master    Analyst     Alvin     13      48
#
# [500 rows x 6 columns]

# %%
df2['Salary'].mean()
# Out:
# 73.528

# %% [markdown]
# #### What's the highest salary?

# %%
df2['Salary'].max()
# Out:
# 120

# %%
df2['Salary'].nlargest()
# Out:
# 71     120
# 140    120
# 174    120
# 291    120
# 352    120
# Name: Salary, dtype: int64

# %% [markdown]
# #### What's the lowest salary?

# %%
df2['Salary'].min()
# Out:
# 30

# %%
df2['Salary'].nsmallest()
# Out:
# 27     30
# 106    30
# 128    30
# 139    30
# 214    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
df2
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 3        Admin    Master         VP  Manuella     15      33
# 4        Sales    Master    Analyst     Carla      6      38
# ..         ...       ...        ...       ...    ...     ...
# 495      Sales       PhD         VP    Calvin      2     119
# 496         HR    Master    Analyst    Dustin      6      67
# 497      Sales       PhD         VP   Winston     13      93
# 498         IT       PhD    Analyst      Earl     12     108
# 499      Sales    Master    Analyst     Alvin     13      48
#
# [500 rows x 6 columns]

# %%
df2.loc[df['Salary'].nsmallest(), 'Name']
# Out:
# 30    Ben
# 30    Ben
# 30    Ben
# 30    Ben
# 30    Ben
# Name: Name, dtype: object

# %%
df2[df2['Salary']== (df2['Salary'].min())]
# Out:
#     Department Education      Title      Name  Years  Salary
# 27          IT  Bachelor    Analyst      Sean     12      30
# 106      Admin  Bachelor  associate      Luke      4      30
# 128      Sales       PhD         VP      Adam      8      30
# 139      Sales       PhD    Analyst      Rick     11      30
# 214      Sales    Master         VP      Neil     11      30
# 266         HR       PhD  associate    Marcel     10      30
# 452         IT  Bachelor    Analyst  Augustin     13      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
df2[df2['Name'] == 'David']
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
df2.loc[(df2['Name'] == 'David'), 'Name':'Salary']
# Out:
#       Name  Years  Salary
# 0    David      4      58
# 124  David      3      31

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
df2[df2['Title'] == 'associate']
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
df.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
df.iloc[:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
df2[(df2['Title']=='associate') & (df2['Salary']>55)]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
df2.groupby('Years').Salary.mean()
# Out:
# Years
# 1     75.863636
# 2     75.857143
# 3     74.571429
# 4     77.129032
# 5     73.857143
# 6     72.382353
# 7     73.840000
# 8     64.250000
# 9     76.741935
# 10    73.351351
# 11    74.866667
# 12    73.454545
# 13    71.935484
# 14    70.968750
# 15    69.758621
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average salary per title?

# %%
df2.groupby('Title').Salary.mean()
# Out:
# Title
# Analyst      73.703911
# VP           72.907975
# associate    73.968354
# Name: Salary, dtype: float64

# %% [markdown]
# ####  Find the salary quartiles.

# %%
df2['Salary'].quantile(q=.25)
# Out:
# 50.0

# %%
df2['Salary'].quantile(q=.25)

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
"Damn well shouldnt be!"
# Out:
# 'Damn well shouldnt be!'

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
df2.describe()
# Out:
#             Years      Salary
# count  500.000000  500.000000
# mean     7.556000   73.528000
# std      4.465731   26.890061
# min      1.000000   30.000000
# 25%      3.000000   50.000000
# 50%      7.000000   72.000000
# 75%     11.250000   97.000000
# max     15.000000  120.000000

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
df2.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
df2['Salary'].max()
# Out:
# 120

# %%
df2['Salary'].min()
# Out:
# 30

# %%
df2.groupby('Department').Salary.apply(lambda x: x.max()-x.min())
# Out:
# Department
# Admin    90
# HR       89
# IT       90
# Sales    90
# Name: Salary, dtype: int64

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
df3 = pd.read_csv('.\Orders.csv')

# %%
df3.drop(columns='Unnamed: 0', inplace = True)

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
df3.head(3)
# Out:
#    InvoiceNo StockCode  year  month  day  hour  \
# 0     536365    85123A  2010     12    3     8
# 1     536365     71053  2010     12    3     8
# 2     536365    84406B  2010     12    3     8
#
#                           Description  Quantity          InvoiceDate  \
# 0  white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                 white metal lantern         6  2010-12-01 08:26:00
# 2      cream cupid hearts coat hanger         8  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     397924 non-null  int64
#  1   StockCode     397924 non-null  object
#  2   year          397924 non-null  int64
#  3   month         397924 non-null  int64
#  4   day           397924 non-null  int64
#  5   hour          397924 non-null  int64
#  6   Description   397924 non-null  object
#  7   Quantity      397924 non-null  int64
#  8   InvoiceDate   397924 non-null  object
#  9   UnitPrice     397924 non-null  float64
#  10  CustomerID    397924 non-null  int64
#  11  Country       397924 non-null  object
#  12  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 33.4+ MB

# %%
df3.describe()
# Out:
#            InvoiceNo           year          month            day  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   560617.126645    2010.934259       7.612537       3.614555
# std     13106.167695       0.247829       3.416527       1.928274
# min    536365.000000    2010.000000       1.000000       1.000000
# 25%    549234.000000    2011.000000       5.000000       2.000000
# 50%    561893.000000    2011.000000       8.000000       3.000000
# 75%    572090.000000    2011.000000      11.000000       5.000000
# max    581587.000000    2011.000000      12.000000       7.000000
#
#                 hour       Quantity      UnitPrice     CustomerID  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean       12.728247      13.021823       3.116174   15294.315171
# std         2.273535     180.420210      22.096788    1713.169877
# min         6.000000       1.000000       0.000000   12346.000000
# ...

# %%
"""
Data Frame containing mainly floats with some objects columns
"""

# %% [markdown]
# ####  What is the average purchase price?

# %%
df3.head(2)
# Out:
#    InvoiceNo StockCode  year  month  day  hour  \
# 0     536365    85123A  2010     12    3     8
# 1     536365     71053  2010     12    3     8
#
#                           Description  Quantity          InvoiceDate  \
# 0  white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                 white metal lantern         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34

# %%
df3['UnitPrice'].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
df3['UnitPrice'].nlargest()
# Out:
# 118352    8142.75
# 308822    4161.06
# 308846    4161.06
# 295254    3949.32
# 269591    3155.95
# Name: UnitPrice, dtype: float64

# %%
df3['UnitPrice'].max()
# Out:
# 8142.75

# %%
df3['UnitPrice'].nsmallest()
# Out:
# 6914     0.0
# 22539    0.0
# 25379    0.0
# 29080    0.0
# 29082    0.0
# Name: UnitPrice, dtype: float64

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
spain = df3[df3['Country'] == 'Spain']
spain
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 4250       536944     22383  2010     12    5    12
# 4251       536944     22384  2010     12    5    12
# 4252       536944     20727  2010     12    5    12
# 4253       536944     20725  2010     12    5    12
# 4254       536944     20728  2010     12    5    12
# ...           ...       ...   ...    ...  ...   ...
# 394733     581193     23291  2011     12    3    17
# 394734     581193    85232D  2011     12    3    17
# 394735     581193     22721  2011     12    3    17
# 394736     581193     23241  2011     12    3    17
# 394737     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# 4251          lunch bag pink polkadot       100  2010-12-03 12:20:00
# 4252          lunch bag  black skull.        60  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
spain.CustomerID.nunique()
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
x = df3.groupby('CustomerID').Quantity.sum().apply(lambda x: x > 50).reset_index()
x = x[x['Quantity']==True]
len(x)
# Out:
# 4091

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
spain[spain['Quantity'] > 50]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 4250       536944     22383  2010     12    5    12
# 4251       536944     22384  2010     12    5    12
# 4252       536944     20727  2010     12    5    12
# 4253       536944     20725  2010     12    5    12
# 4254       536944     20728  2010     12    5    12
# 32454      540785    84997B  2011      1    2    11
# 32455      540785    84997D  2011      1    2    11
# 32456      540785    84997C  2011      1    2    11
# 32457      540785    84997A  2011      1    2    11
# 91155      547972     22383  2011      3    1    16
# 91156      547972     22384  2011      3    1    16
# 91159      547972     20728  2011      3    1    16
# 174442     558871     22384  2011      7    1    13
# 174443     558871     20727  2011      7    1    13
# 174444     558871     20725  2011      7    1    13
# 174445     558871     20728  2011      7    1    13
# 174446     558871    84997B  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders.

# %%
df3[df3['UnitPrice'] == 0]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 6914       537197     22841  2010     12    7    14
# 22539      539263     22580  2010     12    4    14
# 25379      539722     22423  2010     12    2    13
# 29080      540372     22090  2011      1    4    16
# 29082      540372     22553  2011      1    4    16
# 34494      541109     22168  2011      1    4    15
# 53788      543599    84535B  2011      2    4    13
# 85671      547417     22062  2011      3    3    10
# 92875      548318     22055  2011      3    3    12
# 97430      548871     22162  2011      4    1    14
# 107192     550188     22636  2011      4    4    18
# 128641     553000     47566  2011      5    4    15
# 137127     554037     22619  2011      5    5    14
# 194648     561284     22167  2011      7    2    12
# 197173     561669     22960  2011      7    4    17
# 199711     561916         M  2011      8    1    11
# 208950     562973     23157  2011      8    4    11
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
df3[df3['Description'].str.startswith('lunch bag')]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 93         536378     20725  2010     12    3     9
# 172        536385     22662  2010     12    3     9
# 354        536401     22662  2010     12    3    11
# 359        536401     20725  2010     12    3    11
# 360        536401     22382  2010     12    3    11
# ...           ...       ...   ...    ...  ...   ...
# 397465     581486     23207  2011     12    5     9
# 397713     581538     20727  2011     12    5    11
# 397714     581538     20725  2011     12    5    11
# 397877     581581     23681  2011     12    5    12
# 397880     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# 172     lunch bag dolly girl design        10  2010-12-01 09:56:00       1.65
# 354     lunch bag dolly girl design         1  2010-12-01 11:21:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
df3[(df3['Description'].str.startswith('lunch bag')) & df3['InvoiceDate'].str.startswith('2011')]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 26340      540015     20725  2011      1    2    11
# 26341      540015     20726  2011      1    2    11
# 26512      540023     22382  2011      1    2    12
# 26513      540023     20726  2011      1    2    12
# 26860      540098     22384  2011      1    2    15
# ...           ...       ...   ...    ...  ...   ...
# 397465     581486     23207  2011     12    5     9
# 397713     581538     20727  2011     12    5    11
# 397714     581538     20725  2011     12    5    11
# 397877     581581     23681  2011     12    5    12
# 397880     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# 26341            lunch bag woodland        10  2011-01-04 11:40:00       1.65
# 26512    lunch bag spaceboy design          2  2011-01-04 12:58:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
spain['amount_spent'].value_counts().hist()

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
df3[df3['month'] == 8]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 199475     561904     22075  2011      8    1     8
# 199476     561904    85049E  2011      8    1     8
# 199477     561905     21385  2011      8    1     9
# 199478     561905    84970L  2011      8    1     9
# 199479     561905    84970S  2011      8    1     9
# ...           ...       ...   ...    ...  ...   ...
# 226483     565067     22644  2011      8    3    17
# 226484     565067     22645  2011      8    3    17
# 226485     565067     22637  2011      8    3    17
# 226486     565067     22646  2011      8    3    17
# 226487     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# 199476            scandinavian reds ribbons       156  2011-08-01 08:30:00
# 199477      ivory hanging decoration  heart        24  2011-08-01 09:31:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
df3[df3.month == 8].Country.value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
df3.groupby('Country').amount_spent.mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
df3.head(2)
# Out:
#    InvoiceNo StockCode  year  month  day  hour  \
# 0     536365    85123A  2010     12    3     8
# 1     536365     71053  2010     12    3     8
#
#                           Description  Quantity          InvoiceDate  \
# 0  white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                 white metal lantern         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34

# %%
df3[df3['UnitPrice'] == df3['UnitPrice'].max()]
# Out:
#         InvoiceNo StockCode  year  month  day  hour Description  Quantity  \
# 118352     551697      POST  2011      5    2    13     postage         1
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
df3.groupby('year').amount_spent.mean()
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
