# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %%
z
# Out:
# array([   0,    1,    4,    9,   16,   25,   36,   49,   64,   81,  100,
#         121,  144,  169,  196,  225,  256,  289,  324,  361,  400,  441,
#         484,  529,  576,  625,  676,  729,  784,  841,  900,  961, 1024,
#        1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849,
#        1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916,
#        3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225,
#        4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776,
#        5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569,
#        7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604,
#        9801])

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x,y)
plt.xlabel('Test')
plt.grid()
plt.show()
plt.plot(x,z, 'go--', label='banana')
plt.xlabel('Logarithmic increase')
plt.ylabel('Value')
plt.title('Trial')
plt.legend()
plt.xticks(rotation=40)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=x,y=z)
# Out:
# <AxesSubplot:>

# %%
plt.plot(x,z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, axes=plt.subplots(1,2)
axes[0].plot(x,y)
axes[1].plot(x,z)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, axes=plt.subplots(1,2, figsize=(12,6))
axes[0].plot(x,y)
axes[1].plot(x,z)

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
fig, axes=plt.subplots(1,2, figsize=(12,6))
axes[0].set_yscale('linear')
axes[0].set_title('boo')
axes[0].plot(x,y)
axes[1].set_yscale('log')
axes[1].plot(x,z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-dd216d4b4916> in <module>
#       2 axes[0].set_yscale('linear')
#       3 axes[0].set_title('boo')
# ----> 4 axes[0].plot(x,y)
#       5 axes[1].set_yscale('log')
#       6 axes[1].plot(x,z)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# ...

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
plt.plot(x,y, label='Blue')
plt.plot(x,z, label='greeney')
plt.legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv(r'/Users/teahupoo20/Documents/GitHub/data-ft-par-labs/Labs/data/Fitbit2.csv')

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %%
fitbit[['Months_encoded','Work_or_Weekend','Days_encoded','Steps']]
# Out:
#      Months_encoded  Work_or_Weekend  Days_encoded  Steps
# 0                 5                1           4.0    905
# 1                 5                0           5.0  18925
# 2                 5                0           6.0  14228
# 3                 5                1           0.0   6756
# 4                 5                1           1.0    502
# ..              ...              ...           ...    ...
# 362               5                1           1.0  18588
# 363               5                1           2.0  16382
# 364               5                1           3.0  21913
# 365               5                1           4.0  19023
# 366               5                0           5.0   9526
#
# [367 rows x 4 columns]

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
#average number of steps per month
fig=plt.figure()
plt.figure(figsize=(12,4))
x=fitbit.groupby('Months').Steps.agg('mean')
plt.plot(x)
plt.show()

# %%
#median number of steps per month
x=fitbit.groupby('Months').Steps.agg('median')
plt.plot(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-9d99ce9ae3d2> in <module>
#       2 x=fitbit.groupby('Months').Steps.agg('median')
#       3 plt.plot(x)
# ----> 4 plt.sca(20)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in sca(ax)
#     980     Set the current Axes to *ax* and the current Figure to the parent of *ax*.
#     981     """
# --> 982     if not hasattr(ax.figure.canvas, "manager"):
#     983         raise ValueError("Axes parent figure is not managed by pyplot")
#     984     _pylab_helpers.Gcf.set_active(ax.figure.canvas.manager)
#
# AttributeError: 'int' object has no attribute 'figure'

# %%
#more active work day or weekend?
x=fitbit.groupby('Work_or_Weekend').Steps.agg('mean')
plt.xticks(x)
# Out:
# ([<matplotlib.axis.XTick at 0x7ffc91d25220>,
# ...
#  [Text(0, 0, ''), Text(0, 0, '')])

# %%
x=fitbit.groupby('Months').Steps.agg('mean')
plt.plot(x, label='Average steps per month')
x=fitbit.groupby('Months').Steps.agg('median')
plt.plot(x, label='Median steps per month')
plt.scatter(x)
x=fitbit.groupby('Work_or_Weekend').Steps.agg('mean')
plt.plot(x, label='Average steps work or WE')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-fa1aa800be8d> in <module>
#       3 x=fitbit.groupby('Months').Steps.agg('median')
#       4 plt.plot(x, label='Median steps per month')
# ----> 5 plt.scatter(x)
#       6 x=fitbit.groupby('Work_or_Weekend').Steps.agg('mean')
#       7 plt.plot(x, label='Average steps work or WE')
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
plt.plot(x)

# %%
# MEDIAN STEPS BY MONTH_ENCODED



# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %%
f1=fitbit.groupby('Date')[['Minutes Lightly Active', 'Steps']].mean()
f2=fitbit.groupby('Date')[['Minutes Very Active', 'Steps']].mean()
f3=fitbit.groupby('Date')[['Minutes Sedentary', 'Steps']].mean()

# %%
fig, axes=plt.subplots(1,3, figsize=(12,6), sharey=True)
for ix, value in enumerate(['Minutes Lightly Active','Minutes Very Active','Steps']):
    sns.

# %%
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        367 non-null    object
#  1   Calorie burned              367 non-null    int64
#  2   Steps                       367 non-null    int64
#  3   Distance                    367 non-null    float64
#  4   Floors                      367 non-null    int64
#  5   Minutes Sedentary           367 non-null    float64
#  6   Minutes Lightly Active      367 non-null    int64
#  7   Minutes Fairly Active       367 non-null    int64
#  8   Minutes Very Active         367 non-null    int64
#  9   Activity Calories           367 non-null    int64
#  10  MinutesOfSleep              367 non-null    int64
#  11  MinutesOfBeingAwake         367 non-null    int64
#  12  NumberOfAwakings            367 non-null    int64
# ...

# %%
plt.xticks(range(13), ['','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
# Out:
# ([<matplotlib.axis.XTick at 0x7ffca4767af0>,
# ...
#  [Text(0, 0, ''),
#   Text(1, 0, 'Jan'),
#   Text(2, 0, 'Feb'),
#   Text(3, 0, 'Mar'),
#   Text(4, 0, 'Apr'),
#   Text(5, 0, 'May'),
#   Text(6, 0, 'Jun'),
#   Text(7, 0, 'Jul'),
#   Text(8, 0, 'Aug'),
#   Text(9, 0, 'Sep'),
#   Text(10, 0, 'Oct'),
#   Text(11, 0, 'Nov'),
#   Text(12, 0, 'Dec')])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

# %%
# CATEGORICAL VARIABLES
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
