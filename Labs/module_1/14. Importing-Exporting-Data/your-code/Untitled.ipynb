# %%
import os
import pandas as pd

os.getcwd() 
os.chdir('C:\\Users\\Quoc\\Desktop\\ironhack\\github\\data-ft-par-labs\\Labs\\module_1\\14. Importing-Exporting-Data\\data\\')

path = 'C:\\Users\\Quoc\\Desktop\\ironhack\\github\\data-ft-par-labs\\Labs\\module_1\\14. Importing-Exporting-Data\\data\\'
os.listdir()
# Out:
# ['astronauts.xls', 'nasa.json']

# %%
df = pd.read_json('nasa.json')
df
# Out:
#      :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4  fall  \
# 0                            NaN                          NaN  Fell
# 1                            NaN                          NaN  Fell
# 2                            NaN                          NaN  Fell
# 3                            NaN                          NaN  Fell
# 4                            NaN                          NaN  Fell
# ..                           ...                          ...   ...
# 995                          NaN                          NaN  Fell
# 996                          NaN                          NaN  Fell
# 997                          NaN                          NaN  Fell
# 998                          NaN                          NaN  Fell
# 999                          NaN                          NaN  Fell
#
#                                            geolocation     id      mass  \
# 0    {'type': 'Point', 'coordinates': [6.08333, 50....      1      21.0
# ...

# %%
df.head()
# Out:
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4  fall  \
# 0                          NaN                          NaN  Fell
# 1                          NaN                          NaN  Fell
# 2                          NaN                          NaN  Fell
# 3                          NaN                          NaN  Fell
# 4                          NaN                          NaN  Fell
#
#                                          geolocation   id      mass      name  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....    1      21.0    Aachen
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...    2     720.0    Aarhus
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...    6  107000.0      Abee
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...   10    1914.0  Acapulco
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....  370     780.0   Achiras
#
#   nametype     recclass    reclat    reclong                     year
# ...

# %%
df["fall"].value_counts()
# Out:
# Fell     996
# Found      4
# Name: fall, dtype: int64

# %%
engine=create_engine(f"mysql+pymysql://{username}:{password}@{Hostname}/nasa-output.json")  #remove {} finace because its a text, not file
