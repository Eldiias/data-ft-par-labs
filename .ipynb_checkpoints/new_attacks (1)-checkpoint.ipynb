# %%
"""
read a Sharks DB,
drop weird columns,
rename columns,
drop rows with all missing,
sort by some column
reindex
"""


import os
import pandas as pd
df= pd.read_csv('attacks.csv',encoding='ISO-8859-1')


df.drop(columns=['href formula', 'href', 'Unnamed: 22', 'Unnamed: 23', "Case Number.1", "Case Number.2", 'pdf', 'original order'], axis=1, inplace = True)

df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df.dropna(inplace = True)
df
# Out:
#        Case Number         Date    Year        Type    Country          Area  \
# 0       2018.06.25  25-Jun-2018  2018.0     Boating        USA    California
# 6     2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL    Pernambuco
# 8     2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA       Florida
# 10      2018.05.24  24-May-2018  2018.0    Provoked  AUSTRALIA    Queensland
# 13    2018.05.13.a  13-May-2018  2018.0     Invalid    ENGLAND      Cornwall
# ...            ...          ...     ...         ...        ...           ...
# 5814    1880.11.25  25-Nov-1880  1880.0  Unprovoked  AUSTRALIA    Queensland
# 5922    1868.05.13  13-May-1868  1868.0  Unprovoked      INDIA  Hoogly River
# 6242       ND.0064        1960s     0.0  Unprovoked       IRAQ        Basrah
# 6243       ND.0063        1960s     0.0  Unprovoked       IRAQ        Basrah
# 6265       ND.0038    1941-1942     0.0  Unprovoked       IRAQ        Basrah
#
# ...

# %%
df.sort_values(by='Area', ascending=False, inplace = True)
df
# Out:
#        Case Number         Date    Year        Type           Country  \
# 607   2013.10.26.b  26-Oct-2013  2013.0  Unprovoked           REUNION
# 447     2015.02.14  14-Feb-2015  2015.0  Unprovoked           REUNION
# 3739    1963.09.22  22-Sep-1963  1963.0  Unprovoked   SOLOMON ISLANDS
# 5224    1922.05.24  24-May 1922  1922.0  Unprovoked           JAMAICA
# 1051    2010.01.12  12-Jan-2010  2010.0  Unprovoked      SOUTH AFRICA
# ...            ...          ...     ...         ...               ...
# 3850  1962.01.11.b  11-Jan-1962  1962.0  Unprovoked  PAPUA NEW GUINEA
# 1199    2008.10.06  06-Oct-2008  2008.0  Unprovoked           CROATIA
# 943     2011.02.23  23-Feb-2011  2011.0  Unprovoked     NEW CALEDONIA
# 3728    1963.11.28  28-Nov-1963  1963.0  Unprovoked              FIJI
# 4463    1950.08.06  06-Aug-1950  1950.0    Provoked       EL SALVADOR
#
#                         Area                       Location  \
# 607             dÉtang-Salé                    Ravine Mula
# ...

# %%
ix=pd.Index(list('Date'), name='Reindex Date')

ix.name
# Out:
# 'Reindex Date'

# %%
df
# Out:
#        Case Number         Date    Year        Type           Country  \
# 607   2013.10.26.b  26-Oct-2013  2013.0  Unprovoked           REUNION
# 447     2015.02.14  14-Feb-2015  2015.0  Unprovoked           REUNION
# 3739    1963.09.22  22-Sep-1963  1963.0  Unprovoked   SOLOMON ISLANDS
# 5224    1922.05.24  24-May 1922  1922.0  Unprovoked           JAMAICA
# 1051    2010.01.12  12-Jan-2010  2010.0  Unprovoked      SOUTH AFRICA
# ...            ...          ...     ...         ...               ...
# 3850  1962.01.11.b  11-Jan-1962  1962.0  Unprovoked  PAPUA NEW GUINEA
# 1199    2008.10.06  06-Oct-2008  2008.0  Unprovoked           CROATIA
# 943     2011.02.23  23-Feb-2011  2011.0  Unprovoked     NEW CALEDONIA
# 3728    1963.11.28  28-Nov-1963  1963.0  Unprovoked              FIJI
# 4463    1950.08.06  06-Aug-1950  1950.0    Provoked       EL SALVADOR
#
#                         Area                       Location  \
# 607             dÉtang-Salé                    Ravine Mula
# ...

# %%
df.reset_index()
# Out:
#       index   Case Number         Date    Year        Type           Country  \
# 0       607  2013.10.26.b  26-Oct-2013  2013.0  Unprovoked           REUNION
# 1       447    2015.02.14  14-Feb-2015  2015.0  Unprovoked           REUNION
# 2      3739    1963.09.22  22-Sep-1963  1963.0  Unprovoked   SOLOMON ISLANDS
# 3      5224    1922.05.24  24-May 1922  1922.0  Unprovoked           JAMAICA
# 4      1051    2010.01.12  12-Jan-2010  2010.0  Unprovoked      SOUTH AFRICA
# ...     ...           ...          ...     ...         ...               ...
# 1417   3850  1962.01.11.b  11-Jan-1962  1962.0  Unprovoked  PAPUA NEW GUINEA
# 1418   1199    2008.10.06  06-Oct-2008  2008.0  Unprovoked           CROATIA
# 1419    943    2011.02.23  23-Feb-2011  2011.0  Unprovoked     NEW CALEDONIA
# 1420   3728    1963.11.28  28-Nov-1963  1963.0  Unprovoked              FIJI
# 1421   4463    1950.08.06  06-Aug-1950  1950.0    Provoked       EL SALVADOR
#
# ...

# %%
df.to_csv('new_attacks.csv', encoding='utf-8')
