# %%
import os
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
os.chdir('C:\\Users\\mcoge\\Downloads')

# %%
france = gpd.read_file('departements.geojson')
france.head()
# Out:
#   code           nom                                           geometry
# 0   02         Aisne  POLYGON ((3.17270 50.01200, 3.18220 50.01234, ...
# 1   10          Aube  POLYGON ((3.41479 48.39027, 3.42208 48.41334, ...
# 2   14      Calvados  POLYGON ((-1.11962 49.35557, -1.11503 49.36240...
# 3   15        Cantal  POLYGON ((2.50841 45.47850, 2.52444 45.48070, ...
# 4   28  Eure-et-Loir  POLYGON ((0.81482 48.67016, 0.82767 48.68072, ...

# %%
france.plot(figsize=(15, 15))
# Out:
# <AxesSubplot:>

# %%
regions = gpd.read_file('regions.geojson')

# %%
regions
# Out:
#    code                         nom  \
# 0    11               Île-de-France
# 1    24         Centre-Val de Loire
# 2    27     Bourgogne-Franche-Comté
# 3    28                   Normandie
# 4    32             Hauts-de-France
# 5    44                   Grand Est
# 6    52            Pays de la Loire
# 7    53                    Bretagne
# 8    75          Nouvelle-Aquitaine
# 9    01                  Guadeloupe
# 10   02                  Martinique
# 11   03                      Guyane
# 12   04                  La Réunion
# 13   06                     Mayotte
# 14   76                   Occitanie
# 15   84        Auvergne-Rhône-Alpes
# 16   93  Provence-Alpes-Côte d'Azur
# 17   94                       Corse
#
#                                              geometry
# 0   POLYGON ((1.92215 48.45760, 1.92074 48.44775, ...
# 1   POLYGON ((0.81482 48.67016, 0.82767 48.68072, ...
# 2   POLYGON ((6.94054 47.43337, 6.94168 47.41580, ...
# 3   POLYGON ((-1.11962 49.35557, -1.11503 49.36240...
# 4   POLYGON ((4.14089 49.97876, 4.15398 49.97484, ...
# 5   POLYGON ((3.41479 48.39027, 3.42208 48.41334, ...
# 6   MULTIPOLYGON (((-2.30479 46.70942, -2.28612 46...
# 7   MULTIPOLYGON (((-2.12371 48.60441, -2.13448 48...
# 8   MULTIPOLYGON (((-1.02574 45.57469, -0.99300 45...
# 9   MULTIPOLYGON (((-61.63356 15.83977, -61.64798 ...
# 10  POLYGON ((-61.20405 14.86191, -61.19794 14.863...
# 11  MULTIPOLYGON (((-53.87043 5.74491, -53.87789 5...
# 12  POLYGON ((55.25415 -21.10974, 55.23094 -21.090...
# 13  MULTIPOLYGON (((45.04101 -12.64686, 45.03392 -...
# 14  MULTIPOLYGON (((1.78613 42.57362, 1.78094 42.5...
# 15  POLYGON ((3.36135 44.97141, 3.35453 44.95482, ...
# 16  MULTIPOLYGON (((6.94833 44.65482, 6.95451 44.6...
# 17  MULTIPOLYGON (((9.27103 41.36496, 9.26570 41.3...

# %%
regions.plot(figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
regions = regions[(regions.nom!="Mayotte")]
regions = regions[(regions.nom!="Guadeloupe")]
regions = regions[(regions.nom!="Martinique")]
regions = regions[(regions.nom!="La Réunion")]
regions = regions[(regions.nom!="Guyane")]

# %%
regions
# Out:
#    code                         nom  \
# 0    11               Île-de-France
# 1    24         Centre-Val de Loire
# 2    27     Bourgogne-Franche-Comté
# 3    28                   Normandie
# 4    32             Hauts-de-France
# 5    44                   Grand Est
# 6    52            Pays de la Loire
# 7    53                    Bretagne
# 8    75          Nouvelle-Aquitaine
# 14   76                   Occitanie
# 15   84        Auvergne-Rhône-Alpes
# 16   93  Provence-Alpes-Côte d'Azur
# 17   94                       Corse
#
#                                              geometry
# 0   POLYGON ((1.92215 48.45760, 1.92074 48.44775, ...
# 1   POLYGON ((0.81482 48.67016, 0.82767 48.68072, ...
# 2   POLYGON ((6.94054 47.43337, 6.94168 47.41580, ...
# 3   POLYGON ((-1.11962 49.35557, -1.11503 49.36240...
# 4   POLYGON ((4.14089 49.97876, 4.15398 49.97484, ...
# 5   POLYGON ((3.41479 48.39027, 3.42208 48.41334, ...
# 6   MULTIPOLYGON (((-2.30479 46.70942, -2.28612 46...
# 7   MULTIPOLYGON (((-2.12371 48.60441, -2.13448 48...
# 8   MULTIPOLYGON (((-1.02574 45.57469, -0.99300 45...
# 14  MULTIPOLYGON (((1.78613 42.57362, 1.78094 42.5...
# 15  POLYGON ((3.36135 44.97141, 3.35453 44.95482, ...
# 16  MULTIPOLYGON (((6.94833 44.65482, 6.95451 44.6...
# 17  MULTIPOLYGON (((9.27103 41.36496, 9.26570 41.3...

# %%
regions.plot(figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
usa=gpd.read_file('gz_2010_us_040_00_500k.json')
usa.plot()
plt.savefig("test.jpg",dpi=300)

# %%
usa = usa[(usa.NAME!="Alaska")]
usa = usa[(usa.NAME!="Hawaii")]
usa = usa[(usa.NAME!="Puerto Rico")]

# %%
usa.plot(figsize=(30,30))
# Out:
# <AxesSubplot:>

# %%
regions = gpd.read_file('regions.geojson')

# %%
regions.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
# !pip install GDAL
# !pip install Fiona
# !pip install geopandas
# !pip install proj
# !pip install Shapely
# !pip install Cartopy
# !pip install rasterio
# !pip install contextily
# Out:
# Requirement already satisfied: GDAL in c:\programdata\anaconda3\lib\site-packages (3.1.4)
# Requirement already satisfied: Fiona in c:\programdata\anaconda3\lib\site-packages (1.8.18)
# Requirement already satisfied: attrs>=17 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (19.3.0)
# Requirement already satisfied: cligj>=0.5 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (0.7.1)
# Requirement already satisfied: click<8,>=4.0 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (7.1.2)
# Requirement already satisfied: six>=1.7 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (1.15.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (1.1.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from Fiona) (2020.6.20)
# Requirement already satisfied: gdal~=3.1.2 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (3.1.4)
# Requirement already satisfied: munch in c:\programdata\anaconda3\lib\site-packages (from Fiona) (2.5.0)
# Requirement already satisfied: geopandas in c:\programdata\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: shapely in c:\programdata\anaconda3\lib\site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pandas>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (1.0.5)
# Requirement already satisfied: pyproj>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (3.0.0.post1)
# Requirement already satisfied: fiona in c:\programdata\anaconda3\lib\site-packages (from geopandas) (1.8.18)
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (1.18.5)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from pyproj>=2.2.0->geopandas) (2020.6.20)
# Requirement already satisfied: cligj>=0.5 in c:\programdata\anaconda3\lib\site-packages (from fiona->geopandas) (0.7.1)
# Requirement already satisfied: click-plugins>=1.0 in c:\programdata\anaconda3\lib\site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: munch in c:\programdata\anaconda3\lib\site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: attrs>=17 in c:\programdata\anaconda3\lib\site-packages (from fiona->geopandas) (19.3.0)
# Requirement already satisfied: six>=1.7 in c:\programdata\anaconda3\lib\site-packages (from fiona->geopandas) (1.15.0)
# Requirement already satisfied: click<8,>=4.0 in c:\programdata\anaconda3\lib\site-packages (from fiona->geopandas) (7.1.2)
# Requirement already satisfied: gdal~=3.1.2 in c:\programdata\anaconda3\lib\site-packages (from fiona->geopandas) (3.1.4)
# Requirement already satisfied: proj in c:\programdata\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: click>=7.1.2 in c:\programdata\anaconda3\lib\site-packages (from proj) (7.1.2)
# Requirement already satisfied: arrow>=0.15.6 in c:\programdata\anaconda3\lib\site-packages (from proj) (0.17.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\programdata\anaconda3\lib\site-packages (from arrow>=0.15.6->proj) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->arrow>=0.15.6->proj) (1.15.0)
# Requirement already satisfied: Shapely in c:\programdata\anaconda3\lib\site-packages (1.7.1)
# Collecting Cartopy
#   Using cached Cartopy-0.18.0.tar.gz (14.4 MB)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\ProgramData\Anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mcoge\\AppData\\Local\\Temp\\pip-install-atv8g7_j\\Cartopy\\setup.py'"'"'; __file__='"'"'C:\\Users\\mcoge\\AppData\\Local\\Temp\\pip-install-atv8g7_j\\Cartopy\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\mcoge\AppData\Local\Temp\pip-pip-egg-info-_491kqs1'
#          cwd: C:\Users\mcoge\AppData\Local\Temp\pip-install-atv8g7_j\Cartopy\
#     Complete output (5 lines):
#     C:\Users\mcoge\AppData\Local\Temp\pip-install-atv8g7_j\Cartopy\setup.py:104: UserWarning: Unable to determine GEOS version. Ensure you have 3.3.3 or later installed, or installation may fail.
#       warnings.warn(
#     C:\Users\mcoge\AppData\Local\Temp\pip-install-atv8g7_j\Cartopy\setup.py:157: UserWarning: Unable to determine Proj version. Ensure you have 4.9.0 or later installed, or installation may fail.
#       warnings.warn(
#     Proj version 0.0.0 is installed, but cartopy requires at least version 4.9.0.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting rasterio
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\ProgramData\Anaconda3\python.exe' 'C:\ProgramData\Anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' get_requires_for_build_wheel 'C:\Users\mcoge\AppData\Local\Temp\tmpq51y0qiq'
#        cwd: C:\Users\mcoge\AppData\Local\Temp\pip-install-hm594bov\rasterio
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\ProgramData\Anaconda3\python.exe' 'C:\ProgramData\Anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' get_requires_for_build_wheel 'C:\Users\mcoge\AppData\Local\Temp\tmpq51y0qiq' Check the logs for full command output.
#   Using cached rasterio-1.2.0.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Collecting contextily
#   Using cached contextily-1.0.1-py3-none-any.whl (23 kB)
# Collecting mercantile
#   Using cached mercantile-1.1.6-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from contextily) (2.24.0)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from contextily) (7.2.0)
# Collecting rasterio
#   Using cached rasterio-1.2.0.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\ProgramData\Anaconda3\python.exe' 'C:\ProgramData\Anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' get_requires_for_build_wheel 'C:\Users\mcoge\AppData\Local\Temp\tmpi2x7bote'
#        cwd: C:\Users\mcoge\AppData\Local\Temp\pip-install-p_9qicxt\rasterio
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\ProgramData\Anaconda3\python.exe' 'C:\ProgramData\Anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' get_requires_for_build_wheel 'C:\Users\mcoge\AppData\Local\Temp\tmpi2x7bote' Check the logs for full command output.

# %%
# !pip install GDAL --user
# Out:
# Collecting GDAL
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\ProgramData\Anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mcoge\\AppData\\Local\\Temp\\pip-install-fp09tir9\\GDAL\\setup.py'"'"'; __file__='"'"'C:\\Users\\mcoge\\AppData\\Local\\Temp\\pip-install-fp09tir9\\GDAL\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\mcoge\AppData\Local\Temp\pip-wheel-kyab691a'
#        cwd: C:\Users\mcoge\AppData\Local\Temp\pip-install-fp09tir9\GDAL\
#   Complete output (54 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\osgeo
#   copying osgeo\gdal.py -> build\lib.win-amd64-3.8\osgeo
#   copying osgeo\gdalconst.py -> build\lib.win-amd64-3.8\osgeo
#   copying osgeo\gdalnumeric.py -> build\lib.win-amd64-3.8\osgeo
#   copying osgeo\gdal_array.py -> build\lib.win-amd64-3.8\osgeo
#   copying osgeo\gnm.py -> build\lib.win-amd64-3.8\osgeo
#   copying osgeo\ogr.py -> build\lib.win-amd64-3.8\osgeo
#   copying osgeo\osr.py -> build\lib.win-amd64-3.8\osgeo
#   copying osgeo\__init__.py -> build\lib.win-amd64-3.8\osgeo
#   creating build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\epsg_tr.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\esri2wkt.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gcps2vec.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gcps2wld.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal2xyz.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdalchksum.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdalcompare.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdalident.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdalimport.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdalmove.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal_auth.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal_calc.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal_edit.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal_fillnodata.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal_merge.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal_pansharpen.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal_polygonize.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal_proximity.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal_retile.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\gdal_sieve.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\mkgraticule.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\ogrmerge.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\pct2rgb.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\rgb2pct.py -> build\lib.win-amd64-3.8\osgeo\utils
#   copying osgeo\utils\__init__.py -> build\lib.win-amd64-3.8\osgeo\utils
#   C:\Users\mcoge\AppData\Roaming\Python\Python38\site-packages\setuptools\lib2to3_ex.py:36: SetuptoolsDeprecationWarning: 2to3 support is deprecated. If the project still requires Python 2 support, please migrate to a single-codebase solution or employ an independent conversion process.
#     warnings.warn(
#   Fixing build\lib.win-amd64-3.8\osgeo\gdal.py build\lib.win-amd64-3.8\osgeo\gdalconst.py build\lib.win-amd64-3.8\osgeo\gdalnumeric.py build\lib.win-amd64-3.8\osgeo\gdal_array.py build\lib.win-amd64-3.8\osgeo\gnm.py build\lib.win-amd64-3.8\osgeo\ogr.py build\lib.win-amd64-3.8\osgeo\osr.py build\lib.win-amd64-3.8\osgeo\__init__.py build\lib.win-amd64-3.8\osgeo\utils\epsg_tr.py build\lib.win-amd64-3.8\osgeo\utils\esri2wkt.py build\lib.win-amd64-3.8\osgeo\utils\gcps2vec.py build\lib.win-amd64-3.8\osgeo\utils\gcps2wld.py build\lib.win-amd64-3.8\osgeo\utils\gdal2xyz.py build\lib.win-amd64-3.8\osgeo\utils\gdalchksum.py build\lib.win-amd64-3.8\osgeo\utils\gdalcompare.py build\lib.win-amd64-3.8\osgeo\utils\gdalident.py build\lib.win-amd64-3.8\osgeo\utils\gdalimport.py build\lib.win-amd64-3.8\osgeo\utils\gdalmove.py build\lib.win-amd64-3.8\osgeo\utils\gdal_auth.py build\lib.win-amd64-3.8\osgeo\utils\gdal_calc.py build\lib.win-amd64-3.8\osgeo\utils\gdal_edit.py build\lib.win-amd64-3.8\osgeo\utils\gdal_fillnodata.py build\lib.win-amd64-3.8\osgeo\utils\gdal_merge.py build\lib.win-amd64-3.8\osgeo\utils\gdal_pansharpen.py build\lib.win-amd64-3.8\osgeo\utils\gdal_polygonize.py build\lib.win-amd64-3.8\osgeo\utils\gdal_proximity.py build\lib.win-amd64-3.8\osgeo\utils\gdal_retile.py build\lib.win-amd64-3.8\osgeo\utils\gdal_sieve.py build\lib.win-amd64-3.8\osgeo\utils\mkgraticule.py build\lib.win-amd64-3.8\osgeo\utils\ogrmerge.py build\lib.win-amd64-3.8\osgeo\utils\pct2rgb.py build\lib.win-amd64-3.8\osgeo\utils\rgb2pct.py build\lib.win-amd64-3.8\osgeo\utils\__init__.py
#   Skipping optional fixer: ws_comma
#   Fixing build\lib.win-amd64-3.8\osgeo\gdal.py build\lib.win-amd64-3.8\osgeo\gdalconst.py build\lib.win-amd64-3.8\osgeo\gdalnumeric.py build\lib.win-amd64-3.8\osgeo\gdal_array.py build\lib.win-amd64-3.8\osgeo\gnm.py build\lib.win-amd64-3.8\osgeo\ogr.py build\lib.win-amd64-3.8\osgeo\osr.py build\lib.win-amd64-3.8\osgeo\__init__.py build\lib.win-amd64-3.8\osgeo\utils\epsg_tr.py build\lib.win-amd64-3.8\osgeo\utils\esri2wkt.py build\lib.win-amd64-3.8\osgeo\utils\gcps2vec.py build\lib.win-amd64-3.8\osgeo\utils\gcps2wld.py build\lib.win-amd64-3.8\osgeo\utils\gdal2xyz.py build\lib.win-amd64-3.8\osgeo\utils\gdalchksum.py build\lib.win-amd64-3.8\osgeo\utils\gdalcompare.py build\lib.win-amd64-3.8\osgeo\utils\gdalident.py build\lib.win-amd64-3.8\osgeo\utils\gdalimport.py build\lib.win-amd64-3.8\osgeo\utils\gdalmove.py build\lib.win-amd64-3.8\osgeo\utils\gdal_auth.py build\lib.win-amd64-3.8\osgeo\utils\gdal_calc.py build\lib.win-amd64-3.8\osgeo\utils\gdal_edit.py build\lib.win-amd64-3.8\osgeo\utils\gdal_fillnodata.py build\lib.win-amd64-3.8\osgeo\utils\gdal_merge.py build\lib.win-amd64-3.8\osgeo\utils\gdal_pansharpen.py build\lib.win-amd64-3.8\osgeo\utils\gdal_polygonize.py build\lib.win-amd64-3.8\osgeo\utils\gdal_proximity.py build\lib.win-amd64-3.8\osgeo\utils\gdal_retile.py build\lib.win-amd64-3.8\osgeo\utils\gdal_sieve.py build\lib.win-amd64-3.8\osgeo\utils\mkgraticule.py build\lib.win-amd64-3.8\osgeo\utils\ogrmerge.py build\lib.win-amd64-3.8\osgeo\utils\pct2rgb.py build\lib.win-amd64-3.8\osgeo\utils\rgb2pct.py build\lib.win-amd64-3.8\osgeo\utils\__init__.py
#   Skipping optional fixer: ws_comma
#   running build_ext
#   building 'osgeo._gdal' extension
#   Using cached GDAL-3.2.1.tar.gz (604 kB)
# Building wheels for collected packages: GDAL
#   Building wheel for GDAL (setup.py): started
#   Building wheel for GDAL (setup.py): finished with status 'error'
#   Running setup.py clean for GDAL
# Failed to build GDAL
# Installing collected packages: GDAL
#     Running setup.py install for GDAL: started
#     Running setup.py install for GDAL: finished with status 'error'
#   building 'osgeo._gdalconst' extension
#   building 'osgeo._osr' extension
#   building 'osgeo._ogr' extension
#   building 'osgeo._gdal_array' extension
#   building 'osgeo._gnm' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for GDAL
# ERROR: fiona 1.8.18 has requirement gdal~=3.1.2, but you'll have gdal 3.2.1 which is incompatible.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\ProgramData\Anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mcoge\\AppData\\Local\\Temp\\pip-install-fp09tir9\\GDAL\\setup.py'"'"'; __file__='"'"'C:\\Users\\mcoge\\AppData\\Local\\Temp\\pip-install-fp09tir9\\GDAL\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\mcoge\AppData\Local\Temp\pip-record-c0fu90uj\install-record.txt' --single-version-externally-managed --user --prefix= --compile --install-headers 'C:\Users\mcoge\AppData\Roaming\Python\Python38\Include\GDAL'
#          cwd: C:\Users\mcoge\AppData\Local\Temp\pip-install-fp09tir9\GDAL\
#     Complete output (54 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.8
#     creating build\lib.win-amd64-3.8\osgeo
#     copying osgeo\gdal.py -> build\lib.win-amd64-3.8\osgeo
#     copying osgeo\gdalconst.py -> build\lib.win-amd64-3.8\osgeo
#     copying osgeo\gdalnumeric.py -> build\lib.win-amd64-3.8\osgeo
#     copying osgeo\gdal_array.py -> build\lib.win-amd64-3.8\osgeo
#     copying osgeo\gnm.py -> build\lib.win-amd64-3.8\osgeo
#     copying osgeo\ogr.py -> build\lib.win-amd64-3.8\osgeo
#     copying osgeo\osr.py -> build\lib.win-amd64-3.8\osgeo
#     copying osgeo\__init__.py -> build\lib.win-amd64-3.8\osgeo
#     creating build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\epsg_tr.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\esri2wkt.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gcps2vec.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gcps2wld.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal2xyz.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdalchksum.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdalcompare.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdalident.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdalimport.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdalmove.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal_auth.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal_calc.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal_edit.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal_fillnodata.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal_merge.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal_pansharpen.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal_polygonize.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal_proximity.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal_retile.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\gdal_sieve.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\mkgraticule.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\ogrmerge.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\pct2rgb.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\rgb2pct.py -> build\lib.win-amd64-3.8\osgeo\utils
#     copying osgeo\utils\__init__.py -> build\lib.win-amd64-3.8\osgeo\utils
#     C:\Users\mcoge\AppData\Roaming\Python\Python38\site-packages\setuptools\lib2to3_ex.py:36: SetuptoolsDeprecationWarning: 2to3 support is deprecated. If the project still requires Python 2 support, please migrate to a single-codebase solution or employ an independent conversion process.
#       warnings.warn(
#     Fixing build\lib.win-amd64-3.8\osgeo\gdal.py build\lib.win-amd64-3.8\osgeo\gdalconst.py build\lib.win-amd64-3.8\osgeo\gdalnumeric.py build\lib.win-amd64-3.8\osgeo\gdal_array.py build\lib.win-amd64-3.8\osgeo\gnm.py build\lib.win-amd64-3.8\osgeo\ogr.py build\lib.win-amd64-3.8\osgeo\osr.py build\lib.win-amd64-3.8\osgeo\__init__.py build\lib.win-amd64-3.8\osgeo\utils\epsg_tr.py build\lib.win-amd64-3.8\osgeo\utils\esri2wkt.py build\lib.win-amd64-3.8\osgeo\utils\gcps2vec.py build\lib.win-amd64-3.8\osgeo\utils\gcps2wld.py build\lib.win-amd64-3.8\osgeo\utils\gdal2xyz.py build\lib.win-amd64-3.8\osgeo\utils\gdalchksum.py build\lib.win-amd64-3.8\osgeo\utils\gdalcompare.py build\lib.win-amd64-3.8\osgeo\utils\gdalident.py build\lib.win-amd64-3.8\osgeo\utils\gdalimport.py build\lib.win-amd64-3.8\osgeo\utils\gdalmove.py build\lib.win-amd64-3.8\osgeo\utils\gdal_auth.py build\lib.win-amd64-3.8\osgeo\utils\gdal_calc.py build\lib.win-amd64-3.8\osgeo\utils\gdal_edit.py build\lib.win-amd64-3.8\osgeo\utils\gdal_fillnodata.py build\lib.win-amd64-3.8\osgeo\utils\gdal_merge.py build\lib.win-amd64-3.8\osgeo\utils\gdal_pansharpen.py build\lib.win-amd64-3.8\osgeo\utils\gdal_polygonize.py build\lib.win-amd64-3.8\osgeo\utils\gdal_proximity.py build\lib.win-amd64-3.8\osgeo\utils\gdal_retile.py build\lib.win-amd64-3.8\osgeo\utils\gdal_sieve.py build\lib.win-amd64-3.8\osgeo\utils\mkgraticule.py build\lib.win-amd64-3.8\osgeo\utils\ogrmerge.py build\lib.win-amd64-3.8\osgeo\utils\pct2rgb.py build\lib.win-amd64-3.8\osgeo\utils\rgb2pct.py build\lib.win-amd64-3.8\osgeo\utils\__init__.py
#     Skipping optional fixer: ws_comma
#     Fixing build\lib.win-amd64-3.8\osgeo\gdal.py build\lib.win-amd64-3.8\osgeo\gdalconst.py build\lib.win-amd64-3.8\osgeo\gdalnumeric.py build\lib.win-amd64-3.8\osgeo\gdal_array.py build\lib.win-amd64-3.8\osgeo\gnm.py build\lib.win-amd64-3.8\osgeo\ogr.py build\lib.win-amd64-3.8\osgeo\osr.py build\lib.win-amd64-3.8\osgeo\__init__.py build\lib.win-amd64-3.8\osgeo\utils\epsg_tr.py build\lib.win-amd64-3.8\osgeo\utils\esri2wkt.py build\lib.win-amd64-3.8\osgeo\utils\gcps2vec.py build\lib.win-amd64-3.8\osgeo\utils\gcps2wld.py build\lib.win-amd64-3.8\osgeo\utils\gdal2xyz.py build\lib.win-amd64-3.8\osgeo\utils\gdalchksum.py build\lib.win-amd64-3.8\osgeo\utils\gdalcompare.py build\lib.win-amd64-3.8\osgeo\utils\gdalident.py build\lib.win-amd64-3.8\osgeo\utils\gdalimport.py build\lib.win-amd64-3.8\osgeo\utils\gdalmove.py build\lib.win-amd64-3.8\osgeo\utils\gdal_auth.py build\lib.win-amd64-3.8\osgeo\utils\gdal_calc.py build\lib.win-amd64-3.8\osgeo\utils\gdal_edit.py build\lib.win-amd64-3.8\osgeo\utils\gdal_fillnodata.py build\lib.win-amd64-3.8\osgeo\utils\gdal_merge.py build\lib.win-amd64-3.8\osgeo\utils\gdal_pansharpen.py build\lib.win-amd64-3.8\osgeo\utils\gdal_polygonize.py build\lib.win-amd64-3.8\osgeo\utils\gdal_proximity.py build\lib.win-amd64-3.8\osgeo\utils\gdal_retile.py build\lib.win-amd64-3.8\osgeo\utils\gdal_sieve.py build\lib.win-amd64-3.8\osgeo\utils\mkgraticule.py build\lib.win-amd64-3.8\osgeo\utils\ogrmerge.py build\lib.win-amd64-3.8\osgeo\utils\pct2rgb.py build\lib.win-amd64-3.8\osgeo\utils\rgb2pct.py build\lib.win-amd64-3.8\osgeo\utils\__init__.py
#     Skipping optional fixer: ws_comma
#     running build_ext
#     building 'osgeo._gdal' extension
#     building 'osgeo._gdalconst' extension
#     building 'osgeo._osr' extension
#     building 'osgeo._ogr' extension
#     building 'osgeo._gnm' extension
#     building 'osgeo._gdal_array' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\ProgramData\Anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mcoge\\AppData\\Local\\Temp\\pip-install-fp09tir9\\GDAL\\setup.py'"'"'; __file__='"'"'C:\\Users\\mcoge\\AppData\\Local\\Temp\\pip-install-fp09tir9\\GDAL\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\mcoge\AppData\Local\Temp\pip-record-c0fu90uj\install-record.txt' --single-version-externally-managed --user --prefix= --compile --install-headers 'C:\Users\mcoge\AppData\Roaming\Python\Python38\Include\GDAL' Check the logs for full command output.

# %%
--upgrade

# %%
# !pip install proj --upgrade
# Out:
# Requirement already up-to-date: proj in c:\programdata\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied, skipping upgrade: click>=7.1.2 in c:\programdata\anaconda3\lib\site-packages (from proj) (7.1.2)
# Requirement already satisfied, skipping upgrade: arrow>=0.15.6 in c:\programdata\anaconda3\lib\site-packages (from proj) (0.17.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.0 in c:\programdata\anaconda3\lib\site-packages (from arrow>=0.15.6->proj) (2.8.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->arrow>=0.15.6->proj) (1.15.0)

# %%
# !pip install Cartopy
# Out:
# Collecting Cartopy
#   Using cached Cartopy-0.18.0.tar.gz (14.4 MB)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\ProgramData\Anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mcoge\\AppData\\Local\\Temp\\pip-install-llrqlu23\\Cartopy\\setup.py'"'"'; __file__='"'"'C:\\Users\\mcoge\\AppData\\Local\\Temp\\pip-install-llrqlu23\\Cartopy\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\mcoge\AppData\Local\Temp\pip-pip-egg-info-ss5dbecn'
#          cwd: C:\Users\mcoge\AppData\Local\Temp\pip-install-llrqlu23\Cartopy\
#     Complete output (5 lines):
#     C:\Users\mcoge\AppData\Local\Temp\pip-install-llrqlu23\Cartopy\setup.py:104: UserWarning: Unable to determine GEOS version. Ensure you have 3.3.3 or later installed, or installation may fail.
#       warnings.warn(
#     C:\Users\mcoge\AppData\Local\Temp\pip-install-llrqlu23\Cartopy\setup.py:157: UserWarning: Unable to determine Proj version. Ensure you have 4.9.0 or later installed, or installation may fail.
#       warnings.warn(
#     Proj version 0.0.0 is installed, but cartopy requires at least version 4.9.0.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
import contextily as ctx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-90425f271be4> in <module>
# ----> 1 import contextily as ctx
#
# ModuleNotFoundError: No module named 'contextily'

# %%
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax)
