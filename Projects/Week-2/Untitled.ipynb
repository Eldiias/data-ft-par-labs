# %%
import pandas as pd 
import numpy as np

# %%
import os
os.chdir(r'/Users/teahupoo20/Documents/GitHub/data-ft-par-labs/Projects/Week-2')

# %%
atck=pd.read_csv('attacks.csv', engine='python')
atck
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
atck.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
atck.count()
# Out:
# Case Number               8702
# Date                      6302
# Year                      6300
# Type                      6298
# Country                   6252
# Area                      5847
# Location                  5762
# Activity                  5758
# Name                      6092
# Sex                       5737
# Age                       3471
# Injury                    6274
# Fatal (Y/N)               5763
# Time                      2948
# Species                   3464
# Investigator or Source    6285
# pdf                       6302
# href formula              6301
# href                      6302
# Case Number.1             6302
# Case Number.2             6302
# original order            6309
# Unnamed: 22                  1
# Unnamed: 23                  2
# dtype: int64

# %%
atck.isna()
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 25718         True   True   True   True     True   True      True      True
# 25719         True   True   True   True     True   True      True      True
# 25720         True   True   True   True     True   True      True      True
# 25721         True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
# ...

# %%
atck.isna().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
atcknul=atck.isnull().sum()
atcknul[atcknul>0]
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
drop_atcknul= list(atcknul[atcknul>10000].index)

# %%
null_CN = atck[(atck['Case Number'].isnull()==True) & (atck['Name'].isnull()==True)]
null_CN
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8702          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8703          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8704          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8705          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8706          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...           ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 25717         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# ...

# %%
null_CL = atck[(atck['Case Number'].isnull()==True) & (atck['Location'].isnull()==True)]
null_CL
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8702          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8703          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8704          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8705          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8706          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...           ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 25717         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# ...

# %% [markdown]
# ## We start to select and drop columns
#
# Starting with those which has all empty rows

# %%
atck.dropna(axis=0, how='all', inplace=True)
atck.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8703 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %% [markdown]
# ## We change the display to maximum 24 columns instead of 20

# %%
pd.options.display.max_columns = 24

# %% [markdown]
# ## Then we replace those having 0 as value in Case number with NaN to be harmonious

# %%
atck[atck['Case Number']=='0']
# Out:
#      Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6302           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6303           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6304           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6305           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6306           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...          ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 8697           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8698           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#       Age Injury Fatal (Y/N) Time Species  Investigator or Source  pdf  \
# ...

# %%
atck['Case Number'].replace(['NaN'], np.nan, inplace=True) # we need numpy to all nan

# %%
atck.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8698            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        Age Injury Fatal (Y/N) Time Species  Investigator or Source  pdf  \
# 8698   NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# 8699   NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# 8700   NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# 8701   NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# 25722  NaN    NaN         NaN  NaN      NaN                    NaN  NaN
#
#       href formula href Case Number.1 Case Number.2  original order  \
# ...

# %%
atck['Case Number'].value_counts()
# Out:
# 0               2400
# 1962.06.11.b       2
# 2009.12.18         2
# 2013.10.05         2
# 1907.10.16.R       2
#                 ...
# 1872.02.26         1
# 2009.10.19         1
# 1956.08.01         1
# 1942.11.00.b       1
# 1976.07.16         1
# Name: Case Number, Length: 6287, dtype: int64

# %% [markdown]
# ## We continue looking for useless columns

# %%
atck['Unnamed: 23'].value_counts()
# Out:
# Teramo             1
# change filename    1
# Name: Unnamed: 23, dtype: int64

# %% [markdown]
# ## Then we drop these columns and assign a new variable

# %%
ndf=atck.drop(columns=['Unnamed: 22', 'Unnamed: 23','Investigator or Source', 'href formula','pdf', 'href','original order'])

# %%
ndf
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
ndf.dropna(axis=0, how='all', inplace=True)

# %%
ndf
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %% [markdown]
# ## Now we have a relatively clean dataset
#
# Lets calculate the frequency of missing data on some columns like fatal, time, species

# %%
mask = ndf.T.isna().sum()>ndf.shape[1] *90/100

# %%
pm=100*(len(ndf.loc[:,ndf.isnull().sum(axis=0)>=1 ].index) / len(ndf.index))
print(round(pm,2))
# Out:
# 100.0

# %% [markdown]
# pm

# %%
percent_missing = ndf.isnull().sum() * 100 / len(ndf)
percent_missing
# Out:
# Case Number       0.011490
# Date             27.588188
# Year             27.611169
# Type             27.634149
# Country          28.162703
# Area             32.816270
# Location         33.792945
# Activity         33.838906
# Name             30.001149
# Sex              34.080202
# Age              60.117201
# Injury           27.909916
# Fatal (Y/N)      33.781455
# Time             66.126623
# Species          60.197633
# Case Number.1    27.588188
# Case Number.2    27.588188
# dtype: float64

# %% [markdown]
# ## Question : fatal injuries appear at what time?
#     Then is there a place more dangerous than other in fatal injuries?

# %%
Q1=ndf.drop(columns=['Case Number', 'Date', 'Year', 'Type', 'Area', 'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Species ', 'Case Number.1', 'Case Number.2'], axis=1)

# %%
Q1
# Out:
#          Country                                             Injury  \
# 0            USA  No injury to occupant, outrigger canoe and pad...
# 1            USA                         Minor injury to left thigh
# 2            USA       Injury to left lower leg from surfboard skeg
# 3      AUSTRALIA                          Minor injury to lower leg
# 4         MEXICO  Lacerations to leg & hand shark PROVOKED INCIDENT
# ...          ...                                                ...
# 8698         NaN                                                NaN
# 8699         NaN                                                NaN
# 8700         NaN                                                NaN
# 8701         NaN                                                NaN
# 25722        NaN                                                NaN
#
#       Fatal (Y/N)           Time
# 0               N          18h00
# 1               N  14h00  -15h00
# 2               N          07h45
# ...

# %%
atck[atck['Case Number.1'].isna()==True].count()

# %%
Q1=ndf

# %%
atck.drop(columns='original order')

# %%
for i in drop_atcknul:
    atckt=atck.drop(atck[atck['Case Number'] == i].index)

# %%
drop_atcknul

# %%
atck.nunique()

# %%
atck[atck['Case Number']== '2018.06.25'].value_counts()

# %%
atck[atck['Case Number'].isna()>0].sample(100)

# %%
atck[atck['Case Number'].isna()>0 & atck['Date'].isna()>0 ].sample(100)
