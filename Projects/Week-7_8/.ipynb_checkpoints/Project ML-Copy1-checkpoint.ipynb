# %% [markdown]
# ## Importing Libraries as Needed

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv('/Users/laetitia/IronHack/data-ft-par-labs/Projects/Week-7_8/data/heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# #### Basic data info, missing values and data desciption

# %%
df.info()

# From the info, there seem to be no misisng values
# The datatype is either interger of float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isna().sum()

# No missing values
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# ## Preliminary Data Exploration

# %%
# Overview of dataframe variables distributions

df.hist(layout=(4,4), figsize=(14,12), grid=False)
plt.show()

# %%
# Centering plots

from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# #### Percentage Surveyed

# %%
plt.figure(figsize=(10, 8))

explode = (0, 0.02)
color_list = ['#de758d', '#4c9a97']
target = [len(df[df['sex'] == 0]), len(df[df['sex'] == 1])]
labels = ["Female", "Male"]
plt.pie(x=target, labels=labels, autopct='%1.2f%%', colors=color_list, explode=explode, textprops={'fontsize':14})
plt.title("Pouplation Percentage Surveyed", fontsize=14)
plt.show()

# %% [markdown]
# #### Heart Attacks by Gender

# %%
fig = plt.figure(figsize=(7,6))

attack_by_gender = df.groupby('sex')['target'].sum()
plot1 = sns.barplot(x= attack_by_gender.index, y = attack_by_gender.values, palette="husl")
plot1.set(xticklabels=['Female', 'Male'])
plt.xlabel(None)
plt.xticks(fontsize = 14)
plt.ylabel('Number of Heart Attacks', fontsize=14)
plt.yticks(fontsize = 12)
plt.title('Number of Heart Attacks by Gender', fontsize=12)
plt.show()

# %%
fig = plt.figure(figsize=(7,6))

attack_by_gender = df.groupby('sex')['target'].mean().round(2)*100
plot2 = sns.barplot(x= attack_by_gender.index, y = attack_by_gender.values, palette="husl")
plot2.set(xticklabels=['Female', 'Male'])
plt.xlabel(None)
plt.xticks(fontsize = 14)
plt.ylabel('Percentage of Heart Attacks', fontsize=14)
plt.yticks(fontsize = 12)
plt.title('Percentage of Heart Attacks by Gender', fontsize=14)

# for i in range(len(attack_by_gender)):
#     plot2.annotate(str(attack_by_gender[i]), xy=(i, attack_by_gender[i]), fontsize=14)
plt.show()

# %% [markdown]
# ##### Observations
#
# - By numbers, males appear to be prone to heart attacks than female
# - Based on population sampled, there seem to be a higher percentage of females prone to heart attacks

# %% [markdown]
# #### Chest Pain by Gender

# %%
plt.figure(figsize=(10, 8))

plot3 = sns.countplot(data=df, x='cp',hue='sex', palette="husl")
plot3.set(xticklabels=['Typical Angina ', 'Atypical Angina', 'Non-anginal Pain', 'Non-anginal Pain'])
plt.xlabel(None)
plt.xticks(fontsize=14)
plt.ylabel("Number of People", fontsize=14)
plt.yticks(fontsize=14)
plt.title("Chest Pain Severity Type", fontsize=14)
plt.legend(['Female', 'Male'], fontsize=14, title='Gender', title_fontsize='x-large')
plt.show()

# %% [markdown]
# #### Chest Pain by Age

# %%
plt.figure(figsize=(10, 8))

plot4 = sns.boxplot( df['cp'], df['age'], hue='sex', palette='husl', data=df)
plot4.set(xticklabels=['Typical Angina ', 'Atypical Angina', 'Non-anginal Pain', 'Non-anginal Pain'])
plt.xlabel(None)
plt.xticks(fontsize=14)
plt.ylabel("Age", fontsize=14)
plt.yticks(fontsize=14)
plt.title("Chest Pain Severity Type by Age", fontsize=14)
# plt.legend( ('Female', 1='Male'), fontsize=14)
plt.show()
# Out:
# /Users/laetitia/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### Cholesterol by Age

# %%
fig = plt.figure(figsize=(20, 12))

plot5 = sns.relplot(df.age, df.chol, hue='sex', data=df, palette='husl', size='cp', sizes=(20,200), legend='brief')
    
plot5._legend.texts[0].set_text("Gender")
gender_labels = ["Gender", "Female",'Male']
for t, l in zip(plot5._legend.texts, gender_labels): 
    t.set_text(l)

plot5._legend.texts[3].set_text("Chest Pain Type")

# cp_labels = [ "Chest Pain Type", 'Typical Angina ', 'Atypical Angina', 'Non-anginal Pain', 'Non-anginal Pain']
# for t, l in zip(plot5._legend.texts[3], cp_labels): 
#     t.set_text(l)

plt.show()
# Out:
# /Users/laetitia/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = plt.figure(figsize=(20, 12))

plot6 = sns.relplot(df.age, df.thalach, hue='sex', data=df, palette='husl', size='cp', sizes=(20,200))

plot6._legend.texts[0].set_text("Gender")
gender_labels = ["Gender", "Female",'Male']
for t, l in zip(plot6._legend.texts, gender_labels): 
    t.set_text(l)

plot5._legend.texts[3].set_text("Chest Pain Type")
# Out:
# /Users/laetitia/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### Pair Plots

# %%
fig = plt.figure(figsize=(10,6))

sns.set(style='ticks')
data = df[[ 'trestbps', 'chol', 'thalach', 'sex']]
plot7 = sns.pairplot(data, hue='sex', palette='husl')
replacements = {'trestbps': 'Resting BP', 'chol': 'Serum Cholesterol',
                'thalach': 'Max Heart Rate'}

for i in range(3):
    for j in range(3):
        xlabel = plot7.axes[i][j].get_xlabel()
        ylabel = plot7.axes[i][j].get_ylabel()
        if xlabel in replacements.keys():
            plot7.axes[i][j].set_xlabel(replacements[xlabel], fontsize=12)
        if ylabel in replacements.keys():
            plot7.axes[i][j].set_ylabel(replacements[ylabel], fontsize=12)
            
# for i in range(len(plot7.fig.get_children()[-1].texts)):
#     label = plot7.fig.get_children()[-1].texts[i].get_text()
#     if label in replacements.keys():
#         plot7.fig.get_children()[-1].texts[i].set_text(replacements[label], fontsize=14)
            
plot7.fig.get_children()[-1].set_bbox_to_anchor((1.1, 0.5, 0, 0))
plt.show()

# %% [markdown]
# #### Heatmap Correlation of Features to chech for colinearity

# %%
fig, ax = plt.subplots(figsize=(15,10))

cmap = sns.diverging_palette(240, 20, as_cmap=True)
sns.set(font_scale=1.2)
sns.heatmap(df.corr().round(2), annot=True, cmap = cmap, ax=ax, vmin=-1, vmax=1)

plt.show()

# %% [markdown]
# ##### Observations
#
# - From the heatmap, there seem to be no colinearity between the variables

# %% [markdown]
# ## Evaluating Some Algorithms

# %% [markdown]
# ### Supervised Learning - Classification Modeling

# %% [markdown]
# #### Spliting Data into Training and Testing Sets

# %%
# Import function to split the DataFrame
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Import different models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# Import the scoring
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis=1),
                                                    df.target,
                                                    test_size=0.3,
                                                    stratify=df.target, 
                                                    random_state = 42)

# %% [markdown]
# #### Scaling Data

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
models = []
models.append(('Linear Rgression',LogisticRegression(max_iter = 1e5)))
models.append(('KNeighbors', KNeighborsClassifier(4, weights='distance')))
models.append(('Support Vector', SVC()))
models.append(('Gaussian NB', GaussianNB()))
models.append(('Decision Tree', DecisionTreeClassifier()))
models.append(('Random Forest', RandomForestClassifier()))
# models.append(('AdaBoost', AdaBoostClassifier()))
# models.append(('XGBC', XGBClassifier()))
# models.append(('LGBM', LGBMClassifier()))
# models.append(('CatBoost', CatBoostClassifier()))

# %%
results = []
names = []

for name, model in models:
    mode = model
    mode.fit(X_train, y_train)
    y_pred = mode.predict(X_test)
    acc_score = accuracy_score(y_test, y_pred)
    print(' The Accuracy Score for the %s: is: %f' %(name,  acc_score*100))
    
    pre_score = precision_score(y_test, y_pred)
    print(' The Precision Score for the %s: is: %f' %(name,  pre_score*100))
    
    rec_score = recall_score(y_test, y_pred)
    print(' The Recall Score for the %s: is: %f' %(name,  rec_score*100))
#     f1_score = f1_score(y_test, y_pred)
#     results.append(acc_score.round(2))
#     names.append(name)
    
    print(' The f1 Score for the %s: is: %f' %(name,  rec_score*100))
    print('\n')
# Out:
#  The Accuracy Score for the Linear Rgression: is: 75.824176
#  The Precision Score for the Linear Rgression: is: 75.925926
#  The Recall Score for the Linear Rgression: is: 82.000000
#  The f1 Score for the Linear Rgression: is: 82.000000
#
#
#  The Accuracy Score for the KNeighbors: is: 72.527473
#  The Precision Score for the KNeighbors: is: 73.584906
#  The Recall Score for the KNeighbors: is: 78.000000
#  The f1 Score for the KNeighbors: is: 78.000000
#
#
#  The Accuracy Score for the Support Vector: is: 79.120879
#  The Precision Score for the Support Vector: is: 79.245283
#  The Recall Score for the Support Vector: is: 84.000000
#  The f1 Score for the Support Vector: is: 84.000000
#
#
#  The Accuracy Score for the Gaussian NB: is: 79.120879
#  The Precision Score for the Gaussian NB: is: 78.181818
#  The Recall Score for the Gaussian NB: is: 86.000000
#  The f1 Score for the Gaussian NB: is: 86.000000
#
#
#  The Accuracy Score for the Decision Tree: is: 72.527473
#  The Precision Score for the Decision Tree: is: 73.584906
#  The Recall Score for the Decision Tree: is: 78.000000
#  The f1 Score for the Decision Tree: is: 78.000000
#
#
#  The Accuracy Score for the Random Forest: is: 75.824176
#  The Precision Score for the Random Forest: is: 74.137931
#  The Recall Score for the Random Forest: is: 86.000000
#  The f1 Score for the Random Forest: is: 86.000000

# %%
results
# Out:
# [0.76, 0.73, 0.79, 0.79]

# %%
name
# Out:
# 'GNB'

# %%
print('name')
# Out:
# name

# %% [markdown]
# #### Logistic Regression Model

# %%
model1 = LogisticRegression(max_iter = 1e5)
model1.fit(X_train, y_train)
y_pred1 = model1.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred1)
print('Confusion Matrix')
print('\n')
print(conf_matrix)
print('\n')
print('Accuracy Score for Logistic Regression:', accuracy_score(y_test, y_pred1).round(3)*100)
print('---------------------------------------------')
print('Precision Score for Logistic Regression:', precision_score(y_test, y_pred1).round(3)*100)
print('---------------------------------------------')
print('Recall Score for Logistic Regression:', recall_score(y_test, y_pred1).round(2)*100)
print('---------------------------------------------')
print('f1 Score for Logistic Regression:', f1_score(y_test, y_pred1).round(3)*100)
# Out:
# Confusion Matrix
#
#
# [[28 13]
#  [10 40]]
#
#
# Accuracy Score for Logistic Regression: 74.7
# ---------------------------------------------
# Precision Score for Logistic Regression: 75.5
# ---------------------------------------------
# Recall Score for Logistic Regression: 80.0
# ---------------------------------------------
# f1 Score for Logistic Regression: 77.7

# %% [markdown]
# #### KNeighborsClassifier Model

# %%
model2= KNeighborsClassifier(4, weights='distance')
model2.fit(X_train, y_train)
y_pred2= model2.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred2)
print('Confusion Matrix')
print('\n')
print(conf_matrix)
print('\n')
print('Accuracy Score for Logistic Regression:', accuracy_score(y_test, y_pred2).round(3)*100)
print('---------------------------------------------')
print('Precision Score for Logistic Regression:', precision_score(y_test, y_pred2).round(2)*100)
print('---------------------------------------------')
print('Recall Score for Logistic Regression:', recall_score(y_test, y_pred2).round(2)*100)
print('---------------------------------------------')
print('f1 Score for Logistic Regression:', f1_score(y_test, y_pred2).round(3)*100)
# Out:
# Confusion Matrix
#
#
# [[22 19]
#  [15 35]]
#
#
# Accuracy Score for Logistic Regression: 62.6
# ---------------------------------------------
# Precision Score for Logistic Regression: 65.0
# ---------------------------------------------
# Recall Score for Logistic Regression: 70.0
# ---------------------------------------------
# f1 Score for Logistic Regression: 67.30000000000001

# %% [markdown]
# #### Support Vector Classifier

# %%
model3= SVC()
model3.fit(X_train, y_train)
y_pred3= model3.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred3)
print('Confusion Matrix')
print('\n')
print(conf_matrix)
print('\n')
print('Accuracy Score for Logistic Regression:', accuracy_score(y_test, y_pred3).round(3)*100)
print('---------------------------------------------')
print('Precision Score for Logistic Regression:', precision_score(y_test, y_pred3).round(2)*100)
print('---------------------------------------------')
print('Recall Score for Logistic Regression:', recall_score(y_test, y_pred3).round(3)*100)
print('---------------------------------------------')
print('f1 Score for Logistic Regression:', f1_score(y_test, y_pred3).round(3)*100)
# Out:
# Confusion Matrix
#
#
# [[21 20]
#  [10 40]]
#
#
# Accuracy Score for Logistic Regression: 67.0
# ---------------------------------------------
# Precision Score for Logistic Regression: 67.0
# ---------------------------------------------
# Recall Score for Logistic Regression: 80.0
# ---------------------------------------------
# f1 Score for Logistic Regression: 72.7

# %% [markdown]
# #### Gaussian NB

# %%
model4= GaussianNB()
model4.fit(X_train, y_train)
y_pred4= model4.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred4)
print('Confusion Matrix')
print('\n')
print(conf_matrix)
print('\n')
print('Accuracy Score for Logistic Regression:', accuracy_score(y_test, y_pred4).round(3)*100)
print('---------------------------------------------')
print('Precision Score for Logistic Regression:', precision_score(y_test, y_pred4).round(2)*100)
print('---------------------------------------------')
print('Recall Score for Logistic Regression:', recall_score(y_test, y_pred4).round(3)*100)
print('---------------------------------------------')
print('f1 Score for Logistic Regression:', f1_score(y_test, y_pred4).round(3)*100)
# Out:
# Confusion Matrix
#
#
# [[48  8]
#  [ 8 58]]
#
#
# Accuracy Score for Logistic Regression: 86.9
# ---------------------------------------------
# Precision Score for Logistic Regression: 88.0
# ---------------------------------------------
# Recall Score for Logistic Regression: 87.9
# ---------------------------------------------
# f1 Score for Logistic Regression: 87.9

# %% [markdown]
# #### Decision Tree

# %%
model5= DecisionTreeClassifier()
model5.fit(X_train, y_train)
y_pred5= model5.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred5)
print('Confusion Matrix')
print('\n')
print(conf_matrix)
print('\n')
print('Accuracy Score for Logistic Regression:', accuracy_score(y_test, y_pred5).round(3)*100)
print('---------------------------------------------')
print('Precision Score for Logistic Regression:', precision_score(y_test, y_pred5).round(2)*100)
print('---------------------------------------------')
print('Recall Score for Logistic Regression:', recall_score(y_test, y_pred5).round(3)*100)
print('---------------------------------------------')
print('f1 Score for Logistic Regression:', f1_score(y_test, y_pred5).round(3)*100)
# Out:
# Confusion Matrix
#
#
# [[38 18]
#  [17 49]]
#
#
# Accuracy Score for Logistic Regression: 71.3
# ---------------------------------------------
# Precision Score for Logistic Regression: 73.0
# ---------------------------------------------
# Recall Score for Logistic Regression: 74.2
# ---------------------------------------------
# f1 Score for Logistic Regression: 73.7

# %% [markdown]
# #### Random Forest

# %%
model6=RandomForestClassifier()
model6.fit(X_train, y_train)
y_pred6 = model6.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred6)
print('Confusion Matrix')
print('\n')
print(conf_matrix)
print('\n')
print('Accuracy Score for Logistic Regression:', accuracy_score(y_test, y_pred6).round(2)*100)
print('---------------------------------------------')
print('Precision Score for Logistic Regression:', precision_score(y_test, y_pred6).round(2)*100)
print('---------------------------------------------')
print('Recall Score for Logistic Regression:', recall_score(y_test, y_pred6).round(3)*100)
print('---------------------------------------------')
print('f1 Score for Logistic Regression:', f1_score(y_test, y_pred6).round(3)*100)
# Out:
# Confusion Matrix
#
#
# [[43 13]
#  [15 51]]
#
#
# Accuracy Score for Logistic Regression: 77.0
# ---------------------------------------------
# Precision Score for Logistic Regression: 80.0
# ---------------------------------------------
# Recall Score for Logistic Regression: 77.3
# ---------------------------------------------
# f1 Score for Logistic Regression: 78.5

# %% [markdown]
# #### AdaBoost

# %%
model7=AdaBoostClassifier()
model7.fit(X_train, y_train)
y_pred7 = model7.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred7)
print('Confusion Matrix')
print('\n')
print(conf_matrix)
print('\n')
print('Accuracy Score for Logistic Regression:', accuracy_score(y_test, y_pred7).round(2)*100)
print('---------------------------------------------')
print('Precision Score for Logistic Regression:', precision_score(y_test, y_pred7).round(2)*100)
print('---------------------------------------------')
print('Recall Score for Logistic Regression:', recall_score(y_test, y_pred7).round(3)*100)
print('---------------------------------------------')
print('f1 Score for Logistic Regression:', f1_score(y_test, y_pred7).round(3)*100)
# Out:
# Confusion Matrix
#
#
# [[44 12]
#  [22 44]]
#
#
# Accuracy Score for Logistic Regression: 72.0
# ---------------------------------------------
# Precision Score for Logistic Regression: 79.0
# ---------------------------------------------
# Recall Score for Logistic Regression: 66.7
# ---------------------------------------------
# f1 Score for Logistic Regression: 72.1

# %% [markdown]
# #### XGBoost

# %%
model8=XGBClassifier()
model8.fit(X_train, y_train)
y_pred8 = model8.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred8)
print('Confusion Matrix')
print('\n')
print(conf_matrix)
print('\n')
print('Accuracy Score for Logistic Regression:', accuracy_score(y_test, y_pred8).round(2)*100)
print('---------------------------------------------')
print('Precision Score for Logistic Regression:', precision_score(y_test, y_pred8).round(2)*100)
print('---------------------------------------------')
print('Recall Score for Logistic Regression:', recall_score(y_test, y_pred8).round(3)*100)
print('---------------------------------------------')
print('f1 Score for Logistic Regression:', f1_score(y_test, y_pred8).round(3)*100)
# Out:
# [01:19:54] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion Matrix
#
#
# [[39 17]
#  [13 53]]
#
#
# Accuracy Score for Logistic Regression: 75.0
# ---------------------------------------------
# Precision Score for Logistic Regression: 76.0
# ---------------------------------------------
# Recall Score for Logistic Regression: 80.30000000000001
# ---------------------------------------------
# f1 Score for Logistic Regression: 77.9
# /Users/laetitia/opt/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %% [markdown]
# #### LightGBM

# %%
model9=LGBMClassifier()
model9.fit(X_train, y_train)
y_pred9 = model9.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred9)
print('Confusion Matrix')
print('\n')
print(conf_matrix)
print('\n')
print('Accuracy Score for Logistic Regression:', accuracy_score(y_test, y_pred9).round(2)*100)
print('---------------------------------------------')
print('Precision Score for Logistic Regression:', precision_score(y_test, y_pred9).round(2)*100)
print('---------------------------------------------')
print('Recall Score for Logistic Regression:', recall_score(y_test, y_pred9).round(3)*100)
print('---------------------------------------------')
print('f1 Score for Logistic Regression:', f1_score(y_test, y_pred9).round(3)*100)
# Out:
# Confusion Matrix
#
#
# [[38 18]
#  [13 53]]
#
#
# Accuracy Score for Logistic Regression: 75.0
# ---------------------------------------------
# Precision Score for Logistic Regression: 75.0
# ---------------------------------------------
# Recall Score for Logistic Regression: 80.30000000000001
# ---------------------------------------------
# f1 Score for Logistic Regression: 77.4

# %% [markdown]
# #### CatBoost

# %%
model10=CatBoostClassifier()
model10.fit(X_train, y_train.map(int))
y_pred10 = model10.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred10)
print('Confusion Matrix')
print('\n')
print(conf_matrix)
print('\n')
print('Accuracy Score for Logistic Regression:', accuracy_score(y_test, y_pred10).round(2)*100)
print('---------------------------------------------')
print('Precision Score for Logistic Regression:', precision_score(y_test, y_pred10).round(2)*100)
print('---------------------------------------------')
print('Recall Score for Logistic Regression:', recall_score(y_test, y_pred10).round(3)*100)
print('---------------------------------------------')
print('f1 Score for Logistic Regression:', f1_score(y_test, y_pred10).round(3)*100)
# Out:
# Learning rate set to 0.004965
# 0:	learn: 0.6879374	total: 56.3ms	remaining: 56.3s
# 1:	learn: 0.6841717	total: 57.9ms	remaining: 28.9s
# 2:	learn: 0.6798350	total: 59.2ms	remaining: 19.7s
# 3:	learn: 0.6746549	total: 60.5ms	remaining: 15.1s
# 4:	learn: 0.6704401	total: 61.6ms	remaining: 12.3s
# 5:	learn: 0.6662416	total: 62.7ms	remaining: 10.4s
# 6:	learn: 0.6618635	total: 63.8ms	remaining: 9.05s
# 7:	learn: 0.6582195	total: 65ms	remaining: 8.06s
# 8:	learn: 0.6542851	total: 66.1ms	remaining: 7.28s
# 9:	learn: 0.6496505	total: 67.9ms	remaining: 6.72s
# 10:	learn: 0.6452587	total: 69.5ms	remaining: 6.25s
# 11:	learn: 0.6408797	total: 71.2ms	remaining: 5.86s
# 12:	learn: 0.6365303	total: 73.1ms	remaining: 5.55s
# 13:	learn: 0.6323494	total: 74.8ms	remaining: 5.26s
# 14:	learn: 0.6291559	total: 76.3ms	remaining: 5.01s
# 15:	learn: 0.6249707	total: 77.9ms	remaining: 4.79s
# 16:	learn: 0.6215993	total: 79.6ms	remaining: 4.6s
# 17:	learn: 0.6181176	total: 80.7ms	remaining: 4.4s
# 18:	learn: 0.6144773	total: 82.1ms	remaining: 4.24s
# 19:	learn: 0.6106005	total: 83.6ms	remaining: 4.09s
# 20:	learn: 0.6067715	total: 85ms	remaining: 3.96s
# 21:	learn: 0.6024782	total: 86.6ms	remaining: 3.85s
# 22:	learn: 0.5988809	total: 87.9ms	remaining: 3.73s
# 23:	learn: 0.5948709	total: 89ms	remaining: 3.62s
# 24:	learn: 0.5913538	total: 90.2ms	remaining: 3.52s
# 25:	learn: 0.5877991	total: 91.4ms	remaining: 3.42s
# 26:	learn: 0.5851217	total: 92.6ms	remaining: 3.34s
# 27:	learn: 0.5823042	total: 93.8ms	remaining: 3.25s
# 28:	learn: 0.5794229	total: 94.8ms	remaining: 3.17s
# 29:	learn: 0.5766842	total: 96.1ms	remaining: 3.11s
# 30:	learn: 0.5738779	total: 97.1ms	remaining: 3.03s
# 31:	learn: 0.5708245	total: 98.2ms	remaining: 2.97s
# 32:	learn: 0.5681183	total: 99.3ms	remaining: 2.91s
# 33:	learn: 0.5643924	total: 100ms	remaining: 2.85s
# 34:	learn: 0.5606388	total: 101ms	remaining: 2.8s
# 35:	learn: 0.5581090	total: 103ms	remaining: 2.75s
# 36:	learn: 0.5552842	total: 104ms	remaining: 2.7s
# 37:	learn: 0.5527147	total: 105ms	remaining: 2.65s
# 38:	learn: 0.5503700	total: 106ms	remaining: 2.6s
# 39:	learn: 0.5466126	total: 107ms	remaining: 2.56s
# 40:	learn: 0.5438476	total: 108ms	remaining: 2.52s
# 41:	learn: 0.5408228	total: 109ms	remaining: 2.48s
# 42:	learn: 0.5378369	total: 110ms	remaining: 2.44s
# 43:	learn: 0.5354304	total: 111ms	remaining: 2.41s
# 44:	learn: 0.5325962	total: 112ms	remaining: 2.38s
# 45:	learn: 0.5303099	total: 113ms	remaining: 2.35s
# 46:	learn: 0.5272455	total: 114ms	remaining: 2.31s
# 47:	learn: 0.5239282	total: 115ms	remaining: 2.29s
# 48:	learn: 0.5201983	total: 116ms	remaining: 2.26s
# 49:	learn: 0.5172636	total: 117ms	remaining: 2.23s
# 50:	learn: 0.5153488	total: 118ms	remaining: 2.2s
# 51:	learn: 0.5124504	total: 120ms	remaining: 2.18s
# 52:	learn: 0.5091495	total: 121ms	remaining: 2.16s
# 53:	learn: 0.5070690	total: 122ms	remaining: 2.13s
# 54:	learn: 0.5046553	total: 123ms	remaining: 2.11s
# 55:	learn: 0.5014220	total: 124ms	remaining: 2.09s
# 56:	learn: 0.4990119	total: 125ms	remaining: 2.07s
# 57:	learn: 0.4963432	total: 126ms	remaining: 2.05s
# 58:	learn: 0.4935320	total: 127ms	remaining: 2.03s
# 59:	learn: 0.4914716	total: 129ms	remaining: 2.01s
# 60:	learn: 0.4890911	total: 130ms	remaining: 2s
# 61:	learn: 0.4864307	total: 131ms	remaining: 1.98s
# 62:	learn: 0.4840067	total: 132ms	remaining: 1.96s
# 63:	learn: 0.4811549	total: 133ms	remaining: 1.95s
# 64:	learn: 0.4783484	total: 134ms	remaining: 1.93s
# 65:	learn: 0.4760502	total: 135ms	remaining: 1.91s
# 66:	learn: 0.4739274	total: 136ms	remaining: 1.9s
# 67:	learn: 0.4717900	total: 137ms	remaining: 1.88s
# 68:	learn: 0.4691125	total: 138ms	remaining: 1.87s
# 69:	learn: 0.4668733	total: 140ms	remaining: 1.85s
# 70:	learn: 0.4643451	total: 141ms	remaining: 1.84s
# 71:	learn: 0.4622255	total: 142ms	remaining: 1.83s
# 72:	learn: 0.4596873	total: 143ms	remaining: 1.82s
# 73:	learn: 0.4569442	total: 144ms	remaining: 1.8s
# 74:	learn: 0.4544756	total: 145ms	remaining: 1.79s
# 75:	learn: 0.4535652	total: 146ms	remaining: 1.77s
# 76:	learn: 0.4512732	total: 147ms	remaining: 1.76s
# 77:	learn: 0.4490992	total: 148ms	remaining: 1.75s
# 78:	learn: 0.4473417	total: 149ms	remaining: 1.74s
# 79:	learn: 0.4448362	total: 150ms	remaining: 1.73s
# 80:	learn: 0.4424608	total: 152ms	remaining: 1.72s
# 81:	learn: 0.4405449	total: 153ms	remaining: 1.71s
# 82:	learn: 0.4382424	total: 154ms	remaining: 1.7s
# 83:	learn: 0.4359966	total: 155ms	remaining: 1.69s
# 84:	learn: 0.4346021	total: 156ms	remaining: 1.68s
# 85:	learn: 0.4323201	total: 157ms	remaining: 1.67s
# 86:	learn: 0.4302522	total: 158ms	remaining: 1.66s
# 87:	learn: 0.4283581	total: 159ms	remaining: 1.65s
# 88:	learn: 0.4262674	total: 161ms	remaining: 1.65s
# 89:	learn: 0.4246949	total: 162ms	remaining: 1.64s
# 90:	learn: 0.4232369	total: 164ms	remaining: 1.63s
# 91:	learn: 0.4212791	total: 165ms	remaining: 1.63s
# 92:	learn: 0.4189108	total: 167ms	remaining: 1.63s
# 93:	learn: 0.4174212	total: 168ms	remaining: 1.62s
# 94:	learn: 0.4155863	total: 170ms	remaining: 1.62s
# 95:	learn: 0.4139402	total: 171ms	remaining: 1.61s
# 96:	learn: 0.4123359	total: 172ms	remaining: 1.6s
# 97:	learn: 0.4109094	total: 173ms	remaining: 1.6s
# 98:	learn: 0.4088830	total: 175ms	remaining: 1.59s
# 99:	learn: 0.4080409	total: 176ms	remaining: 1.58s
# 100:	learn: 0.4065967	total: 177ms	remaining: 1.57s
# 101:	learn: 0.4047712	total: 178ms	remaining: 1.57s
# 102:	learn: 0.4031208	total: 179ms	remaining: 1.56s
# 103:	learn: 0.4011713	total: 181ms	remaining: 1.56s
# 104:	learn: 0.3995151	total: 183ms	remaining: 1.56s
# 105:	learn: 0.3977454	total: 184ms	remaining: 1.55s
# 106:	learn: 0.3962903	total: 185ms	remaining: 1.55s
# 107:	learn: 0.3944625	total: 186ms	remaining: 1.54s
# 108:	learn: 0.3926402	total: 188ms	remaining: 1.53s
# 109:	learn: 0.3918002	total: 188ms	remaining: 1.52s
# 110:	learn: 0.3904336	total: 190ms	remaining: 1.52s
# 111:	learn: 0.3893123	total: 191ms	remaining: 1.52s
# 112:	learn: 0.3882561	total: 192ms	remaining: 1.51s
# 113:	learn: 0.3865696	total: 194ms	remaining: 1.5s
# 114:	learn: 0.3849585	total: 195ms	remaining: 1.5s
# 115:	learn: 0.3833855	total: 197ms	remaining: 1.5s
# 116:	learn: 0.3818673	total: 198ms	remaining: 1.49s
# 117:	learn: 0.3805270	total: 199ms	remaining: 1.49s
# 118:	learn: 0.3787560	total: 200ms	remaining: 1.48s
# 119:	learn: 0.3771979	total: 201ms	remaining: 1.47s
# 120:	learn: 0.3754848	total: 202ms	remaining: 1.47s
# 121:	learn: 0.3736508	total: 203ms	remaining: 1.46s
# 122:	learn: 0.3720401	total: 205ms	remaining: 1.46s
# 123:	learn: 0.3704709	total: 205ms	remaining: 1.45s
# 124:	learn: 0.3687900	total: 206ms	remaining: 1.44s
# 125:	learn: 0.3673266	total: 207ms	remaining: 1.44s
# 126:	learn: 0.3660397	total: 208ms	remaining: 1.43s
# 127:	learn: 0.3643930	total: 209ms	remaining: 1.42s
# 128:	learn: 0.3636862	total: 210ms	remaining: 1.42s
# 129:	learn: 0.3625121	total: 211ms	remaining: 1.41s
# 130:	learn: 0.3610757	total: 212ms	remaining: 1.41s
# 131:	learn: 0.3596490	total: 213ms	remaining: 1.4s
# 132:	learn: 0.3591934	total: 214ms	remaining: 1.39s
# 133:	learn: 0.3582165	total: 215ms	remaining: 1.39s
# 134:	learn: 0.3568231	total: 216ms	remaining: 1.38s
# 135:	learn: 0.3553932	total: 217ms	remaining: 1.38s
# 136:	learn: 0.3537835	total: 218ms	remaining: 1.38s
# 137:	learn: 0.3520947	total: 219ms	remaining: 1.37s
# 138:	learn: 0.3508145	total: 220ms	remaining: 1.36s
# 139:	learn: 0.3500077	total: 221ms	remaining: 1.36s
# 140:	learn: 0.3489795	total: 222ms	remaining: 1.35s
# 141:	learn: 0.3475875	total: 223ms	remaining: 1.34s
# 142:	learn: 0.3463378	total: 224ms	remaining: 1.34s
# 143:	learn: 0.3452519	total: 224ms	remaining: 1.33s
# 144:	learn: 0.3438578	total: 225ms	remaining: 1.33s
# 145:	learn: 0.3427921	total: 226ms	remaining: 1.32s
# 146:	learn: 0.3416838	total: 227ms	remaining: 1.32s
# 147:	learn: 0.3403959	total: 228ms	remaining: 1.31s
# 148:	learn: 0.3387257	total: 229ms	remaining: 1.31s
# 149:	learn: 0.3374625	total: 230ms	remaining: 1.3s
# 150:	learn: 0.3360878	total: 231ms	remaining: 1.3s
# 151:	learn: 0.3346916	total: 233ms	remaining: 1.3s
# 152:	learn: 0.3333220	total: 234ms	remaining: 1.29s
# 153:	learn: 0.3324795	total: 235ms	remaining: 1.29s
# 154:	learn: 0.3315211	total: 237ms	remaining: 1.29s
# 155:	learn: 0.3305633	total: 238ms	remaining: 1.29s
# 156:	learn: 0.3295561	total: 240ms	remaining: 1.29s
# 157:	learn: 0.3291104	total: 240ms	remaining: 1.28s
# 158:	learn: 0.3279580	total: 242ms	remaining: 1.28s
# 159:	learn: 0.3268456	total: 243ms	remaining: 1.27s
# 160:	learn: 0.3259322	total: 244ms	remaining: 1.27s
# 161:	learn: 0.3245888	total: 245ms	remaining: 1.27s
# 162:	learn: 0.3235403	total: 247ms	remaining: 1.27s
# 163:	learn: 0.3226006	total: 249ms	remaining: 1.27s
# 164:	learn: 0.3213874	total: 250ms	remaining: 1.26s
# 165:	learn: 0.3204261	total: 251ms	remaining: 1.26s
# 166:	learn: 0.3192934	total: 252ms	remaining: 1.26s
# 167:	learn: 0.3180693	total: 253ms	remaining: 1.25s
# 168:	learn: 0.3170991	total: 255ms	remaining: 1.25s
# 169:	learn: 0.3159274	total: 256ms	remaining: 1.25s
# 170:	learn: 0.3143417	total: 258ms	remaining: 1.25s
# 171:	learn: 0.3131302	total: 259ms	remaining: 1.25s
# 172:	learn: 0.3119224	total: 260ms	remaining: 1.25s
# 173:	learn: 0.3107500	total: 262ms	remaining: 1.24s
# 174:	learn: 0.3097000	total: 263ms	remaining: 1.24s
# 175:	learn: 0.3087814	total: 265ms	remaining: 1.24s
# 176:	learn: 0.3079202	total: 266ms	remaining: 1.24s
# 177:	learn: 0.3067413	total: 267ms	remaining: 1.23s
# 178:	learn: 0.3057044	total: 269ms	remaining: 1.23s
# 179:	learn: 0.3047579	total: 270ms	remaining: 1.23s
# 180:	learn: 0.3037782	total: 271ms	remaining: 1.23s
# 181:	learn: 0.3026888	total: 272ms	remaining: 1.22s
# 182:	learn: 0.3014807	total: 273ms	remaining: 1.22s
# 183:	learn: 0.3008305	total: 274ms	remaining: 1.21s
# 184:	learn: 0.2999736	total: 275ms	remaining: 1.21s
# 185:	learn: 0.2991890	total: 276ms	remaining: 1.21s
# 186:	learn: 0.2988056	total: 277ms	remaining: 1.2s
# 187:	learn: 0.2980158	total: 278ms	remaining: 1.2s
# 188:	learn: 0.2969085	total: 278ms	remaining: 1.19s
# 189:	learn: 0.2959627	total: 279ms	remaining: 1.19s
# 190:	learn: 0.2951128	total: 280ms	remaining: 1.19s
# 191:	learn: 0.2942026	total: 281ms	remaining: 1.18s
# 192:	learn: 0.2933088	total: 282ms	remaining: 1.18s
# 193:	learn: 0.2924397	total: 283ms	remaining: 1.17s
# 194:	learn: 0.2916885	total: 284ms	remaining: 1.17s
# 195:	learn: 0.2908001	total: 285ms	remaining: 1.17s
# 196:	learn: 0.2899712	total: 286ms	remaining: 1.17s
# 197:	learn: 0.2895634	total: 287ms	remaining: 1.16s
# 198:	learn: 0.2887911	total: 288ms	remaining: 1.16s
# 199:	learn: 0.2879107	total: 289ms	remaining: 1.16s
# 200:	learn: 0.2870419	total: 290ms	remaining: 1.15s
# 201:	learn: 0.2861673	total: 291ms	remaining: 1.15s
# 202:	learn: 0.2852993	total: 292ms	remaining: 1.15s
# 203:	learn: 0.2847410	total: 293ms	remaining: 1.14s
# 204:	learn: 0.2839982	total: 293ms	remaining: 1.14s
# 205:	learn: 0.2830735	total: 294ms	remaining: 1.13s
# 206:	learn: 0.2821332	total: 295ms	remaining: 1.13s
# 207:	learn: 0.2811261	total: 296ms	remaining: 1.13s
# 208:	learn: 0.2802391	total: 297ms	remaining: 1.12s
# 209:	learn: 0.2793586	total: 298ms	remaining: 1.12s
# 210:	learn: 0.2785985	total: 299ms	remaining: 1.12s
# 211:	learn: 0.2775670	total: 299ms	remaining: 1.11s
# 212:	learn: 0.2767936	total: 300ms	remaining: 1.11s
# 213:	learn: 0.2761422	total: 301ms	remaining: 1.11s
# 214:	learn: 0.2751469	total: 302ms	remaining: 1.1s
# 215:	learn: 0.2744040	total: 303ms	remaining: 1.1s
# 216:	learn: 0.2735033	total: 304ms	remaining: 1.1s
# 217:	learn: 0.2725440	total: 305ms	remaining: 1.09s
# 218:	learn: 0.2717112	total: 306ms	remaining: 1.09s
# 219:	learn: 0.2711739	total: 307ms	remaining: 1.09s
# 220:	learn: 0.2706785	total: 307ms	remaining: 1.08s
# 221:	learn: 0.2696837	total: 308ms	remaining: 1.08s
# 222:	learn: 0.2685411	total: 309ms	remaining: 1.08s
# 223:	learn: 0.2676326	total: 310ms	remaining: 1.07s
# 224:	learn: 0.2670300	total: 311ms	remaining: 1.07s
# 225:	learn: 0.2662926	total: 312ms	remaining: 1.07s
# 226:	learn: 0.2653183	total: 313ms	remaining: 1.06s
# 227:	learn: 0.2644390	total: 314ms	remaining: 1.06s
# 228:	learn: 0.2636301	total: 314ms	remaining: 1.06s
# 229:	learn: 0.2629255	total: 315ms	remaining: 1.05s
# 230:	learn: 0.2620427	total: 316ms	remaining: 1.05s
# 231:	learn: 0.2615852	total: 317ms	remaining: 1.05s
# 232:	learn: 0.2609751	total: 318ms	remaining: 1.05s
# 233:	learn: 0.2601886	total: 319ms	remaining: 1.04s
# 234:	learn: 0.2594677	total: 320ms	remaining: 1.04s
# 235:	learn: 0.2589065	total: 320ms	remaining: 1.04s
# 236:	learn: 0.2582019	total: 321ms	remaining: 1.03s
# 237:	learn: 0.2574166	total: 322ms	remaining: 1.03s
# 238:	learn: 0.2565709	total: 323ms	remaining: 1.03s
# 239:	learn: 0.2558299	total: 324ms	remaining: 1.02s
# 240:	learn: 0.2549487	total: 325ms	remaining: 1.02s
# 241:	learn: 0.2541739	total: 325ms	remaining: 1.02s
# 242:	learn: 0.2537281	total: 326ms	remaining: 1.02s
# 243:	learn: 0.2532529	total: 327ms	remaining: 1.01s
# 244:	learn: 0.2525492	total: 328ms	remaining: 1.01s
# 245:	learn: 0.2520251	total: 329ms	remaining: 1.01s
# 246:	learn: 0.2514573	total: 330ms	remaining: 1s
# 247:	learn: 0.2508168	total: 331ms	remaining: 1s
# 248:	learn: 0.2502471	total: 331ms	remaining: 1000ms
# 249:	learn: 0.2497450	total: 332ms	remaining: 997ms
# 250:	learn: 0.2489450	total: 333ms	remaining: 994ms
# 251:	learn: 0.2482700	total: 334ms	remaining: 992ms
# 252:	learn: 0.2477004	total: 335ms	remaining: 989ms
# 253:	learn: 0.2470997	total: 336ms	remaining: 986ms
# 254:	learn: 0.2465311	total: 337ms	remaining: 984ms
# 255:	learn: 0.2459186	total: 338ms	remaining: 981ms
# 256:	learn: 0.2453078	total: 338ms	remaining: 978ms
# 257:	learn: 0.2446222	total: 340ms	remaining: 976ms
# 258:	learn: 0.2439536	total: 341ms	remaining: 975ms
# 259:	learn: 0.2432337	total: 342ms	remaining: 974ms
# 260:	learn: 0.2424803	total: 344ms	remaining: 973ms
# 261:	learn: 0.2415904	total: 345ms	remaining: 972ms
# 262:	learn: 0.2409431	total: 346ms	remaining: 970ms
# 263:	learn: 0.2405444	total: 347ms	remaining: 968ms
# 264:	learn: 0.2397163	total: 348ms	remaining: 966ms
# 265:	learn: 0.2391679	total: 349ms	remaining: 963ms
# 266:	learn: 0.2387795	total: 350ms	remaining: 961ms
# 267:	learn: 0.2381752	total: 352ms	remaining: 961ms
# 268:	learn: 0.2374110	total: 353ms	remaining: 958ms
# 269:	learn: 0.2367373	total: 354ms	remaining: 956ms
# 270:	learn: 0.2359177	total: 354ms	remaining: 953ms
# 271:	learn: 0.2352853	total: 355ms	remaining: 951ms
# 272:	learn: 0.2349152	total: 357ms	remaining: 950ms
# 273:	learn: 0.2342445	total: 358ms	remaining: 949ms
# 274:	learn: 0.2335521	total: 360ms	remaining: 950ms
# 275:	learn: 0.2329951	total: 362ms	remaining: 948ms
# 276:	learn: 0.2326528	total: 363ms	remaining: 947ms
# 277:	learn: 0.2321035	total: 364ms	remaining: 946ms
# 278:	learn: 0.2312535	total: 366ms	remaining: 945ms
# 279:	learn: 0.2306736	total: 367ms	remaining: 944ms
# 280:	learn: 0.2300439	total: 368ms	remaining: 942ms
# 281:	learn: 0.2292886	total: 369ms	remaining: 939ms
# 282:	learn: 0.2285909	total: 370ms	remaining: 937ms
# 283:	learn: 0.2279666	total: 371ms	remaining: 934ms
# 284:	learn: 0.2274091	total: 372ms	remaining: 932ms
# 285:	learn: 0.2267121	total: 373ms	remaining: 931ms
# 286:	learn: 0.2261474	total: 374ms	remaining: 929ms
# 287:	learn: 0.2254068	total: 375ms	remaining: 927ms
# 288:	learn: 0.2248572	total: 376ms	remaining: 924ms
# 289:	learn: 0.2241671	total: 377ms	remaining: 922ms
# 290:	learn: 0.2236200	total: 377ms	remaining: 919ms
# 291:	learn: 0.2230436	total: 378ms	remaining: 917ms
# 292:	learn: 0.2224976	total: 379ms	remaining: 915ms
# 293:	learn: 0.2218992	total: 380ms	remaining: 913ms
# 294:	learn: 0.2214030	total: 381ms	remaining: 911ms
# 295:	learn: 0.2209211	total: 382ms	remaining: 908ms
# 296:	learn: 0.2203286	total: 383ms	remaining: 906ms
# 297:	learn: 0.2200654	total: 384ms	remaining: 903ms
# 298:	learn: 0.2199660	total: 384ms	remaining: 900ms
# 299:	learn: 0.2193443	total: 385ms	remaining: 898ms
# 300:	learn: 0.2190034	total: 386ms	remaining: 896ms
# 301:	learn: 0.2184202	total: 387ms	remaining: 894ms
# 302:	learn: 0.2177330	total: 388ms	remaining: 892ms
# 303:	learn: 0.2174302	total: 389ms	remaining: 890ms
# 304:	learn: 0.2165843	total: 390ms	remaining: 888ms
# 305:	learn: 0.2159829	total: 390ms	remaining: 886ms
# 306:	learn: 0.2152264	total: 391ms	remaining: 883ms
# 307:	learn: 0.2146044	total: 392ms	remaining: 881ms
# 308:	learn: 0.2138825	total: 393ms	remaining: 879ms
# 309:	learn: 0.2134737	total: 394ms	remaining: 877ms
# 310:	learn: 0.2129888	total: 395ms	remaining: 875ms
# 311:	learn: 0.2123588	total: 396ms	remaining: 873ms
# 312:	learn: 0.2118924	total: 397ms	remaining: 871ms
# 313:	learn: 0.2114174	total: 398ms	remaining: 869ms
# 314:	learn: 0.2110608	total: 398ms	remaining: 866ms
# 315:	learn: 0.2104945	total: 399ms	remaining: 864ms
# 316:	learn: 0.2100643	total: 400ms	remaining: 862ms
# 317:	learn: 0.2095636	total: 401ms	remaining: 860ms
# 318:	learn: 0.2089607	total: 402ms	remaining: 858ms
# 319:	learn: 0.2084159	total: 403ms	remaining: 856ms
# 320:	learn: 0.2079346	total: 404ms	remaining: 854ms
# 321:	learn: 0.2074159	total: 404ms	remaining: 852ms
# 322:	learn: 0.2067792	total: 405ms	remaining: 849ms
# 323:	learn: 0.2061538	total: 406ms	remaining: 847ms
# 324:	learn: 0.2056178	total: 407ms	remaining: 845ms
# 325:	learn: 0.2050161	total: 408ms	remaining: 843ms
# 326:	learn: 0.2044245	total: 409ms	remaining: 841ms
# 327:	learn: 0.2039216	total: 409ms	remaining: 839ms
# 328:	learn: 0.2036068	total: 410ms	remaining: 837ms
# 329:	learn: 0.2030265	total: 411ms	remaining: 835ms
# 330:	learn: 0.2024318	total: 412ms	remaining: 833ms
# 331:	learn: 0.2021732	total: 413ms	remaining: 832ms
# 332:	learn: 0.2016206	total: 415ms	remaining: 831ms
# 333:	learn: 0.2010085	total: 416ms	remaining: 830ms
# 334:	learn: 0.2004726	total: 418ms	remaining: 829ms
# 335:	learn: 0.1999654	total: 419ms	remaining: 829ms
# 336:	learn: 0.1992306	total: 420ms	remaining: 827ms
# 337:	learn: 0.1987624	total: 421ms	remaining: 825ms
# 338:	learn: 0.1983218	total: 422ms	remaining: 823ms
# 339:	learn: 0.1980337	total: 423ms	remaining: 822ms
# 340:	learn: 0.1975043	total: 425ms	remaining: 822ms
# 341:	learn: 0.1969595	total: 427ms	remaining: 821ms
# 342:	learn: 0.1963527	total: 428ms	remaining: 820ms
# 343:	learn: 0.1959868	total: 429ms	remaining: 819ms
# 344:	learn: 0.1957413	total: 431ms	remaining: 818ms
# 345:	learn: 0.1951707	total: 432ms	remaining: 816ms
# 346:	learn: 0.1946040	total: 433ms	remaining: 815ms
# 347:	learn: 0.1941090	total: 434ms	remaining: 813ms
# 348:	learn: 0.1939078	total: 435ms	remaining: 811ms
# 349:	learn: 0.1935421	total: 436ms	remaining: 809ms
# 350:	learn: 0.1933400	total: 437ms	remaining: 807ms
# 351:	learn: 0.1928927	total: 437ms	remaining: 805ms
# 352:	learn: 0.1924285	total: 439ms	remaining: 804ms
# 353:	learn: 0.1918824	total: 440ms	remaining: 803ms
# 354:	learn: 0.1916882	total: 441ms	remaining: 801ms
# 355:	learn: 0.1913948	total: 442ms	remaining: 799ms
# 356:	learn: 0.1910549	total: 442ms	remaining: 797ms
# 357:	learn: 0.1906572	total: 443ms	remaining: 795ms
# 358:	learn: 0.1903868	total: 444ms	remaining: 793ms
# 359:	learn: 0.1900220	total: 445ms	remaining: 791ms
# 360:	learn: 0.1897599	total: 446ms	remaining: 790ms
# 361:	learn: 0.1895338	total: 448ms	remaining: 789ms
# 362:	learn: 0.1890378	total: 449ms	remaining: 788ms
# 363:	learn: 0.1885443	total: 450ms	remaining: 787ms
# 364:	learn: 0.1882493	total: 452ms	remaining: 786ms
# 365:	learn: 0.1878725	total: 453ms	remaining: 784ms
# 366:	learn: 0.1875161	total: 454ms	remaining: 782ms
# 367:	learn: 0.1871390	total: 455ms	remaining: 781ms
# 368:	learn: 0.1868797	total: 456ms	remaining: 779ms
# 369:	learn: 0.1864901	total: 457ms	remaining: 778ms
# 370:	learn: 0.1861761	total: 458ms	remaining: 777ms
# 371:	learn: 0.1858673	total: 460ms	remaining: 776ms
# 372:	learn: 0.1854094	total: 461ms	remaining: 774ms
# 373:	learn: 0.1849339	total: 462ms	remaining: 773ms
# 374:	learn: 0.1845358	total: 463ms	remaining: 771ms
# 375:	learn: 0.1842524	total: 465ms	remaining: 772ms
# 376:	learn: 0.1839102	total: 467ms	remaining: 771ms
# 377:	learn: 0.1838320	total: 468ms	remaining: 770ms
# 378:	learn: 0.1835860	total: 470ms	remaining: 769ms
# 379:	learn: 0.1831758	total: 471ms	remaining: 769ms
# 380:	learn: 0.1827468	total: 473ms	remaining: 768ms
# 381:	learn: 0.1826329	total: 474ms	remaining: 767ms
# 382:	learn: 0.1822820	total: 476ms	remaining: 766ms
# 383:	learn: 0.1819452	total: 477ms	remaining: 765ms
# 384:	learn: 0.1815966	total: 478ms	remaining: 764ms
# 385:	learn: 0.1814233	total: 480ms	remaining: 764ms
# 386:	learn: 0.1811115	total: 482ms	remaining: 763ms
# 387:	learn: 0.1807225	total: 483ms	remaining: 761ms
# 388:	learn: 0.1802048	total: 484ms	remaining: 760ms
# 389:	learn: 0.1797571	total: 485ms	remaining: 759ms
# 390:	learn: 0.1792952	total: 486ms	remaining: 757ms
# 391:	learn: 0.1788608	total: 487ms	remaining: 756ms
# 392:	learn: 0.1784370	total: 489ms	remaining: 755ms
# 393:	learn: 0.1780660	total: 490ms	remaining: 753ms
# 394:	learn: 0.1777561	total: 491ms	remaining: 752ms
# 395:	learn: 0.1775665	total: 492ms	remaining: 751ms
# 396:	learn: 0.1771842	total: 493ms	remaining: 749ms
# 397:	learn: 0.1766965	total: 495ms	remaining: 748ms
# 398:	learn: 0.1763082	total: 496ms	remaining: 747ms
# 399:	learn: 0.1758907	total: 497ms	remaining: 746ms
# 400:	learn: 0.1755275	total: 499ms	remaining: 745ms
# 401:	learn: 0.1751714	total: 500ms	remaining: 744ms
# 402:	learn: 0.1746907	total: 501ms	remaining: 742ms
# 403:	learn: 0.1743379	total: 502ms	remaining: 741ms
# 404:	learn: 0.1740905	total: 503ms	remaining: 739ms
# 405:	learn: 0.1737720	total: 504ms	remaining: 738ms
# 406:	learn: 0.1736734	total: 505ms	remaining: 736ms
# 407:	learn: 0.1733474	total: 507ms	remaining: 736ms
# 408:	learn: 0.1729850	total: 510ms	remaining: 736ms
# 409:	learn: 0.1725691	total: 511ms	remaining: 735ms
# 410:	learn: 0.1721931	total: 513ms	remaining: 735ms
# 411:	learn: 0.1719416	total: 514ms	remaining: 734ms
# 412:	learn: 0.1716524	total: 517ms	remaining: 734ms
# 413:	learn: 0.1713199	total: 519ms	remaining: 734ms
# 414:	learn: 0.1708457	total: 521ms	remaining: 734ms
# 415:	learn: 0.1704075	total: 523ms	remaining: 734ms
# 416:	learn: 0.1699000	total: 525ms	remaining: 734ms
# 417:	learn: 0.1695229	total: 526ms	remaining: 733ms
# 418:	learn: 0.1691026	total: 528ms	remaining: 732ms
# 419:	learn: 0.1689640	total: 529ms	remaining: 731ms
# 420:	learn: 0.1686416	total: 531ms	remaining: 731ms
# 421:	learn: 0.1683223	total: 533ms	remaining: 730ms
# 422:	learn: 0.1680559	total: 535ms	remaining: 730ms
# 423:	learn: 0.1676761	total: 537ms	remaining: 729ms
# 424:	learn: 0.1675624	total: 538ms	remaining: 729ms
# 425:	learn: 0.1671239	total: 540ms	remaining: 728ms
# 426:	learn: 0.1667587	total: 542ms	remaining: 727ms
# 427:	learn: 0.1664817	total: 543ms	remaining: 726ms
# 428:	learn: 0.1661999	total: 544ms	remaining: 725ms
# 429:	learn: 0.1659316	total: 546ms	remaining: 723ms
# 430:	learn: 0.1655921	total: 547ms	remaining: 722ms
# 431:	learn: 0.1653463	total: 549ms	remaining: 721ms
# 432:	learn: 0.1649996	total: 551ms	remaining: 721ms
# 433:	learn: 0.1645711	total: 552ms	remaining: 720ms
# 434:	learn: 0.1642341	total: 554ms	remaining: 720ms
# 435:	learn: 0.1639377	total: 556ms	remaining: 719ms
# 436:	learn: 0.1636592	total: 557ms	remaining: 718ms
# 437:	learn: 0.1634388	total: 559ms	remaining: 717ms
# 438:	learn: 0.1631386	total: 561ms	remaining: 717ms
# 439:	learn: 0.1627122	total: 562ms	remaining: 715ms
# 440:	learn: 0.1625660	total: 564ms	remaining: 715ms
# 441:	learn: 0.1623105	total: 565ms	remaining: 713ms
# 442:	learn: 0.1619572	total: 566ms	remaining: 712ms
# 443:	learn: 0.1615364	total: 567ms	remaining: 710ms
# 444:	learn: 0.1611717	total: 568ms	remaining: 709ms
# 445:	learn: 0.1608800	total: 569ms	remaining: 707ms
# 446:	learn: 0.1605582	total: 570ms	remaining: 705ms
# 447:	learn: 0.1601714	total: 571ms	remaining: 703ms
# 448:	learn: 0.1600079	total: 572ms	remaining: 702ms
# 449:	learn: 0.1597430	total: 573ms	remaining: 700ms
# 450:	learn: 0.1593701	total: 573ms	remaining: 698ms
# 451:	learn: 0.1593310	total: 574ms	remaining: 696ms
# 452:	learn: 0.1590591	total: 575ms	remaining: 694ms
# 453:	learn: 0.1587893	total: 576ms	remaining: 693ms
# 454:	learn: 0.1584970	total: 577ms	remaining: 691ms
# 455:	learn: 0.1580748	total: 578ms	remaining: 689ms
# 456:	learn: 0.1577151	total: 579ms	remaining: 687ms
# 457:	learn: 0.1574393	total: 579ms	remaining: 686ms
# 458:	learn: 0.1573013	total: 580ms	remaining: 684ms
# 459:	learn: 0.1570088	total: 581ms	remaining: 682ms
# 460:	learn: 0.1569592	total: 582ms	remaining: 680ms
# 461:	learn: 0.1566445	total: 583ms	remaining: 678ms
# 462:	learn: 0.1564075	total: 583ms	remaining: 677ms
# 463:	learn: 0.1561440	total: 584ms	remaining: 675ms
# 464:	learn: 0.1558917	total: 585ms	remaining: 673ms
# 465:	learn: 0.1555121	total: 586ms	remaining: 672ms
# 466:	learn: 0.1552824	total: 587ms	remaining: 670ms
# 467:	learn: 0.1551675	total: 589ms	remaining: 669ms
# 468:	learn: 0.1549878	total: 591ms	remaining: 669ms
# 469:	learn: 0.1547230	total: 592ms	remaining: 668ms
# 470:	learn: 0.1544917	total: 594ms	remaining: 667ms
# 471:	learn: 0.1540721	total: 595ms	remaining: 666ms
# 472:	learn: 0.1537694	total: 596ms	remaining: 664ms
# 473:	learn: 0.1534894	total: 598ms	remaining: 663ms
# 474:	learn: 0.1532812	total: 600ms	remaining: 663ms
# 475:	learn: 0.1529928	total: 602ms	remaining: 662ms
# 476:	learn: 0.1529098	total: 603ms	remaining: 661ms
# 477:	learn: 0.1525869	total: 605ms	remaining: 660ms
# 478:	learn: 0.1522406	total: 606ms	remaining: 659ms
# 479:	learn: 0.1519741	total: 607ms	remaining: 658ms
# 480:	learn: 0.1516890	total: 608ms	remaining: 656ms
# 481:	learn: 0.1514466	total: 609ms	remaining: 654ms
# 482:	learn: 0.1511270	total: 610ms	remaining: 652ms
# 483:	learn: 0.1507754	total: 611ms	remaining: 651ms
# 484:	learn: 0.1503205	total: 612ms	remaining: 650ms
# 485:	learn: 0.1500954	total: 613ms	remaining: 648ms
# 486:	learn: 0.1498842	total: 614ms	remaining: 646ms
# 487:	learn: 0.1497266	total: 615ms	remaining: 645ms
# 488:	learn: 0.1493954	total: 615ms	remaining: 643ms
# 489:	learn: 0.1491159	total: 616ms	remaining: 641ms
# 490:	learn: 0.1488478	total: 617ms	remaining: 640ms
# 491:	learn: 0.1485574	total: 618ms	remaining: 638ms
# 492:	learn: 0.1482448	total: 619ms	remaining: 637ms
# 493:	learn: 0.1479463	total: 620ms	remaining: 635ms
# 494:	learn: 0.1477881	total: 621ms	remaining: 634ms
# 495:	learn: 0.1476248	total: 622ms	remaining: 632ms
# 496:	learn: 0.1474248	total: 623ms	remaining: 630ms
# 497:	learn: 0.1471221	total: 624ms	remaining: 629ms
# 498:	learn: 0.1468808	total: 625ms	remaining: 627ms
# 499:	learn: 0.1466780	total: 626ms	remaining: 626ms
# 500:	learn: 0.1464610	total: 627ms	remaining: 624ms
# 501:	learn: 0.1461913	total: 627ms	remaining: 622ms
# 502:	learn: 0.1458770	total: 628ms	remaining: 621ms
# 503:	learn: 0.1456851	total: 629ms	remaining: 619ms
# 504:	learn: 0.1453296	total: 630ms	remaining: 617ms
# 505:	learn: 0.1451302	total: 631ms	remaining: 616ms
# 506:	learn: 0.1448020	total: 632ms	remaining: 614ms
# 507:	learn: 0.1446392	total: 633ms	remaining: 613ms
# 508:	learn: 0.1444318	total: 633ms	remaining: 611ms
# 509:	learn: 0.1441233	total: 634ms	remaining: 609ms
# 510:	learn: 0.1440083	total: 635ms	remaining: 608ms
# 511:	learn: 0.1436489	total: 636ms	remaining: 606ms
# 512:	learn: 0.1433101	total: 637ms	remaining: 605ms
# 513:	learn: 0.1429226	total: 638ms	remaining: 603ms
# 514:	learn: 0.1427373	total: 639ms	remaining: 602ms
# 515:	learn: 0.1424831	total: 640ms	remaining: 600ms
# 516:	learn: 0.1421977	total: 641ms	remaining: 599ms
# 517:	learn: 0.1418749	total: 642ms	remaining: 597ms
# 518:	learn: 0.1416003	total: 643ms	remaining: 595ms
# 519:	learn: 0.1413244	total: 643ms	remaining: 594ms
# 520:	learn: 0.1410573	total: 644ms	remaining: 592ms
# 521:	learn: 0.1408137	total: 645ms	remaining: 591ms
# 522:	learn: 0.1405893	total: 646ms	remaining: 589ms
# 523:	learn: 0.1404285	total: 647ms	remaining: 588ms
# 524:	learn: 0.1401518	total: 648ms	remaining: 586ms
# 525:	learn: 0.1398723	total: 648ms	remaining: 584ms
# 526:	learn: 0.1396672	total: 649ms	remaining: 583ms
# 527:	learn: 0.1395000	total: 650ms	remaining: 581ms
# 528:	learn: 0.1392302	total: 651ms	remaining: 580ms
# 529:	learn: 0.1390742	total: 652ms	remaining: 578ms
# 530:	learn: 0.1388822	total: 653ms	remaining: 577ms
# 531:	learn: 0.1387628	total: 654ms	remaining: 575ms
# 532:	learn: 0.1385664	total: 655ms	remaining: 574ms
# 533:	learn: 0.1384071	total: 655ms	remaining: 572ms
# 534:	learn: 0.1382420	total: 656ms	remaining: 570ms
# 535:	learn: 0.1379211	total: 657ms	remaining: 569ms
# 536:	learn: 0.1377670	total: 658ms	remaining: 567ms
# 537:	learn: 0.1374901	total: 659ms	remaining: 566ms
# 538:	learn: 0.1373210	total: 660ms	remaining: 564ms
# 539:	learn: 0.1371376	total: 661ms	remaining: 563ms
# 540:	learn: 0.1368147	total: 662ms	remaining: 561ms
# 541:	learn: 0.1366537	total: 663ms	remaining: 560ms
# 542:	learn: 0.1363910	total: 664ms	remaining: 558ms
# 543:	learn: 0.1361010	total: 664ms	remaining: 557ms
# 544:	learn: 0.1358315	total: 665ms	remaining: 555ms
# 545:	learn: 0.1355291	total: 666ms	remaining: 554ms
# 546:	learn: 0.1352127	total: 667ms	remaining: 552ms
# 547:	learn: 0.1350295	total: 668ms	remaining: 551ms
# 548:	learn: 0.1348444	total: 669ms	remaining: 549ms
# 549:	learn: 0.1346945	total: 670ms	remaining: 548ms
# 550:	learn: 0.1344768	total: 670ms	remaining: 546ms
# 551:	learn: 0.1343028	total: 671ms	remaining: 545ms
# 552:	learn: 0.1340708	total: 672ms	remaining: 543ms
# 553:	learn: 0.1338532	total: 673ms	remaining: 542ms
# 554:	learn: 0.1335182	total: 674ms	remaining: 540ms
# 555:	learn: 0.1334279	total: 675ms	remaining: 539ms
# 556:	learn: 0.1332003	total: 676ms	remaining: 537ms
# 557:	learn: 0.1330713	total: 676ms	remaining: 536ms
# 558:	learn: 0.1329390	total: 677ms	remaining: 534ms
# 559:	learn: 0.1327146	total: 678ms	remaining: 533ms
# 560:	learn: 0.1324126	total: 679ms	remaining: 531ms
# 561:	learn: 0.1321296	total: 680ms	remaining: 530ms
# 562:	learn: 0.1318688	total: 681ms	remaining: 528ms
# 563:	learn: 0.1316771	total: 682ms	remaining: 527ms
# 564:	learn: 0.1314626	total: 682ms	remaining: 525ms
# 565:	learn: 0.1313038	total: 683ms	remaining: 524ms
# 566:	learn: 0.1310618	total: 684ms	remaining: 523ms
# 567:	learn: 0.1308282	total: 685ms	remaining: 521ms
# 568:	learn: 0.1305902	total: 686ms	remaining: 520ms
# 569:	learn: 0.1302758	total: 687ms	remaining: 518ms
# 570:	learn: 0.1299924	total: 688ms	remaining: 517ms
# 571:	learn: 0.1298890	total: 688ms	remaining: 515ms
# 572:	learn: 0.1296359	total: 689ms	remaining: 514ms
# 573:	learn: 0.1294825	total: 690ms	remaining: 512ms
# 574:	learn: 0.1292787	total: 691ms	remaining: 511ms
# 575:	learn: 0.1290582	total: 692ms	remaining: 510ms
# 576:	learn: 0.1288311	total: 694ms	remaining: 509ms
# 577:	learn: 0.1286575	total: 695ms	remaining: 508ms
# 578:	learn: 0.1284694	total: 697ms	remaining: 507ms
# 579:	learn: 0.1282945	total: 698ms	remaining: 505ms
# 580:	learn: 0.1281692	total: 700ms	remaining: 505ms
# 581:	learn: 0.1279142	total: 701ms	remaining: 504ms
# 582:	learn: 0.1277282	total: 702ms	remaining: 502ms
# 583:	learn: 0.1275165	total: 703ms	remaining: 501ms
# 584:	learn: 0.1272457	total: 704ms	remaining: 500ms
# 585:	learn: 0.1272113	total: 705ms	remaining: 498ms
# 586:	learn: 0.1268989	total: 706ms	remaining: 496ms
# 587:	learn: 0.1265752	total: 707ms	remaining: 495ms
# 588:	learn: 0.1263120	total: 708ms	remaining: 494ms
# 589:	learn: 0.1260884	total: 709ms	remaining: 492ms
# 590:	learn: 0.1259289	total: 710ms	remaining: 491ms
# 591:	learn: 0.1257052	total: 710ms	remaining: 490ms
# 592:	learn: 0.1254725	total: 712ms	remaining: 489ms
# 593:	learn: 0.1254391	total: 713ms	remaining: 487ms
# 594:	learn: 0.1252792	total: 714ms	remaining: 486ms
# 595:	learn: 0.1250918	total: 715ms	remaining: 485ms
# 596:	learn: 0.1248576	total: 716ms	remaining: 484ms
# 597:	learn: 0.1246975	total: 718ms	remaining: 483ms
# 598:	learn: 0.1245451	total: 719ms	remaining: 481ms
# 599:	learn: 0.1243994	total: 720ms	remaining: 480ms
# 600:	learn: 0.1242263	total: 721ms	remaining: 478ms
# 601:	learn: 0.1240013	total: 722ms	remaining: 477ms
# 602:	learn: 0.1237611	total: 723ms	remaining: 476ms
# 603:	learn: 0.1235345	total: 724ms	remaining: 474ms
# 604:	learn: 0.1233517	total: 725ms	remaining: 473ms
# 605:	learn: 0.1231162	total: 725ms	remaining: 472ms
# 606:	learn: 0.1229094	total: 726ms	remaining: 470ms
# 607:	learn: 0.1227998	total: 727ms	remaining: 469ms
# 608:	learn: 0.1225552	total: 728ms	remaining: 467ms
# 609:	learn: 0.1223687	total: 729ms	remaining: 466ms
# 610:	learn: 0.1222406	total: 730ms	remaining: 465ms
# 611:	learn: 0.1221267	total: 731ms	remaining: 463ms
# 612:	learn: 0.1219336	total: 731ms	remaining: 462ms
# 613:	learn: 0.1217690	total: 732ms	remaining: 460ms
# 614:	learn: 0.1216533	total: 733ms	remaining: 459ms
# 615:	learn: 0.1215296	total: 734ms	remaining: 458ms
# 616:	learn: 0.1214318	total: 735ms	remaining: 456ms
# 617:	learn: 0.1212749	total: 736ms	remaining: 455ms
# 618:	learn: 0.1211084	total: 737ms	remaining: 454ms
# 619:	learn: 0.1209658	total: 738ms	remaining: 452ms
# 620:	learn: 0.1208000	total: 739ms	remaining: 451ms
# 621:	learn: 0.1206483	total: 740ms	remaining: 450ms
# 622:	learn: 0.1205005	total: 741ms	remaining: 448ms
# 623:	learn: 0.1203132	total: 742ms	remaining: 447ms
# 624:	learn: 0.1200852	total: 743ms	remaining: 446ms
# 625:	learn: 0.1198201	total: 744ms	remaining: 444ms
# 626:	learn: 0.1196155	total: 745ms	remaining: 443ms
# 627:	learn: 0.1193783	total: 746ms	remaining: 442ms
# 628:	learn: 0.1191205	total: 746ms	remaining: 440ms
# 629:	learn: 0.1189248	total: 747ms	remaining: 439ms
# 630:	learn: 0.1186943	total: 748ms	remaining: 438ms
# 631:	learn: 0.1185046	total: 749ms	remaining: 436ms
# 632:	learn: 0.1183778	total: 750ms	remaining: 435ms
# 633:	learn: 0.1182282	total: 751ms	remaining: 433ms
# 634:	learn: 0.1180107	total: 752ms	remaining: 432ms
# 635:	learn: 0.1178722	total: 753ms	remaining: 431ms
# 636:	learn: 0.1177807	total: 754ms	remaining: 430ms
# 637:	learn: 0.1175459	total: 755ms	remaining: 428ms
# 638:	learn: 0.1173733	total: 756ms	remaining: 427ms
# 639:	learn: 0.1172091	total: 756ms	remaining: 426ms
# 640:	learn: 0.1170746	total: 757ms	remaining: 424ms
# 641:	learn: 0.1168854	total: 758ms	remaining: 423ms
# 642:	learn: 0.1166908	total: 759ms	remaining: 422ms
# 643:	learn: 0.1165105	total: 760ms	remaining: 420ms
# 644:	learn: 0.1162954	total: 761ms	remaining: 419ms
# 645:	learn: 0.1162111	total: 762ms	remaining: 418ms
# 646:	learn: 0.1160364	total: 763ms	remaining: 416ms
# 647:	learn: 0.1159205	total: 764ms	remaining: 415ms
# 648:	learn: 0.1157669	total: 765ms	remaining: 413ms
# 649:	learn: 0.1155730	total: 767ms	remaining: 413ms
# 650:	learn: 0.1153251	total: 768ms	remaining: 412ms
# 651:	learn: 0.1151940	total: 770ms	remaining: 411ms
# 652:	learn: 0.1149360	total: 771ms	remaining: 410ms
# 653:	learn: 0.1147760	total: 772ms	remaining: 409ms
# 654:	learn: 0.1145976	total: 774ms	remaining: 407ms
# 655:	learn: 0.1142978	total: 775ms	remaining: 406ms
# 656:	learn: 0.1141440	total: 776ms	remaining: 405ms
# 657:	learn: 0.1140406	total: 777ms	remaining: 404ms
# 658:	learn: 0.1138186	total: 777ms	remaining: 402ms
# 659:	learn: 0.1136011	total: 779ms	remaining: 401ms
# 660:	learn: 0.1133746	total: 780ms	remaining: 400ms
# 661:	learn: 0.1132269	total: 782ms	remaining: 399ms
# 662:	learn: 0.1129951	total: 783ms	remaining: 398ms
# 663:	learn: 0.1128895	total: 784ms	remaining: 397ms
# 664:	learn: 0.1127629	total: 785ms	remaining: 396ms
# 665:	learn: 0.1126483	total: 786ms	remaining: 394ms
# 666:	learn: 0.1125024	total: 787ms	remaining: 393ms
# 667:	learn: 0.1123387	total: 788ms	remaining: 392ms
# 668:	learn: 0.1121617	total: 790ms	remaining: 391ms
# 669:	learn: 0.1120124	total: 791ms	remaining: 389ms
# 670:	learn: 0.1117791	total: 791ms	remaining: 388ms
# 671:	learn: 0.1116386	total: 792ms	remaining: 387ms
# 672:	learn: 0.1114728	total: 793ms	remaining: 385ms
# 673:	learn: 0.1113105	total: 794ms	remaining: 384ms
# 674:	learn: 0.1111070	total: 795ms	remaining: 383ms
# 675:	learn: 0.1109822	total: 796ms	remaining: 381ms
# 676:	learn: 0.1108187	total: 798ms	remaining: 381ms
# 677:	learn: 0.1106381	total: 799ms	remaining: 379ms
# 678:	learn: 0.1104571	total: 800ms	remaining: 378ms
# 679:	learn: 0.1102004	total: 801ms	remaining: 377ms
# 680:	learn: 0.1101417	total: 802ms	remaining: 376ms
# 681:	learn: 0.1099670	total: 803ms	remaining: 375ms
# 682:	learn: 0.1098608	total: 805ms	remaining: 373ms
# 683:	learn: 0.1097681	total: 806ms	remaining: 372ms
# 684:	learn: 0.1095955	total: 807ms	remaining: 371ms
# 685:	learn: 0.1094982	total: 808ms	remaining: 370ms
# 686:	learn: 0.1093540	total: 809ms	remaining: 368ms
# 687:	learn: 0.1091684	total: 810ms	remaining: 367ms
# 688:	learn: 0.1090058	total: 811ms	remaining: 366ms
# 689:	learn: 0.1088403	total: 812ms	remaining: 365ms
# 690:	learn: 0.1086563	total: 813ms	remaining: 363ms
# 691:	learn: 0.1084500	total: 813ms	remaining: 362ms
# 692:	learn: 0.1083235	total: 814ms	remaining: 361ms
# 693:	learn: 0.1082091	total: 815ms	remaining: 359ms
# 694:	learn: 0.1080699	total: 816ms	remaining: 358ms
# 695:	learn: 0.1079387	total: 817ms	remaining: 357ms
# 696:	learn: 0.1077470	total: 818ms	remaining: 355ms
# 697:	learn: 0.1075848	total: 818ms	remaining: 354ms
# 698:	learn: 0.1073707	total: 819ms	remaining: 353ms
# 699:	learn: 0.1072813	total: 820ms	remaining: 351ms
# 700:	learn: 0.1070909	total: 821ms	remaining: 350ms
# 701:	learn: 0.1068834	total: 822ms	remaining: 349ms
# 702:	learn: 0.1067925	total: 823ms	remaining: 348ms
# 703:	learn: 0.1066893	total: 823ms	remaining: 346ms
# 704:	learn: 0.1064835	total: 824ms	remaining: 345ms
# 705:	learn: 0.1063540	total: 825ms	remaining: 344ms
# 706:	learn: 0.1062220	total: 827ms	remaining: 343ms
# 707:	learn: 0.1060113	total: 828ms	remaining: 341ms
# 708:	learn: 0.1058762	total: 829ms	remaining: 340ms
# 709:	learn: 0.1057365	total: 829ms	remaining: 339ms
# 710:	learn: 0.1054885	total: 830ms	remaining: 338ms
# 711:	learn: 0.1052904	total: 832ms	remaining: 336ms
# 712:	learn: 0.1050919	total: 833ms	remaining: 335ms
# 713:	learn: 0.1049619	total: 833ms	remaining: 334ms
# 714:	learn: 0.1048159	total: 834ms	remaining: 333ms
# 715:	learn: 0.1046541	total: 835ms	remaining: 331ms
# 716:	learn: 0.1044756	total: 836ms	remaining: 330ms
# 717:	learn: 0.1042227	total: 837ms	remaining: 329ms
# 718:	learn: 0.1040113	total: 838ms	remaining: 327ms
# 719:	learn: 0.1038384	total: 839ms	remaining: 326ms
# 720:	learn: 0.1036331	total: 840ms	remaining: 325ms
# 721:	learn: 0.1035138	total: 841ms	remaining: 324ms
# 722:	learn: 0.1033404	total: 842ms	remaining: 323ms
# 723:	learn: 0.1031972	total: 843ms	remaining: 321ms
# 724:	learn: 0.1030963	total: 844ms	remaining: 320ms
# 725:	learn: 0.1029007	total: 845ms	remaining: 319ms
# 726:	learn: 0.1027376	total: 846ms	remaining: 318ms
# 727:	learn: 0.1025808	total: 847ms	remaining: 316ms
# 728:	learn: 0.1024881	total: 848ms	remaining: 315ms
# 729:	learn: 0.1023457	total: 849ms	remaining: 314ms
# 730:	learn: 0.1022400	total: 850ms	remaining: 313ms
# 731:	learn: 0.1019992	total: 850ms	remaining: 311ms
# 732:	learn: 0.1017845	total: 851ms	remaining: 310ms
# 733:	learn: 0.1016325	total: 852ms	remaining: 309ms
# 734:	learn: 0.1014686	total: 853ms	remaining: 308ms
# 735:	learn: 0.1013620	total: 854ms	remaining: 306ms
# 736:	learn: 0.1012650	total: 855ms	remaining: 305ms
# 737:	learn: 0.1011631	total: 856ms	remaining: 304ms
# 738:	learn: 0.1009792	total: 857ms	remaining: 303ms
# 739:	learn: 0.1008393	total: 858ms	remaining: 301ms
# 740:	learn: 0.1006823	total: 859ms	remaining: 300ms
# 741:	learn: 0.1005725	total: 860ms	remaining: 299ms
# 742:	learn: 0.1004190	total: 861ms	remaining: 298ms
# 743:	learn: 0.1002586	total: 862ms	remaining: 296ms
# 744:	learn: 0.1001429	total: 862ms	remaining: 295ms
# 745:	learn: 0.1000071	total: 863ms	remaining: 294ms
# 746:	learn: 0.0999193	total: 864ms	remaining: 293ms
# 747:	learn: 0.0997435	total: 865ms	remaining: 291ms
# 748:	learn: 0.0995518	total: 866ms	remaining: 290ms
# 749:	learn: 0.0993466	total: 866ms	remaining: 289ms
# 750:	learn: 0.0991322	total: 867ms	remaining: 288ms
# 751:	learn: 0.0990004	total: 868ms	remaining: 286ms
# 752:	learn: 0.0988510	total: 869ms	remaining: 285ms
# 753:	learn: 0.0988004	total: 870ms	remaining: 284ms
# 754:	learn: 0.0986480	total: 872ms	remaining: 283ms
# 755:	learn: 0.0985110	total: 873ms	remaining: 282ms
# 756:	learn: 0.0982990	total: 875ms	remaining: 281ms
# 757:	learn: 0.0982355	total: 876ms	remaining: 280ms
# 758:	learn: 0.0981144	total: 878ms	remaining: 279ms
# 759:	learn: 0.0979099	total: 879ms	remaining: 278ms
# 760:	learn: 0.0977690	total: 880ms	remaining: 276ms
# 761:	learn: 0.0976815	total: 881ms	remaining: 275ms
# 762:	learn: 0.0975277	total: 882ms	remaining: 274ms
# 763:	learn: 0.0973813	total: 883ms	remaining: 273ms
# 764:	learn: 0.0973167	total: 884ms	remaining: 271ms
# 765:	learn: 0.0971800	total: 885ms	remaining: 270ms
# 766:	learn: 0.0971195	total: 886ms	remaining: 269ms
# 767:	learn: 0.0969685	total: 887ms	remaining: 268ms
# 768:	learn: 0.0967844	total: 888ms	remaining: 267ms
# 769:	learn: 0.0966330	total: 889ms	remaining: 265ms
# 770:	learn: 0.0964807	total: 890ms	remaining: 264ms
# 771:	learn: 0.0963652	total: 892ms	remaining: 263ms
# 772:	learn: 0.0962699	total: 893ms	remaining: 262ms
# 773:	learn: 0.0961369	total: 894ms	remaining: 261ms
# 774:	learn: 0.0960340	total: 896ms	remaining: 260ms
# 775:	learn: 0.0958953	total: 898ms	remaining: 259ms
# 776:	learn: 0.0957866	total: 899ms	remaining: 258ms
# 777:	learn: 0.0955948	total: 901ms	remaining: 257ms
# 778:	learn: 0.0955000	total: 901ms	remaining: 256ms
# 779:	learn: 0.0953903	total: 902ms	remaining: 255ms
# 780:	learn: 0.0952369	total: 903ms	remaining: 253ms
# 781:	learn: 0.0951119	total: 904ms	remaining: 252ms
# 782:	learn: 0.0950010	total: 905ms	remaining: 251ms
# 783:	learn: 0.0948484	total: 906ms	remaining: 250ms
# 784:	learn: 0.0947459	total: 907ms	remaining: 248ms
# 785:	learn: 0.0946115	total: 908ms	remaining: 247ms
# 786:	learn: 0.0945300	total: 908ms	remaining: 246ms
# 787:	learn: 0.0943719	total: 909ms	remaining: 245ms
# 788:	learn: 0.0942050	total: 910ms	remaining: 243ms
# 789:	learn: 0.0940475	total: 911ms	remaining: 242ms
# 790:	learn: 0.0938944	total: 912ms	remaining: 241ms
# 791:	learn: 0.0937339	total: 913ms	remaining: 240ms
# 792:	learn: 0.0936194	total: 914ms	remaining: 239ms
# 793:	learn: 0.0934861	total: 915ms	remaining: 237ms
# 794:	learn: 0.0933555	total: 916ms	remaining: 236ms
# 795:	learn: 0.0932473	total: 917ms	remaining: 235ms
# 796:	learn: 0.0931018	total: 918ms	remaining: 234ms
# 797:	learn: 0.0930097	total: 919ms	remaining: 233ms
# 798:	learn: 0.0928559	total: 920ms	remaining: 231ms
# 799:	learn: 0.0928298	total: 920ms	remaining: 230ms
# 800:	learn: 0.0927259	total: 921ms	remaining: 229ms
# 801:	learn: 0.0926895	total: 922ms	remaining: 228ms
# 802:	learn: 0.0925004	total: 923ms	remaining: 226ms
# 803:	learn: 0.0924553	total: 924ms	remaining: 225ms
# 804:	learn: 0.0923510	total: 925ms	remaining: 224ms
# 805:	learn: 0.0922292	total: 925ms	remaining: 223ms
# 806:	learn: 0.0921145	total: 926ms	remaining: 222ms
# 807:	learn: 0.0919567	total: 927ms	remaining: 220ms
# 808:	learn: 0.0918001	total: 928ms	remaining: 219ms
# 809:	learn: 0.0917595	total: 929ms	remaining: 218ms
# 810:	learn: 0.0916321	total: 930ms	remaining: 217ms
# 811:	learn: 0.0915389	total: 930ms	remaining: 215ms
# 812:	learn: 0.0914342	total: 931ms	remaining: 214ms
# 813:	learn: 0.0913019	total: 932ms	remaining: 213ms
# 814:	learn: 0.0911879	total: 933ms	remaining: 212ms
# 815:	learn: 0.0910811	total: 934ms	remaining: 211ms
# 816:	learn: 0.0909945	total: 935ms	remaining: 209ms
# 817:	learn: 0.0908801	total: 936ms	remaining: 208ms
# 818:	learn: 0.0907742	total: 936ms	remaining: 207ms
# 819:	learn: 0.0907044	total: 937ms	remaining: 206ms
# 820:	learn: 0.0904348	total: 938ms	remaining: 205ms
# 821:	learn: 0.0903471	total: 940ms	remaining: 203ms
# 822:	learn: 0.0902494	total: 941ms	remaining: 202ms
# 823:	learn: 0.0901895	total: 941ms	remaining: 201ms
# 824:	learn: 0.0900455	total: 942ms	remaining: 200ms
# 825:	learn: 0.0899154	total: 943ms	remaining: 199ms
# 826:	learn: 0.0897973	total: 944ms	remaining: 197ms
# 827:	learn: 0.0896607	total: 945ms	remaining: 196ms
# 828:	learn: 0.0894648	total: 947ms	remaining: 195ms
# 829:	learn: 0.0893253	total: 948ms	remaining: 194ms
# 830:	learn: 0.0891716	total: 950ms	remaining: 193ms
# 831:	learn: 0.0890788	total: 951ms	remaining: 192ms
# 832:	learn: 0.0890596	total: 952ms	remaining: 191ms
# 833:	learn: 0.0889171	total: 953ms	remaining: 190ms
# 834:	learn: 0.0887299	total: 954ms	remaining: 189ms
# 835:	learn: 0.0886142	total: 955ms	remaining: 187ms
# 836:	learn: 0.0884916	total: 956ms	remaining: 186ms
# 837:	learn: 0.0884123	total: 957ms	remaining: 185ms
# 838:	learn: 0.0882588	total: 959ms	remaining: 184ms
# 839:	learn: 0.0881734	total: 961ms	remaining: 183ms
# 840:	learn: 0.0880046	total: 962ms	remaining: 182ms
# 841:	learn: 0.0878811	total: 963ms	remaining: 181ms
# 842:	learn: 0.0877645	total: 964ms	remaining: 180ms
# 843:	learn: 0.0875586	total: 965ms	remaining: 178ms
# 844:	learn: 0.0873957	total: 967ms	remaining: 177ms
# 845:	learn: 0.0872842	total: 968ms	remaining: 176ms
# 846:	learn: 0.0871497	total: 969ms	remaining: 175ms
# 847:	learn: 0.0870592	total: 970ms	remaining: 174ms
# 848:	learn: 0.0869883	total: 971ms	remaining: 173ms
# 849:	learn: 0.0869230	total: 971ms	remaining: 171ms
# 850:	learn: 0.0867740	total: 972ms	remaining: 170ms
# 851:	learn: 0.0866810	total: 973ms	remaining: 169ms
# 852:	learn: 0.0865110	total: 974ms	remaining: 168ms
# 853:	learn: 0.0864142	total: 975ms	remaining: 167ms
# 854:	learn: 0.0862823	total: 976ms	remaining: 166ms
# 855:	learn: 0.0861678	total: 977ms	remaining: 164ms
# 856:	learn: 0.0860420	total: 978ms	remaining: 163ms
# 857:	learn: 0.0859177	total: 979ms	remaining: 162ms
# 858:	learn: 0.0858379	total: 980ms	remaining: 161ms
# 859:	learn: 0.0857108	total: 981ms	remaining: 160ms
# 860:	learn: 0.0855980	total: 982ms	remaining: 158ms
# 861:	learn: 0.0855301	total: 982ms	remaining: 157ms
# 862:	learn: 0.0854094	total: 983ms	remaining: 156ms
# 863:	learn: 0.0853020	total: 984ms	remaining: 155ms
# 864:	learn: 0.0851706	total: 985ms	remaining: 154ms
# 865:	learn: 0.0850619	total: 986ms	remaining: 153ms
# 866:	learn: 0.0850022	total: 987ms	remaining: 151ms
# 867:	learn: 0.0848702	total: 988ms	remaining: 150ms
# 868:	learn: 0.0847685	total: 989ms	remaining: 149ms
# 869:	learn: 0.0846692	total: 989ms	remaining: 148ms
# 870:	learn: 0.0845242	total: 990ms	remaining: 147ms
# 871:	learn: 0.0844055	total: 991ms	remaining: 145ms
# 872:	learn: 0.0842467	total: 992ms	remaining: 144ms
# 873:	learn: 0.0841025	total: 993ms	remaining: 143ms
# 874:	learn: 0.0840498	total: 994ms	remaining: 142ms
# 875:	learn: 0.0840463	total: 994ms	remaining: 141ms
# 876:	learn: 0.0839203	total: 995ms	remaining: 140ms
# 877:	learn: 0.0838284	total: 996ms	remaining: 138ms
# 878:	learn: 0.0836672	total: 997ms	remaining: 137ms
# 879:	learn: 0.0835288	total: 998ms	remaining: 136ms
# 880:	learn: 0.0834305	total: 999ms	remaining: 135ms
# 881:	learn: 0.0833415	total: 1000ms	remaining: 134ms
# 882:	learn: 0.0832218	total: 1s	remaining: 133ms
# 883:	learn: 0.0830916	total: 1s	remaining: 131ms
# 884:	learn: 0.0829563	total: 1s	remaining: 130ms
# 885:	learn: 0.0828723	total: 1s	remaining: 129ms
# 886:	learn: 0.0827948	total: 1s	remaining: 128ms
# 887:	learn: 0.0826601	total: 1s	remaining: 127ms
# 888:	learn: 0.0825004	total: 1s	remaining: 126ms
# 889:	learn: 0.0824255	total: 1.01s	remaining: 124ms
# 890:	learn: 0.0823304	total: 1.01s	remaining: 123ms
# 891:	learn: 0.0822989	total: 1.01s	remaining: 122ms
# 892:	learn: 0.0822036	total: 1.01s	remaining: 121ms
# 893:	learn: 0.0821257	total: 1.01s	remaining: 120ms
# 894:	learn: 0.0819854	total: 1.01s	remaining: 119ms
# 895:	learn: 0.0819142	total: 1.01s	remaining: 117ms
# 896:	learn: 0.0818263	total: 1.01s	remaining: 116ms
# 897:	learn: 0.0816778	total: 1.01s	remaining: 115ms
# 898:	learn: 0.0815295	total: 1.01s	remaining: 114ms
# 899:	learn: 0.0814685	total: 1.01s	remaining: 113ms
# 900:	learn: 0.0813916	total: 1.01s	remaining: 112ms
# 901:	learn: 0.0812163	total: 1.02s	remaining: 110ms
# 902:	learn: 0.0811654	total: 1.02s	remaining: 109ms
# 903:	learn: 0.0811288	total: 1.02s	remaining: 108ms
# 904:	learn: 0.0810675	total: 1.02s	remaining: 107ms
# 905:	learn: 0.0810630	total: 1.02s	remaining: 106ms
# 906:	learn: 0.0809655	total: 1.02s	remaining: 105ms
# 907:	learn: 0.0807921	total: 1.02s	remaining: 104ms
# 908:	learn: 0.0806998	total: 1.02s	remaining: 102ms
# 909:	learn: 0.0806067	total: 1.02s	remaining: 101ms
# 910:	learn: 0.0804943	total: 1.02s	remaining: 100ms
# 911:	learn: 0.0804380	total: 1.02s	remaining: 99ms
# 912:	learn: 0.0803461	total: 1.03s	remaining: 97.8ms
# 913:	learn: 0.0802339	total: 1.03s	remaining: 96.7ms
# 914:	learn: 0.0801791	total: 1.03s	remaining: 95.5ms
# 915:	learn: 0.0800928	total: 1.03s	remaining: 94.4ms
# 916:	learn: 0.0800199	total: 1.03s	remaining: 93.2ms
# 917:	learn: 0.0798952	total: 1.03s	remaining: 92.1ms
# 918:	learn: 0.0798204	total: 1.03s	remaining: 90.9ms
# 919:	learn: 0.0797492	total: 1.03s	remaining: 89.8ms
# 920:	learn: 0.0796738	total: 1.03s	remaining: 88.6ms
# 921:	learn: 0.0795302	total: 1.03s	remaining: 87.5ms
# 922:	learn: 0.0794704	total: 1.03s	remaining: 86.3ms
# 923:	learn: 0.0793521	total: 1.03s	remaining: 85.2ms
# 924:	learn: 0.0793022	total: 1.04s	remaining: 84.1ms
# 925:	learn: 0.0791746	total: 1.04s	remaining: 82.9ms
# 926:	learn: 0.0790660	total: 1.04s	remaining: 81.8ms
# 927:	learn: 0.0789864	total: 1.04s	remaining: 80.6ms
# 928:	learn: 0.0788872	total: 1.04s	remaining: 79.5ms
# 929:	learn: 0.0787963	total: 1.04s	remaining: 78.4ms
# 930:	learn: 0.0786503	total: 1.04s	remaining: 77.2ms
# 931:	learn: 0.0785192	total: 1.04s	remaining: 76.1ms
# 932:	learn: 0.0784074	total: 1.04s	remaining: 75ms
# 933:	learn: 0.0783204	total: 1.04s	remaining: 73.8ms
# 934:	learn: 0.0781973	total: 1.04s	remaining: 72.7ms
# 935:	learn: 0.0781364	total: 1.05s	remaining: 71.6ms
# 936:	learn: 0.0780516	total: 1.05s	remaining: 70.4ms
# 937:	learn: 0.0779536	total: 1.05s	remaining: 69.3ms
# 938:	learn: 0.0778388	total: 1.05s	remaining: 68.2ms
# 939:	learn: 0.0777343	total: 1.05s	remaining: 67.1ms
# 940:	learn: 0.0775955	total: 1.05s	remaining: 66ms
# 941:	learn: 0.0775164	total: 1.05s	remaining: 64.9ms
# 942:	learn: 0.0774359	total: 1.05s	remaining: 63.8ms
# 943:	learn: 0.0773029	total: 1.06s	remaining: 62.7ms
# 944:	learn: 0.0771827	total: 1.06s	remaining: 61.5ms
# 945:	learn: 0.0770833	total: 1.06s	remaining: 60.5ms
# 946:	learn: 0.0769664	total: 1.06s	remaining: 59.3ms
# 947:	learn: 0.0768378	total: 1.06s	remaining: 58.2ms
# 948:	learn: 0.0767610	total: 1.06s	remaining: 57.1ms
# 949:	learn: 0.0766673	total: 1.06s	remaining: 55.9ms
# 950:	learn: 0.0766078	total: 1.06s	remaining: 54.8ms
# 951:	learn: 0.0765282	total: 1.06s	remaining: 53.7ms
# 952:	learn: 0.0764303	total: 1.06s	remaining: 52.6ms
# 953:	learn: 0.0763298	total: 1.07s	remaining: 51.4ms
# 954:	learn: 0.0761904	total: 1.07s	remaining: 50.3ms
# 955:	learn: 0.0760695	total: 1.07s	remaining: 49.2ms
# 956:	learn: 0.0759944	total: 1.07s	remaining: 48.1ms
# 957:	learn: 0.0759121	total: 1.07s	remaining: 47ms
# 958:	learn: 0.0757650	total: 1.07s	remaining: 45.9ms
# 959:	learn: 0.0757287	total: 1.07s	remaining: 44.7ms
# 960:	learn: 0.0756070	total: 1.07s	remaining: 43.6ms
# 961:	learn: 0.0754883	total: 1.07s	remaining: 42.5ms
# 962:	learn: 0.0753694	total: 1.08s	remaining: 41.4ms
# 963:	learn: 0.0752270	total: 1.08s	remaining: 40.3ms
# 964:	learn: 0.0751347	total: 1.08s	remaining: 39.1ms
# 965:	learn: 0.0750783	total: 1.08s	remaining: 38ms
# 966:	learn: 0.0749531	total: 1.08s	remaining: 36.9ms
# 967:	learn: 0.0748756	total: 1.08s	remaining: 35.8ms
# 968:	learn: 0.0748323	total: 1.08s	remaining: 34.6ms
# 969:	learn: 0.0747227	total: 1.08s	remaining: 33.5ms
# 970:	learn: 0.0746486	total: 1.08s	remaining: 32.4ms
# 971:	learn: 0.0744984	total: 1.09s	remaining: 31.3ms
# 972:	learn: 0.0743702	total: 1.09s	remaining: 30.2ms
# 973:	learn: 0.0742515	total: 1.09s	remaining: 29ms
# 974:	learn: 0.0741470	total: 1.09s	remaining: 27.9ms
# 975:	learn: 0.0740640	total: 1.09s	remaining: 26.8ms
# 976:	learn: 0.0740044	total: 1.09s	remaining: 25.7ms
# 977:	learn: 0.0739081	total: 1.09s	remaining: 24.6ms
# 978:	learn: 0.0738326	total: 1.09s	remaining: 23.4ms
# 979:	learn: 0.0737187	total: 1.09s	remaining: 22.3ms
# 980:	learn: 0.0736138	total: 1.09s	remaining: 21.2ms
# 981:	learn: 0.0734996	total: 1.09s	remaining: 20.1ms
# 982:	learn: 0.0733958	total: 1.1s	remaining: 19ms
# 983:	learn: 0.0732965	total: 1.1s	remaining: 17.8ms
# 984:	learn: 0.0732363	total: 1.1s	remaining: 16.7ms
# 985:	learn: 0.0731604	total: 1.1s	remaining: 15.6ms
# 986:	learn: 0.0730338	total: 1.1s	remaining: 14.5ms
# 987:	learn: 0.0728992	total: 1.1s	remaining: 13.4ms
# 988:	learn: 0.0727818	total: 1.1s	remaining: 12.3ms
# 989:	learn: 0.0727231	total: 1.1s	remaining: 11.1ms
# 990:	learn: 0.0726414	total: 1.1s	remaining: 10ms
# 991:	learn: 0.0725236	total: 1.1s	remaining: 8.9ms
# 992:	learn: 0.0723566	total: 1.1s	remaining: 7.79ms
# 993:	learn: 0.0723081	total: 1.1s	remaining: 6.67ms
# 994:	learn: 0.0721730	total: 1.11s	remaining: 5.56ms
# 995:	learn: 0.0721084	total: 1.11s	remaining: 4.45ms
# 996:	learn: 0.0720422	total: 1.11s	remaining: 3.33ms
# 997:	learn: 0.0719489	total: 1.11s	remaining: 2.22ms
# 998:	learn: 0.0718417	total: 1.11s	remaining: 1.11ms
# 999:	learn: 0.0717259	total: 1.11s	remaining: 0us
# Confusion Matrix
#
#
# [[42 14]
#  [14 52]]
#
#
# Accuracy Score for Logistic Regression: 77.0
# ---------------------------------------------
# Precision Score for Logistic Regression: 79.0
# ---------------------------------------------
# Recall Score for Logistic Regression: 78.8
# ---------------------------------------------
# f1 Score for Logistic Regression: 78.8

# %%
y_train.map(int)
# Out:
# 134    1
# 277    0
# 288    0
# 161    1
# 181    0
#       ..
# 265    0
# 231    0
# 195    0
# 87     1
# 34     1
# Name: target, Length: 181, dtype: int64

# %%
a, p, r, f = [], [], [], []
for model in [model1, model2, model3, model4, model5, model6, model7, model8, model9, model10]:
    a.append(accuracy_score(y_test, model.predict(X_test)))
    p.append(precision_score(y_test, model.predict(X_test)))
    r.append(recall_score(y_test, model.predict(X_test)))
    f.append(f1_score(y_test, model.predict(X_test)))

# %%
model_score = pd.DataFrame([a,p,r,f],
             columns = ['LR',
                        'KNN',
                        'SVC',
                        'NB',
                        'DT',
                        'RF',
                        'Ada',
                        'XGB',
                        'LGBM',
                        'Cat']).T.sort_values(by=3, ascending=False).rename(columns={0:'Accuracy', 1: 'Precision', 2: 'Recall', 3: 'F1'})

# %% [markdown]
# #### Model Feature Importance

# %%
imp_feature = pd.DataFrame({'Feature': ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal'], 'Importance': model5.feature_importances_})
plt.figure(figsize=(15,8))
plt.title("Decision Tree Feature Importance ")
plt.xlabel("Importance ", fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel("Features", fontsize=14)
plt.barh(imp_feature['Feature'],imp_feature['Importance'], color = ['turquoise', 'lightseagreen', 'darkturquoise', 
                                                                   'teal', 'cadetblue', 'darkslategrey','darkseagreen',
                                                                   'darkolivegreen', 'slategrey', 'olive', 'darkkhaki',
                                                                   'forestgreen', 'steelblue', 'gray'])
plt.show()

# %%
imp_feature = pd.DataFrame({'Feature': ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal'], 'Importance': model6.feature_importances_})
plt.figure(figsize=(15,8))
plt.title("Random Forest Feature Importance ")
plt.xlabel("Importance ")
plt.ylabel("Features")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.barh(imp_feature['Feature'],imp_feature['Importance'], color = ['turquoise', 'lightseagreen', 'darkturquoise', 
                                                                    'teal', 'cadetblue', 'darkslategrey',
                                                                    'darkseagreen','darkolivegreen', 'slategrey', 
                                                                   'olive', 'darkkhaki','forestgreen', 'steelblue',
                                                                    'gray'])
plt.show()

# %%
imp_feature = pd.DataFrame({'Feature': ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal'], 'Importance': model7.feature_importances_})
plt.figure(figsize=(15,8))
plt.title("AdaBoost Feature Importance ")
plt.xlabel("Importance ")
plt.ylabel("Features")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.barh(imp_feature['Feature'],imp_feature['Importance'],color = ['turquoise', 'lightseagreen', 'darkturquoise', 
                                                                    'teal', 'cadetblue', 'darkslategrey',
                                                                    'darkseagreen','darkolivegreen', 'slategrey', 
                                                                   'olive', 'darkkhaki','forestgreen', 'steelblue',
                                                                    'gray'])
plt.show()

# %%
imp_feature = pd.DataFrame({'Feature': ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal'], 'Importance': model8.feature_importances_})
plt.figure(figsize=(15,8))
plt.title("bXGBoost Feature Importance ")
plt.xlabel("importance ")
plt.ylabel("features")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.barh(imp_feature['Feature'],imp_feature['Importance'],color = ['turquoise', 'lightseagreen', 'darkturquoise', 
                                                                    'teal', 'cadetblue', 'darkslategrey',
                                                                    'darkseagreen','darkolivegreen', 'slategrey', 
                                                                   'olive', 'darkkhaki','forestgreen', 'steelblue',
                                                                    'gray'])
plt.show()

# %%
imp_feature = pd.DataFrame({'Feature': ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal'], 'Importance': model9.feature_importances_})
plt.figure(figsize=(15,8))
plt.title("LightGBM Feature Importance ")
plt.xlabel("Importance ")
plt.ylabel("Features")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.barh(imp_feature['Feature'],imp_feature['Importance'],color = ['turquoise', 'lightseagreen', 'darkturquoise', 
                                                                    'teal', 'cadetblue', 'darkslategrey',
                                                                    'darkseagreen','darkolivegreen', 'slategrey', 
                                                                   'olive', 'darkkhaki','forestgreen', 'steelblue',
                                                                    'gray'])
plt.show()

# %%
imp_feature = pd.DataFrame({'Feature': ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal'], 'Importance': model10.feature_importances_})
plt.figure(figsize=(15,8))
plt.title("CatBoost Feature Importance ")
plt.xlabel("Importance ")
plt.ylabel("Features")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.barh(imp_feature['Feature'],imp_feature['Importance'],color = ['turquoise', 'lightseagreen', 'darkturquoise', 
                                                                   'teal', 'cadetblue', 'darkslategrey',
                                                                   'darkseagreen','darkolivegreen', 'slategrey',
                                                                   'olive', 'darkkhaki','forestgreen', 'steelblue',
                                                                    'gray'])
                                                                 
                                                                   
plt.show()

# %% [markdown]
# ## Model Evaluation

# %%
# Create a heatmap of the summary
plt.figure(figsize= (10,10))
sns.heatmap(model_score, annot=True, cmap = 'coolwarm')
plt.show()

# %%
models = pd.DataFrame({'Models': ['Logistic Regression','KNN','SVC','Gaussian NB','Decision Tree', 'Random Forest',
                                 'AdaBoost', 'XGBoost', 'LightGBM', 'CatBoost'],
                      'Accuracy': [accuracy_score(y_test, y_pred1).round(3)*100, 
                                   accuracy_score(y_test, y_pred2).round(3)*100, 
                                  accuracy_score(y_test, y_pred3).round(3)*100,
                                  accuracy_score(y_test, y_pred4).round(3)*100,
                                  accuracy_score(y_test, y_pred5).round(3)*100,
                                  accuracy_score(y_test, y_pred6).round(3)*100,
                                  accuracy_score(y_test, y_pred7).round(3)*100,
                                  accuracy_score(y_test, y_pred8).round(3)*100,
                                  accuracy_score(y_test, y_pred9).round(3)*100,
                                  accuracy_score(y_test, y_pred10).round(3)*100]})

# %%
sns.set(style='white')
fig = plt.figure(figsize=(15,10))
sns.barplot(data=models, x=models.Models, y=models.Accuracy, palette='RdBu')
plt.show()
