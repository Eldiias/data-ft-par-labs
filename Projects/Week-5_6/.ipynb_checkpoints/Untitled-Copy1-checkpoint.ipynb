# %% [markdown]
# ### Importing and Cleaning Dataset

# %%
# importing libraries as needed

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
from statsmodels.api import OLS
from statsmodels.api import add_constant
# %matplotlib inline
sns.set()
# Out:
# /Users/laetitia/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('/Users/laetitia/IronHack/data-ft-par-labs/Projects/Week-5_6/hotel_bookings.csv')

# %%
df.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
#
# [3 rows x 32 columns]

# %%
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# #### Getting country code names from the internet

# %%
# Getting Country data from google

# countries = pd.read_html('https://en.wikipedia.org/wiki/ISO_3166-1')
# len(countries)
# countries1 = countries[1]

# Assigning Country Names

# countries2 = countries1.drop(['Alpha-2 code', 'Numeric code', 'Link to ISO 3166-2 subdivision codes', 'Independent'], axis=1)
# change_name = countries2.rename(columns={'Alpha-3 code':'country'})
# data = df1.merge(change_name, on='country', how='left')

# Renaming Country Names

# data1 = data.rename(columns={'English short name (using title case)':'country_name', 'country':'country_code'})
# hotel_bookings = data1.copy()

# Updating missing names

# hotel_bookings.loc[hotel_bookings .country_code == 'CN', 'country_name'] = 'China' 
# hotel_bookings.loc[hotel_bookings .country_code == 'TMP', 'country_name'] = 'East Timor'

# hotel_bookings.head(2)

# %% [markdown]
# ----

# %% [markdown]
# ### Visualizations

# %% [markdown]
# #### 1. Revenue per Trip
#
# - 1. First we determine the average daily rates

# %%
pd.set_option('display.max_rows', None, 'display.max_columns', None)

# %%
# Checking the adr shows we have some outliers like -6.38 and 5400

pd.qcut(df['adr'], 4).value_counts()
# Out:
# (94.575, 126.0]    30511
# (-6.381, 69.29]    29870
# (69.29, 94.575]    29825
# (126.0, 5400.0]    29184
# Name: adr, dtype: int64

# %%
sns.boxplot(x=df['adr'])
# Out:
# <AxesSubplot:xlabel='adr'>

# %%
# Dropping values below 0 and above 5400

df = df.loc[(df['adr']>20) & (df['adr']<400)]
pd.qcut(df['adr'], 4).value_counts()
# Out:
# (71.0, 95.0]                  29822
# (20.878999999999998, 71.0]    29253
# (126.0, 397.38]               29176
# (95.0, 126.0]                 28751
# Name: adr, dtype: int64

# %%
# Plotting boxplot to see if better

sns.boxenplot(x=df['adr'])
plt.show()

# %%
df.shape
# Out:
# (117002, 32)

# %%
# Calculating the revenue per total stay from the adr(average daily rate)

df['revenue_per_stay'] = df['adr'] * (df['stays_in_week_nights'] + df['stays_in_weekend_nights'])
df.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 2                        0                     1       1       0.0       0
# 3                        0                     1       1       0.0       0
# 4                        0                     2       2       0.0       0
#
#   meal country market_segment distribution_channel  is_repeated_guest  \
# 2   BB     GBR         Direct               Direct                  0
# 3   BB     GBR      Corporate            Corporate                  0
# 4   BB     GBR      Online TA                TA/TO                  0
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 2                       0                               0                  A
# 3                       0                               0                  A
# 4                       0                               0                  A
#
#   assigned_room_type  booking_changes deposit_type  agent  company  \
# 2                  C                0   No Deposit    NaN      NaN
# 3                  A                0   No Deposit  304.0      NaN
# 4                  A                0   No Deposit  240.0      NaN
#
#    days_in_waiting_list customer_type   adr  required_car_parking_spaces  \
# 2                     0     Transient  75.0                            0
# 3                     0     Transient  75.0                            0
# 4                     0     Transient  98.0                            0
#
#    total_of_special_requests reservation_status reservation_status_date  \
# 2                          0          Check-Out              2015-07-02
# 3                          0          Check-Out              2015-07-02
# 4                          1          Check-Out              2015-07-03
#
#    revenue_per_stay
# 2              75.0
# 3              75.0
# 4             196.0

# %%
# Calculating the yearly revenue

revenue_yearly = df.groupby(['arrival_date_year'])['revenue_per_stay'].sum().reset_index()
revenue_yearly
# Out:
#    arrival_date_year  revenue_per_stay
# 0               2015        6812538.13
# 1               2016       18858764.70
# 2               2017       17016849.48

# %%
# Plotting yearly revenue

plt.figure(figsize=(10,6))
sns.barplot(data=revenue_yearly, x='arrival_date_year', y='revenue_per_stay',  palette='mako')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# Calculating the monthly revenue

revenue_monthly = df.groupby(['arrival_date_year','arrival_date_month'])['revenue_per_stay'].sum()
revenue_monthly  = revenue_monthly.reset_index()
revenue_monthly;

# %%
# Plotting montly revenue

plt.figure(figsize=(15,9))
months = ['January','February','March','April','May','June','July','August','September','October','November','December']
sns.barplot(data=revenue_monthly, x='arrival_date_month', y='revenue_per_stay', hue='arrival_date_year', 
            palette='mako', order=months)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# #### Observations
#
# - Data is complete only for 2016
# - Revenue seem to be higher during summer months (June, July, August)

# %% [markdown]
# #### Data is complete for 2016, so we drop 2015 and 2017 data and use 2016 data for our ananlysis model prediction

# %%
hotel_bookings_2016 = df[df['arrival_date_year'] == 2016]
hotel_bookings_2016.shape
# Out:
# (55608, 33)

# %%
hotel_bookings_2016.tail(3)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 104147  City Hotel            0        107               2016
# 104216  City Hotel            0        310               2016
# 104219  City Hotel            0        310               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 104147           December                        53
# 104216           December                        53
# 104219           December                        53
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 104147                         31                        2
# 104216                         27                        2
# 104219                         27                        2
#
#         stays_in_week_nights  adults  children  babies meal country  \
# 104147                     5       2       0.0       0   BB     FRA
# 104216                    10       2       0.0       0   SC     DEU
# 104219                    10       2       0.0       0   SC     DEU
#
#        market_segment distribution_channel  is_repeated_guest  \
# 104147  Offline TA/TO                TA/TO                  0
# 104216      Online TA                TA/TO                  0
# 104219      Online TA                TA/TO                  0
#
#         previous_cancellations  previous_bookings_not_canceled  \
# 104147                       0                               0
# 104216                       0                               0
# 104219                       0                               0
#
#        reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 104147                  A                  B                0   No Deposit
# 104216                  A                  A                2   No Deposit
# 104219                  A                  A                2   No Deposit
#
#         agent  company  days_in_waiting_list    customer_type     adr  \
# 104147   28.0      NaN                     0        Transient  103.57
# 104216    9.0      NaN                     0  Transient-Party   68.57
# 104219    9.0      NaN                     0  Transient-Party   68.57
#
#         required_car_parking_spaces  total_of_special_requests  \
# 104147                            0                          0
# 104216                            0                          2
# 104219                            0                          2
#
#        reservation_status reservation_status_date  revenue_per_stay
# 104147          Check-Out              2017-01-07            724.99
# 104216          Check-Out              2017-01-08            822.84
# 104219          Check-Out              2017-01-08            822.84

# %%
hotel_type_cancel = hotel_bookings_2016.groupby(['hotel'])['is_canceled'].count().reset_index()
hotel_type_cancel
# Out:
#           hotel  is_canceled
# 0    City Hotel        37496
# 1  Resort Hotel        18112

# %%
# Plotting cancellation by hotel type

plt.figure(figsize=(10,6))
sns.barplot(data=hotel_type_cancel, x='hotel', y='is_canceled',  palette='mako')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# more cancelations at the city hotels than resort

# %%
# which is more expensive on average, city hotel or resort?

hotel_type_revenue = hotel_bookings_2016.groupby(['hotel'])['adr'].mean().reset_index()
hotel_type_revenue
# Out:
#           hotel         adr
# 0    City Hotel  105.082739
# 1  Resort Hotel   89.898830

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=hotel_type_revenue, x='hotel', y='adr', palette='mako')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### Outliers

# %% [markdown]
# #### Dropping weeeknights greter 5 and weekend nights greater than 2
#
# - Some stays are for months and influence pricing, thus dropped from dataframe for better model preediction

# %%
hotel_bookings_2016 = hotel_bookings_2016.loc[(hotel_bookings_2016['stays_in_weekend_nights']<=2) &
                                             (hotel_bookings_2016['stays_in_week_nights']<=5)] 
                                             
hotel_bookings_2016.shape
# Out:
# (53317, 33)

# %% [markdown]
# ---

# %% [markdown]
# #### Dropping columns as needed

# %%
bookings_2016 = hotel_bookings_2016.drop(['arrival_date_year','adr','agent','company',
                                         'arrival_date_week_number','arrival_date_day_of_month','is_canceled',
                                         'country','lead_time','booking_changes','reservation_status_date',
                                         'assigned_room_type','total_of_special_requests'], axis=1)
bookings_2016.shape
# Out:
# (54063, 20)

# %%
bookings_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54063 entries, 3738 to 104219
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           54063 non-null  object
#  1   arrival_date_month              54063 non-null  object
#  2   stays_in_weekend_nights         54063 non-null  int64
#  3   stays_in_week_nights            54063 non-null  int64
#  4   adults                          54063 non-null  int64
#  5   children                        54063 non-null  float64
#  6   babies                          54063 non-null  int64
#  7   meal                            54063 non-null  object
#  8   market_segment                  54063 non-null  object
#  9   distribution_channel            54063 non-null  object
#  10  is_repeated_guest               54063 non-null  int64
#  11  previous_cancellations          54063 non-null  int64
#  12  previous_bookings_not_canceled  54063 non-null  int64
#  13  reserved_room_type              54063 non-null  object
#  14  deposit_type                    54063 non-null  object
#  15  days_in_waiting_list            54063 non-null  int64
#  16  customer_type                   54063 non-null  object
#  17  required_car_parking_spaces     54063 non-null  int64
#  18  reservation_status              54063 non-null  object
#  19  revenue_per_stay                54063 non-null  float64
# dtypes: float64(2), int64(9), object(9)
# memory usage: 8.7+ MB

# %%
pd.qcut(bookings_2016['revenue_per_stay'],5).value_counts()
# Out:
# (24.999, 124.0]    11004
# (303.0, 448.2]     10817
# (213.3, 303.0]     10810
# (448.2, 2482.0]    10807
# (124.0, 213.3]     10625
# Name: revenue_per_stay, dtype: int64

# %% [markdown]
# ### Checking for correlations

# %%
bookings_2016.corr().revenue_per_stay.abs().sort_values()
# Out:
# required_car_parking_spaces       0.021268
# days_in_waiting_list              0.043485
# babies                            0.051902
# previous_cancellations            0.053777
# previous_bookings_not_canceled    0.069087
# is_repeated_guest                 0.123333
# children                          0.242046
# adults                            0.256667
# stays_in_weekend_nights           0.475001
# stays_in_week_nights              0.670406
# revenue_per_stay                  1.000000
# Name: revenue_per_stay, dtype: float64

# %%
plt.figure(figsize=(15,12))
cmap = sns.diverging_palette(220, 15, as_cmap=True)
# sns.set(font_scale=1.2)
sns.heatmap(bookings_2016.corr(), annot=True, annot_kws={"fontsize":12}, cmap=cmap)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Linear Regression
#
# Modeling data to predict the pricing of hotel rooms

# %% [markdown]
# #### Predicting daily rates

# %%
bookings_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54063 entries, 3738 to 104219
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           54063 non-null  object
#  1   arrival_date_month              54063 non-null  object
#  2   stays_in_weekend_nights         54063 non-null  int64
#  3   stays_in_week_nights            54063 non-null  int64
#  4   adults                          54063 non-null  int64
#  5   children                        54063 non-null  float64
#  6   babies                          54063 non-null  int64
#  7   meal                            54063 non-null  object
#  8   market_segment                  54063 non-null  object
#  9   distribution_channel            54063 non-null  object
#  10  is_repeated_guest               54063 non-null  int64
#  11  previous_cancellations          54063 non-null  int64
#  12  previous_bookings_not_canceled  54063 non-null  int64
#  13  reserved_room_type              54063 non-null  object
#  14  deposit_type                    54063 non-null  object
#  15  days_in_waiting_list            54063 non-null  int64
#  16  customer_type                   54063 non-null  object
#  17  required_car_parking_spaces     54063 non-null  int64
#  18  reservation_status              54063 non-null  object
#  19  revenue_per_stay                54063 non-null  float64
# dtypes: float64(2), int64(9), object(9)
# memory usage: 8.7+ MB

# %%
bookings_2016.nunique()
# Out:
# hotel                                2
# arrival_date_month                  12
# stays_in_weekend_nights              3
# stays_in_week_nights                11
# adults                               5
# children                             4
# babies                               4
# meal                                 5
# market_segment                       7
# distribution_channel                 4
# is_repeated_guest                    2
# previous_cancellations               9
# previous_bookings_not_canceled      58
# reserved_room_type                   8
# deposit_type                         3
# days_in_waiting_list                93
# customer_type                        4
# required_car_parking_spaces          4
# reservation_status                   3
# revenue_per_stay                  8437
# dtype: int64

# %%
# Creating dummies for categorical data

hotel_booking = pd.get_dummies(data=bookings_2016, columns=['arrival_date_month','meal','market_segment',
                                                            'distribution_channel','reserved_room_type',
                                                           'deposit_type','customer_type',
                                                           'reservation_status','hotel'],drop_first=True)

# %% [markdown]
# #### Creating Features (independent variables) and Targets (dependent variables)

# %%
# The dependent variable (target) is the revenue_per_stay passed as revenue
# Target are the independent variables passed in the dataframe, X

X, revenue = add_constant(hotel_booking, has_constant='add').drop('revenue_per_stay', axis=1), hotel_booking.revenue_per_stay

# %% [markdown]
# #### Generating the model via Ordinary Least Squares

# %%
model_fit = OLS(revenue.map(np.log), X).fit()
print(model_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       revenue_per_stay   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     4905.
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):               0.00
# Time:                        21:26:22   Log-Likelihood:                -15949.
# No. Observations:               54063   AIC:                         3.200e+04
# Df Residuals:                   54013   BIC:                         3.244e+04
# Df Model:                          49
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              4.1622      0.035    118.048      0.000       4.093       4.231
# stays_in_weekend_nights            0.3074      0.002    172.177      0.000       0.304       0.311
# stays_in_week_nights               0.3053      0.001    290.134      0.000       0.303       0.307
# adults                             0.1120      0.003     34.631      0.000       0.106       0.118
# children                           0.0815      0.005     17.237      0.000       0.072       0.091
# babies                             0.0558      0.014      3.922      0.000       0.028       0.084
# is_repeated_guest                 -0.1006      0.010     -9.577      0.000      -0.121      -0.080
# previous_cancellations             0.0169      0.004      4.262      0.000       0.009       0.025
# previous_bookings_not_canceled    -0.0044      0.001     -3.878      0.000      -0.007      -0.002
# days_in_waiting_list              -0.0002   6.02e-05     -4.094      0.000      -0.000      -0.000
# required_car_parking_spaces        0.0996      0.006     16.992      0.000       0.088       0.111
# arrival_date_month_August          0.3134      0.007     47.400      0.000       0.300       0.326
# arrival_date_month_December       -0.0917      0.007    -12.992      0.000      -0.106      -0.078
# arrival_date_month_February       -0.1853      0.007    -26.256      0.000      -0.199      -0.171
# arrival_date_month_January        -0.2651      0.008    -31.220      0.000      -0.282      -0.248
# arrival_date_month_July            0.2245      0.007     33.069      0.000       0.211       0.238
# arrival_date_month_June            0.1820      0.006     28.027      0.000       0.169       0.195
# arrival_date_month_March          -0.1113      0.007    -16.875      0.000      -0.124      -0.098
# arrival_date_month_May             0.1222      0.006     19.101      0.000       0.110       0.135
# arrival_date_month_November       -0.0575      0.007     -8.489      0.000      -0.071      -0.044
# arrival_date_month_October         0.0911      0.006     14.698      0.000       0.079       0.103
# arrival_date_month_September       0.2393      0.006     37.322      0.000       0.227       0.252
# meal_FB                            0.5633      0.019     29.812      0.000       0.526       0.600
# meal_HB                            0.2832      0.005     57.992      0.000       0.274       0.293
# meal_SC                           -0.1541      0.005    -28.340      0.000      -0.165      -0.143
# meal_Undefined                     0.6536      0.015     44.562      0.000       0.625       0.682
# market_segment_Complementary      -0.4634      0.082     -5.674      0.000      -0.624      -0.303
# market_segment_Corporate          -0.2250      0.032     -7.014      0.000      -0.288      -0.162
# market_segment_Direct             -0.0082      0.034     -0.241      0.810      -0.075       0.059
# market_segment_Groups             -0.2116      0.033     -6.424      0.000      -0.276      -0.147
# market_segment_Offline TA/TO      -0.1122      0.033     -3.411      0.001      -0.177      -0.048
# market_segment_Online TA           0.1514      0.033      4.605      0.000       0.087       0.216
# distribution_channel_Direct        0.0436      0.014      3.191      0.001       0.017       0.070
# distribution_channel_GDS           0.2396      0.034      6.985      0.000       0.172       0.307
# distribution_channel_TA/TO        -0.0579      0.010     -5.547      0.000      -0.078      -0.037
# reserved_room_type_B              -0.1143      0.013     -8.466      0.000      -0.141      -0.088
# reserved_room_type_C               0.3901      0.022     18.072      0.000       0.348       0.432
# reserved_room_type_D               0.1543      0.004     36.329      0.000       0.146       0.163
# reserved_room_type_E               0.2792      0.007     39.865      0.000       0.265       0.293
# reserved_room_type_F               0.3906      0.011     37.187      0.000       0.370       0.411
# reserved_room_type_G               0.5501      0.013     42.789      0.000       0.525       0.575
# reserved_room_type_H               0.5960      0.020     29.534      0.000       0.556       0.636
# deposit_type_Non Refund            0.1269      0.007     18.709      0.000       0.114       0.140
# deposit_type_Refundable            0.2768      0.030      9.322      0.000       0.219       0.335
# customer_type_Group                0.0599      0.030      1.987      0.047       0.001       0.119
# customer_type_Transient            0.1773      0.015     12.022      0.000       0.148       0.206
# customer_type_Transient-Party      0.2629      0.015     17.553      0.000       0.234       0.292
# reservation_status_Check-Out      -0.0470      0.004    -13.205      0.000      -0.054      -0.040
# reservation_status_No-Show        -0.0367      0.014     -2.666      0.008      -0.064      -0.010
# hotel_Resort Hotel                -0.4739      0.004   -129.173      0.000      -0.481      -0.467
# ==============================================================================
# Omnibus:                      963.933   Durbin-Watson:                   0.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1870.719
# Skew:                           0.090   Prob(JB):                         0.00
# Kurtosis:                       3.893   Cond. No.                     1.67e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ---

# %% [markdown]
# - From the model above, there are a few independent variables such as reservation cancelled that are insignificant
# - These insignificant variables will be dropped to improve model prediction
# - There is also an indication of multicolinearity, that is some independent variables are dependent on each other, these are to be eliminated and the aim is to have no multicolinearity

# %% [markdown]
# #### Improving Regression Model

# %%
columns_to_drop = ['market_segment_Direct','customer_type_Group']

model_fit = OLS(revenue.map(np.log), X.drop(columns_to_drop, axis=1)).fit()
print(model_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       revenue_per_stay   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     5113.
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):               0.00
# Time:                        21:26:23   Log-Likelihood:                -15951.
# No. Observations:               54063   AIC:                         3.200e+04
# Df Residuals:                   54015   BIC:                         3.242e+04
# Df Model:                          47
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              4.1704      0.020    208.504      0.000       4.131       4.210
# stays_in_weekend_nights            0.3073      0.002    172.187      0.000       0.304       0.311
# stays_in_week_nights               0.3052      0.001    290.704      0.000       0.303       0.307
# adults                             0.1119      0.003     34.696      0.000       0.106       0.118
# children                           0.0815      0.005     17.231      0.000       0.072       0.091
# babies                             0.0558      0.014      3.921      0.000       0.028       0.084
# is_repeated_guest                 -0.0983      0.010     -9.417      0.000      -0.119      -0.078
# previous_cancellations             0.0166      0.004      4.204      0.000       0.009       0.024
# previous_bookings_not_canceled    -0.0045      0.001     -3.901      0.000      -0.007      -0.002
# days_in_waiting_list              -0.0002   6.02e-05     -4.079      0.000      -0.000      -0.000
# required_car_parking_spaces        0.0996      0.006     16.986      0.000       0.088       0.111
# arrival_date_month_August          0.3134      0.007     47.407      0.000       0.300       0.326
# arrival_date_month_December       -0.0915      0.007    -12.961      0.000      -0.105      -0.078
# arrival_date_month_February       -0.1852      0.007    -26.245      0.000      -0.199      -0.171
# arrival_date_month_January        -0.2652      0.008    -31.238      0.000      -0.282      -0.249
# arrival_date_month_July            0.2244      0.007     33.052      0.000       0.211       0.238
# arrival_date_month_June            0.1818      0.006     28.002      0.000       0.169       0.194
# arrival_date_month_March          -0.1114      0.007    -16.881      0.000      -0.124      -0.098
# arrival_date_month_May             0.1221      0.006     19.084      0.000       0.110       0.135
# arrival_date_month_November       -0.0574      0.007     -8.481      0.000      -0.071      -0.044
# arrival_date_month_October         0.0912      0.006     14.714      0.000       0.079       0.103
# arrival_date_month_September       0.2392      0.006     37.318      0.000       0.227       0.252
# meal_FB                            0.5636      0.019     29.845      0.000       0.527       0.601
# meal_HB                            0.2831      0.005     58.003      0.000       0.274       0.293
# meal_SC                           -0.1542      0.005    -28.367      0.000      -0.165      -0.144
# meal_Undefined                     0.6536      0.015     44.572      0.000       0.625       0.682
# market_segment_Complementary      -0.4563      0.075     -6.096      0.000      -0.603      -0.310
# market_segment_Corporate          -0.2192      0.014    -15.646      0.000      -0.247      -0.192
# market_segment_Groups             -0.2049      0.011    -18.015      0.000      -0.227      -0.183
# market_segment_Offline TA/TO      -0.1057      0.012     -9.086      0.000      -0.128      -0.083
# market_segment_Online TA           0.1584      0.011     14.000      0.000       0.136       0.181
# distribution_channel_Direct        0.0422      0.013      3.330      0.001       0.017       0.067
# distribution_channel_GDS           0.2391      0.034      6.989      0.000       0.172       0.306
# distribution_channel_TA/TO        -0.0582      0.010     -5.719      0.000      -0.078      -0.038
# reserved_room_type_B              -0.1146      0.013     -8.493      0.000      -0.141      -0.088
# reserved_room_type_C               0.3906      0.022     18.099      0.000       0.348       0.433
# reserved_room_type_D               0.1543      0.004     36.407      0.000       0.146       0.163
# reserved_room_type_E               0.2791      0.007     39.852      0.000       0.265       0.293
# reserved_room_type_F               0.3906      0.011     37.186      0.000       0.370       0.411
# reserved_room_type_G               0.5503      0.013     42.806      0.000       0.525       0.575
# reserved_room_type_H               0.5961      0.020     29.541      0.000       0.557       0.636
# deposit_type_Non Refund            0.1272      0.007     18.759      0.000       0.114       0.140
# deposit_type_Refundable            0.2803      0.030      9.475      0.000       0.222       0.338
# customer_type_Transient            0.1632      0.013     12.626      0.000       0.138       0.189
# customer_type_Transient-Party      0.2490      0.013     18.804      0.000       0.223       0.275
# reservation_status_Check-Out      -0.0470      0.004    -13.193      0.000      -0.054      -0.040
# reservation_status_No-Show        -0.0369      0.014     -2.678      0.007      -0.064      -0.010
# hotel_Resort Hotel                -0.4739      0.004   -129.301      0.000      -0.481      -0.467
# ==============================================================================
# Omnibus:                      965.279   Durbin-Watson:                   0.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1873.941
# Skew:                           0.090   Prob(JB):                         0.00
# Kurtosis:                       3.894   Cond. No.                     1.32e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ---

# %% [markdown]
# ### Checking Assumptions

# %%
import Assumptions

# %%
tester = Assumptions.Assumption_Tester_OLS(X.drop(columns_to_drop+['const','customer_type_Transient',
                                                                  'distribution_channel_TA/TO',
                                                                  'market_segment_Online TA'],  axis=1),revenue.map(np.log))
                                                                                           
tester.run_all()
# Out:
# Fitting linear regression
#
# R^2: 0.8152151874339278
#
# Coefficients
# -------------------------------------
# Intercept: 4.4259373168040765
# stays_in_weekend_nights: 0.31
# stays_in_week_nights: 0.31
# adults: 0.11
# children: 0.09
# babies: 0.05
# is_repeated_guest: -0.11
# previous_cancellations: 0.02
# previous_bookings_not_canceled: -0.0
# days_in_waiting_list: -0.0
# required_car_parking_spaces: 0.1
# arrival_date_month_August: 0.31
# arrival_date_month_December: -0.09
# arrival_date_month_February: -0.19
# arrival_date_month_January: -0.26
# arrival_date_month_July: 0.22
# arrival_date_month_June: 0.18
# arrival_date_month_March: -0.11
# arrival_date_month_May: 0.12
# arrival_date_month_November: -0.05
# arrival_date_month_October: 0.09
# arrival_date_month_September: 0.24
# meal_FB: 0.58
# meal_HB: 0.28
# meal_SC: -0.15
# meal_Undefined: 0.65
# market_segment_Complementary: -0.52
# market_segment_Corporate: -0.31
# market_segment_Groups: -0.34
# market_segment_Offline TA/TO: -0.26
# distribution_channel_Direct: -0.03
# distribution_channel_GDS: 0.3
# reserved_room_type_B: -0.12
# reserved_room_type_C: 0.38
# reserved_room_type_D: 0.16
# reserved_room_type_E: 0.28
# reserved_room_type_F: 0.38
# reserved_room_type_G: 0.54
# reserved_room_type_H: 0.59
# deposit_type_Non Refund: 0.12
# deposit_type_Refundable: 0.34
# customer_type_Transient-Party: 0.09
# reservation_status_Check-Out: -0.05
# reservation_status_No-Show: -0.04
# hotel_Resort Hotel: -0.47
#
# =======================================================================================
# Assumption 1: Linear Relationship between the Target and the Features
# Checking with a scatter plot of actual vs. predicted. Predictions should follow the diagonal line.
# /Users/laetitia/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# If non-linearity is apparent, consider adding a polynomial term
# 		or using box-cox transformation to make X or y follow normal distribution
#
#
#
# Building a correlation table
#
# =======================================================================================
#
# Parameters that are most likely VIOLATE linearity assumption and their correlation with revenue_per_stay
# children                          0.200115
# babies                            0.036902
# previous_cancellations           -0.057800
# previous_bookings_not_canceled   -0.105734
# days_in_waiting_list             -0.018186
# required_car_parking_spaces      -0.025019
# Name: revenue_per_stay, dtype: float64
# Parameters that are most likely FOLLOW linearity assumption and their correlation with revenue_per_stay
# stays_in_weekend_nights    0.499523
# stays_in_week_nights       0.687001
# adults                     0.310109
# Name: revenue_per_stay, dtype: float64
# =======================================================================================
# Assumption 2: Little to no multicollinearity among predictors
# Variance Inflation Factors (VIF)
# > 10: An indication that multicollinearity may be present
# > 100: Certain multicollinearity among the variables
# -------------------------------------
# adults: 10.406430044946951
# stays_in_week_nights: 3.919036635019224
# reservation_status_Check-Out: 3.7375078317311865
# market_segment_Groups: 2.774936417226197
# deposit_type_Non Refund: 2.6741400178904944
# market_segment_Offline TA/TO: 2.2232497488326155
# stays_in_weekend_nights: 2.187172742177709
# customer_type_Transient-Party: 2.088056102742771
# hotel_Resort Hotel: 2.0876365766890235
# children: 1.8753685008343244
# arrival_date_month_October: 1.8349535045108372
# arrival_date_month_August: 1.7678926690944268
# arrival_date_month_May: 1.7385907515113659
# arrival_date_month_September: 1.7316201794926196
# arrival_date_month_June: 1.7052869776325439
# arrival_date_month_July: 1.6718526734605177
# arrival_date_month_March: 1.6690326518796847
# arrival_date_month_November: 1.5723047625484046
# arrival_date_month_February: 1.5471998915889906
# arrival_date_month_December: 1.5173825798924676
# reserved_room_type_D: 1.5039012988120408
# previous_bookings_not_canceled: 1.4939236316896494
# is_repeated_guest: 1.4741157223745043
# market_segment_Corporate: 1.4490139726503124
# reserved_room_type_G: 1.3917659984700481
# reserved_room_type_F: 1.3869763367508086
# distribution_channel_Direct: 1.3104047858407628
# meal_SC: 1.3032227595467254
# arrival_date_month_January: 1.2879347673069959
# meal_HB: 1.2722118965574711
# previous_cancellations: 1.2677988553104436
# required_car_parking_spaces: 1.2173659786573208
# reserved_room_type_E: 1.1926508976968773
# days_in_waiting_list: 1.1247167247714966
# reserved_room_type_H: 1.113356541521785
# meal_Undefined: 1.1023467624341023
# reserved_room_type_C: 1.0946709737793787
# reserved_room_type_B: 1.0800206775964025
# meal_FB: 1.054072653722557
# reservation_status_No-Show: 1.0508173025725882
# deposit_type_Refundable: 1.0495001215621407
# babies: 1.0168051730663266
# distribution_channel_GDS: 1.0114247954229283
# market_segment_Complementary: 1.0033255637834475
#
# 1 cases of possible multicollinearity
# 0 cases of definite multicollinearity
#
# Assumption possibly satisfied
#
# Coefficient interpretability may be problematic
# Consider removing variables with a high Variance Inflation Factor (VIF)
#
# =======================================================================================
# Assumption 3: No Autocorrelation
#
# Performing Durbin-Watson Test
# Values of 1.5 < d < 2.5 generally show that there is no autocorrelation in the data
# 0 to 2< is positive autocorrelation
# >2 to 4 is negative autocorrelation
# -------------------------------------
# Durbin-Watson: 0.9192197946437942
# Signs of positive autocorrelation
#
# Assumption not satisfied
#
#
# =======================================================================================
# Assumption 4: Homoskedasticity of Error Terms
# Residuals should have relative constant variance
# If heteroskedasticity is apparent, confidence intervals and predictions will be affected
#
# Consider removing outliers and preprocessing features - nonlinear transformation can help
# {'Lagrange Multiplier': 17736.07851427076,
#  'pvalue for LM': 0.0,
#  'F stats': 599.4084640247571,
#  'pvalue for Fstats': 0.0}
# Signs of positive autocorrelation
#
# Assumption potentially not satisfied
#
#
# =======================================================================================
# Assumption 5: The error terms are kinda normally distributed
#
# Using the Anderson-Darling test for normal distribution
# p-value from the test - below 0.05 generally means non-normal: 0.0
# Residuals are not normally distributed
# /Users/laetitia/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Assumption not satisfied
#
# Confidence intervals will likely be affected
# Try performing nonlinear transformations on variables
# Building a probability plot
# In your dataset you quite fat tails. You have 0.02 potential outliers (1063 rows)
# {'Satisfied': [],
#  'Potentially': ['Linearity',
#   'Multicollinearity',
#   'Autocorrelation',
#   'Sub-Normality'],
#  'Violated': ['Autocorrelation', 'Normality']}

# %% [markdown]
# ---

# %%
sns.pairplot(bookings_2016)

# %%
columns_to_drop = ['market_segment_Direct','customer_type_Group','reservation_status_No-Show']

model_fit = OLS(revenue.map(np.log), X.drop(columns_to_drop, axis=1)).fit()
print(model_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       revenue_per_stay   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     5224.
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):               0.00
# Time:                        21:26:59   Log-Likelihood:                -15954.
# No. Observations:               54063   AIC:                         3.200e+04
# Df Residuals:                   54016   BIC:                         3.242e+04
# Df Model:                          46
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              4.1673      0.020    208.676      0.000       4.128       4.206
# stays_in_weekend_nights            0.3072      0.002    172.160      0.000       0.304       0.311
# stays_in_week_nights               0.3052      0.001    290.711      0.000       0.303       0.307
# adults                             0.1122      0.003     34.828      0.000       0.106       0.119
# children                           0.0815      0.005     17.228      0.000       0.072       0.091
# babies                             0.0557      0.014      3.916      0.000       0.028       0.084
# is_repeated_guest                 -0.0984      0.010     -9.428      0.000      -0.119      -0.078
# previous_cancellations             0.0169      0.004      4.265      0.000       0.009       0.025
# previous_bookings_not_canceled    -0.0045      0.001     -3.927      0.000      -0.007      -0.002
# days_in_waiting_list              -0.0002   6.02e-05     -4.034      0.000      -0.000      -0.000
# required_car_parking_spaces        0.0995      0.006     16.970      0.000       0.088       0.111
# arrival_date_month_August          0.3136      0.007     47.435      0.000       0.301       0.327
# arrival_date_month_December       -0.0912      0.007    -12.924      0.000      -0.105      -0.077
# arrival_date_month_February       -0.1861      0.007    -26.388      0.000      -0.200      -0.172
# arrival_date_month_January        -0.2654      0.008    -31.265      0.000      -0.282      -0.249
# arrival_date_month_July            0.2245      0.007     33.074      0.000       0.211       0.238
# arrival_date_month_June            0.1819      0.006     28.021      0.000       0.169       0.195
# arrival_date_month_March          -0.1115      0.007    -16.902      0.000      -0.124      -0.099
# arrival_date_month_May             0.1220      0.006     19.082      0.000       0.110       0.135
# arrival_date_month_November       -0.0573      0.007     -8.462      0.000      -0.071      -0.044
# arrival_date_month_October         0.0914      0.006     14.748      0.000       0.079       0.104
# arrival_date_month_September       0.2395      0.006     37.358      0.000       0.227       0.252
# meal_FB                            0.5637      0.019     29.848      0.000       0.527       0.601
# meal_HB                            0.2833      0.005     58.029      0.000       0.274       0.293
# meal_SC                           -0.1544      0.005    -28.409      0.000      -0.165      -0.144
# meal_Undefined                     0.6537      0.015     44.578      0.000       0.625       0.682
# market_segment_Complementary      -0.4557      0.075     -6.088      0.000      -0.602      -0.309
# market_segment_Corporate          -0.2187      0.014    -15.614      0.000      -0.246      -0.191
# market_segment_Groups             -0.2043      0.011    -17.962      0.000      -0.227      -0.182
# market_segment_Offline TA/TO      -0.1054      0.012     -9.059      0.000      -0.128      -0.083
# market_segment_Online TA           0.1590      0.011     14.061      0.000       0.137       0.181
# distribution_channel_Direct        0.0421      0.013      3.320      0.001       0.017       0.067
# distribution_channel_GDS           0.2393      0.034      6.995      0.000       0.172       0.306
# distribution_channel_TA/TO        -0.0583      0.010     -5.730      0.000      -0.078      -0.038
# reserved_room_type_B              -0.1144      0.013     -8.478      0.000      -0.141      -0.088
# reserved_room_type_C               0.3908      0.022     18.104      0.000       0.348       0.433
# reserved_room_type_D               0.1543      0.004     36.397      0.000       0.146       0.163
# reserved_room_type_E               0.2790      0.007     39.835      0.000       0.265       0.293
# reserved_room_type_F               0.3904      0.011     37.166      0.000       0.370       0.411
# reserved_room_type_G               0.5506      0.013     42.826      0.000       0.525       0.576
# reserved_room_type_H               0.5958      0.020     29.527      0.000       0.556       0.635
# deposit_type_Non Refund            0.1288      0.007     19.089      0.000       0.116       0.142
# deposit_type_Refundable            0.2800      0.030      9.464      0.000       0.222       0.338
# customer_type_Transient            0.1634      0.013     12.640      0.000       0.138       0.189
# customer_type_Transient-Party      0.2491      0.013     18.807      0.000       0.223       0.275
# reservation_status_Check-Out      -0.0452      0.003    -12.919      0.000      -0.052      -0.038
# hotel_Resort Hotel                -0.4736      0.004   -129.271      0.000      -0.481      -0.466
# ==============================================================================
# Omnibus:                      964.580   Durbin-Watson:                   0.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1872.828
# Skew:                           0.090   Prob(JB):                         0.00
# Kurtosis:                       3.894   Cond. No.                     1.32e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ---

# %% [markdown]
# ### Model

# %% [markdown]
# $$revenue per stay = \beta_0 + \beta_1*stays in weekend nights+\beta_2*stays in week nights+\beta_3*adults
# +\beta_4*children+\beta_5*babies+\beta_6*isrepeatedguest+\beta_7*previouscancellations$$

# %% [markdown]
# $$revenue per stay = 4.1673 + revenue per night* number nights + additional commision for being a resort hotel$$

# %% [markdown]
# $\beta_0 = commisions for city hotel =4.1673 $
#
# $\beta_1 = revenue per night$
#
# $\beta_3 = adults$

# %%
bookings_2016.revenue_per_stay.map(np.log).hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
model_fit.resid.hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# $$revenue per stay = 30.1210 + 95.9664*stays in weekend nights+93.5027*stays in week nights-35.2703*hotel$$

# %% [markdown]
# $30.1210 = commisions for city hotel$
#
# $95.9664 if weekend and 93.5027 if weekday = revenue per night$
#
# $35.2703 = commision disount for being a resort hotel$

# %% [markdown]
# ### Hypothesis Testing

# %%
from scipy.stats import ttest_1samp
ttest_1samp(hotel_bookings_2016['adr'], 90)
# Out:
# Ttest_1sampResult(statistic=54.897745556949396, pvalue=0.0)

# %%
bookings_2016.iloc[0]
# Out:
# hotel                                Resort Hotel
# arrival_date_month                        January
# stays_in_weekend_nights                         0
# stays_in_week_nights                            1
# adults                                          2
# children                                      0.0
# babies                                          0
# meal                                           BB
# market_segment                          Online TA
# distribution_channel                        TA/TO
# is_repeated_guest                               0
# previous_cancellations                          0
# previous_bookings_not_canceled                  0
# reserved_room_type                              A
# deposit_type                           No Deposit
# days_in_waiting_list                            0
# customer_type                     Transient-Party
# required_car_parking_spaces                     0
# reservation_status                      Check-Out
# revenue_per_stay                            59.94
# Name: 3738, dtype: object
