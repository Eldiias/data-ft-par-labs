# %% [markdown]
# # Project 1
# ROULETTE

# %% [markdown]
# ## Steps 4 - 6

# %%
class Roulette:
    
    def __init__(self, number, bet):
        self.player_chips_remain=number
        self.player_chips_bet=bet
        self.number_player=[]
        self.number_roulette=[]
        self.result_game=[]
        self.result_number_wins=[]
        self.result_number_loses=[]
    
    result_game=[]
    
    
    def player_chips_remaining(self,chips_remain):
        print(f'You have {chips_remain} remaining')
        return

    def player_bet_amount(self,chips_bet):
        if chips_bet>player_chips_remain:
            print(f'You have to choose a number under {player_chips_remain}')
            try_chips_bet=input(f'Please select a number under {player_chips_remain}')
        else:
            print(f'You choose to bet {chips_bet} chips_bet')
        return

    
    def player_number_choice(self, number_player):
        if number_player <0 or number_player>36:
            print('\n You have to choose a number between 1 and 36')
            number_player=input('Please select a number between 1 and 36\n')
        else:
            print(f'You choose the number {number_player}')
        return
    
    def result(self, selection):
       
        """ 
        This is step 4
        Compare the number chosen by player and the one generated by computer (number_roulette)
        Then show a text to notify the player about the result
        """
        
        result_game=[]
        
        number_roulette = 10

        if self.player_chips_bet == number_roulette:
            print("Player wins! Congrats")
            game1.number_player.append('1')
            game1.result_game=1
        elif self.player_chips_bet != number_roulette:
            print("You loose, the casino takes the money")
            game1.number_roulette.append('1')
            game1.result_game=0
    
    def gain(self, selection):
        
        """
        This is step 5&6
        """
        
    
        if game1.result_game==1:
            game1.player_chips_remain=game1.player_chips_remain+game1.player_chips_bet*4
            print("You won ", game1.player_chips_bet*4, "chips")
            print("Player chips after gain : ",game1.player_chips_remain)
        elif game1.result_game!=1:
            game1.player_chips_remain=game1.player_chips_remain-game1.player_chips_bet
            print("You loose ", game1.player_chips_bet, "chips")
            print("Number of chips after loosing",game1.player_chips_remain)

    
    def end_of_the_game(self,end_game):
        if game1.player_chips_remain > 0:
            end_game=input('Do you want to continue? (yes or no)\n')
            if number_player == "no":
                print(f"You won {game1.player_chips_remain} chips")
            else:
                print(f"Start a new game")
        elif game1.player_chips_remain == 0:
            print(f"Sorry, you can't continue. You have no more chips")
        return

# %%
P1=Roulette(1000,50)
P1.player_chips_remaining(P1.player_chips_remain)
player_chips_remain=P1.player_chips_remain

P2=Roulette(1000,80)
P2.player_bet_amount(P2.player_chips_bet)
player_chips_bet=P2.player_chips_bet

P3=Roulette(1000,46)
P3.player_number_choice(P3.player_chips_bet)
number_player=P3.player_chips_bet
# Out:
# You have 1000 remaining
# You choose to bet 80 chips_bet
#
#  You have to choose a number between 1 and 36
# Please select a number between 1 and 36
# 10

# %%
class Roulette:
    
    def __init__(self, number, bet):
        self.player_chips_remain=number
        self.player_chips_bet=bet
        self.number_player=[]
        self.number_roulette=[]
        self.result_game=[]
        self.result_number_wins=[]
        self.result_number_loses=[]
    
    
    def end_of_the_game(self,end_game):
        if game1.player_chips_remain > 0:
            end_game=input('Do you want to continue? (yes or no)\n')
            if number_player == "no":
                print(f"You won {game1.player_chips_remain} chips")
            else:
                print(f"Start a new game")
        elif game1.player_chips_remain == 0:
            print(f"Sorry, you can't continue. You have no more chips")
        return



P5=Roulette(1000,19)
P5.end_of_the_game(P5.player_chips_bet)
end_game=P5.player_chips_bet

# %%
game1=Roulette(100,10)                     ### GAME START HERE (for my part)

# %%
game1=Roulette(game1.player_chips_remain,input('Please select a number between 1 and 36\n'))

# %%
#this shows step 4
print("Player bets on number : ",P1.player_chips_bet)
print("The number of player's chips ",P1.player_chips_remain)
P1.result(P1.player_chips_bet)


#this shows the step 6
print("the player wins ",len(P1.number_player)," times")
print("the casino wins ",len(P1.number_roulette)," times")
# Out:
# Player bets on number :  50
# The number of player's chips  1000
# You loose, the casino takes the money
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ef5d3b02c988> in <module>
#       2 print("Player bets on number : ",P1.player_chips_bet)
#       3 print("The number of player's chips ",P1.player_chips_remain)
# ----> 4 P1.result(P1.player_chips_bet)
#       5
#       6
#
# <ipython-input-9-0832e8853418> in result(self, selection)
#      52         elif self.player_chips_bet != number_roulette:
#      53             print("You loose, the casino takes the money")
# ---> 54             game1.number_roulette.append('1')
#      55             game1.result_game=0
#      56
#
# NameError: name 'game1' is not defined

# %%
#this shows step 5
print("Player chips before gain : ",game1.player_chips_remain)
game1.gain(game1.player_chips_remain)  #----< this is the problem! the variable type chages a lot

# %%
game1.player_chips_bet
type(game1.player_chips_bet)

# %%
game1.player_chips_remain
type(game1.player_chips_remain)

# %%
game1.number_player

# %%
game1.number_roulette

# %%
print(number_player)

# %%
    number_roulette = 5
    player_chips_bet = 3
    
#step4
#showing the result of the game

   def result(self, selected_number_player):
       
        """ 
        Compare the number chosen by player and the one generated by computer (number_roulette)
        Then show a text to notify the player about the result
        """

        if selected_number_player.bet == number_roulette:
            print("Player wins!")
            result_number_wins+=1
        elif selected_number_player.bet != number_roulette:
            print("You loose, the casino takes the money")
            result_number_loses+=1

# %%
Roulette(10,20)

# %%
Roulette.result()

# %%
how to save the results?
the variable type changes a lot!
